# %%
import os
import json
import pandas as pd
import torch
import numpy as np 
from parse import *

# %%
datasets = ['FB15k-237','NELL995']
model_names = ['SheafE_Translational', 'SheafE_Multisection']
results_loc = '../data/{}'
complex_metrics = ['1','10','mrr']
groupby_cols = ['model','embdim','esdim','sec','orthogonal']
resnames = ['1p','2p','3p','2i','3i','ip','pi']
orthogonals = [0,0.1,0.01]

# %%
def infer_params_from_filename(fname):
#     print(fname)
    shared_names = ['class','model','embdim','esdim','sec','norm','lbda']
    parse_str_seed_orthogonal = '{}_{}_{:d}embdim_{:d}esdim_{:d}sec_{:d}norm_{:f}lbda_{:f}orthogonal_{:d}epochs_{}loss_{}_{}seed_{:d}-{:d}'
    seed_orthogonal_names = shared_names + ['orthogonal','epochs','loss','sampler','seed','date','time']
    
    parse_str_original_orthogonal = '{}_{}_{:d}embdim_{:d}esdim_{:d}sec_{:d}norm_{:f}lbda_{:f}orthogonal_{:d}epochs_{}loss_{}_{:d}-{:d}'
    original_orthogonal_names = [n for n in seed_orthogonal_names if n != 'seed']
    
    parse_str_seed = '{}_{}_{:d}embdim_{:d}esdim_{:d}sec_{:d}norm_{:f}lbda_{:d}epochs_{}loss_{}_{}seed_{:d}-{:d}'
    seed_names = [n for n in seed_orthogonal_names if n != 'orthogonal']
    
    parse_str_original = '{}_{}_{:d}embdim_{:d}esdim_{:d}sec_{:d}norm_{:f}lbda_{:d}epochs_{}loss_{}_{:d}-{:d}'
    original_names = [n for n in seed_names if n != 'seed']
    
    parse_options = [parse_str_seed_orthogonal, parse_str_original_orthogonal, parse_str_seed, parse_str_original]
    parse_names = [seed_orthogonal_names, original_orthogonal_names, seed_names, original_names]
    for parse_option, parse_name in zip(parse_options,parse_names):
        parsed = parse(parse_option, fname)
        if parsed is not None:
            return {parse_name[i]:parsed[i] for i in range(len(parse_name))}
    
    print('ignoring', fname)

# %%
results = []
complex_results = []
idx = 0
for dataset in datasets:
    dataset_dirname = results_loc.format(dataset)
    dataset_complex_dirname = os.path.join(dataset_dirname, 'complex')
    subdirs = [f.name for f in os.scandir(dataset_dirname) if f.is_dir()]
    for subdir in subdirs:
        for model_name in model_names:
            if model_name in subdir:
                complex_fname = os.path.join(dataset_complex_dirname, subdir + '.csv')
                params = infer_params_from_filename(subdir)
                pk_result_fname = os.path.join(dataset_dirname, subdir, 'results.json')
                if params is not None and os.path.exists(complex_fname) and os.path.exists(pk_result_fname):
                    
                    with open(pk_result_fname) as json_file:
                        pkr = json.load(json_file)
                        
                    cr = pd.read_csv(complex_fname, index_col=0)[complex_metrics].to_dict()
                    try:
                        pk_mrr = pkr['metrics']['inverse_harmonic_mean_rank']['both']['realistic']
                        pk_10 = pkr['metrics']['hits_at_k']['both']['realistic']['10']
                    except KeyError:
                        # old pykeen results format
                        pk_mrr = pkr['metrics']['mean_reciprocal_rank']['both']['avg']
                        pk_10 = pkr['metrics']['hits_at_k']['both']['avg']['10']
                    
                    r = {'id':idx,'dataset':dataset,'gc_mrr':pk_mrr,'gc_10':pk_10}
                    results.append({**r,**params,**cr})
                    idx += 1
# cdf = pd.concat(complex_results, ignore_index=True)
df = pd.DataFrame(results)
df['date'] = pd.to_datetime(df['date'], format='%Y%m%d')
df['orthogonal'] = df['orthogonal'].fillna(0)
df['seed'] = df['seed'].fillna(1234)
# df = df.merge(cdf, on='id', how='left')
# Out:
# ignoring SheafE_Multisection_64embdim_2esdim_1sec_2norm_1000epochs_SoftplusLossloss_20210208-1109
# ignoring SheafE_Multisection_64embdim_64esdim_64sec_1norm_1000epochs_SoftplusLossloss_20210304-1455
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_1epochs_SoftplusLossloss_neighborhood_20210505-1539
# ignoring SheafE_Multisection_64embdim_8esdim_1sec_2norm_1000epochs_SoftplusLossloss_20210208-1109
# ignoring SheafE_Translational_64embdim_64esdim_64sec_2norm_1000epochs_SoftplusLossloss_20210301-1444
# ignoring SheafE_Multisection_16embdim_16esdim_1sec_2norm_5epochs_SoftplusLossloss_neighborhood_20210504-2133
# ignoring SheafE_Multisection_25sec_1000epochs_64embdim_SoftplusLossloss_7seed_20210203-1742
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_1epochs_SoftplusLossloss_neighborhood_20210505-1544
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_100epochs_SoftplusLossloss_neighborhood_20210501-2118
# ignoring SheafE_Translational_Identity_Complex_Queries_64embdim_64esdim_1sec_2norm_50epochs_SoftplusLoss_20210428-2024
# ignoring SheafE_Multisection_64embdim_64esdim_96sec_2norm_1000epochs_SoftplusLossloss_20210301-1108
# ignoring SheafE_Translational_Identity_Complex_Queries_64embdim_64esdim_1sec_2norm_100epochs_SoftplusLoss_20210430-2134
# ignoring SheafE_Translational_64embdim_64esdim_1sec_2norm_1epochs_SoftplusLossloss_neighborhood_20210502-2040
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_1epochs_SoftplusLossloss_geometric_20210503-1246
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_10epochs_SoftplusLossloss_neighborhood_20210503-1838
# ignoring SheafE_Multisection_64embdim_64esdim_32sec_2norm_0.1orthogonal_1000epochs_SoftplusLossloss_20210214-1654
# ignoring SheafE_Multisection_25sec_1000epochs_64embdim_SoftplusLossloss_42seed_20210203-1525
# ignoring SheafE_Multisection_16embdim_16esdim_1sec_2norm_100epochs_SoftplusLossloss_geometric_20210504-1803
# ignoring SheafE_Multisection_16embdim_16esdim_1sec_2norm_1epochs_SoftplusLossloss_neighborhood_20210504-1955
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_10epochs_SoftplusLossloss_neighborhood_20210503-1553
# ignoring SheafE_Multisection_64embdim_64esdim_110sec_2norm_1000epochs_SoftplusLossloss_20210301-1107
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_10epochs_SoftplusLossloss_geometric_20210503-1517
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_1epochs_SoftplusLossloss_neighborhood_20210505-2153
# ignoring SheafE_Multisection_64embdim_64esdim_24sec_2norm_0.3orthogonal_1000epochs_SoftplusLossloss_20210228-1538
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_5epochs_SoftplusLossloss_geometric_20210503-1238
# ignoring SheafE_Multisection_16embdim_16esdim_1sec_2norm_100epochs_SoftplusLossloss_neighborhood_20210504-1850
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_100epochs_SoftplusLossloss_neighborhood_20210506-1518
# ignoring SheafE_Multisection_64embdim_4esdim_1sec_2norm_1000epochs_SoftplusLossloss_20210208-1109
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_20epochs_SoftplusLossloss_neighborhood_20210503-1811
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_1000epochs_SoftplusLossloss_20210301-2035
# ignoring SheafE_Multisection_64embdim_128esdim_1sec_2norm_1000epochs_SoftplusLossloss_20210208-1154
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_1epochs_SoftplusLossloss_neighborhood_20210502-1352
# ignoring SheafE_Multisection_64embdim_64esdim_8sec_2norm_1000epochs_SoftplusLossloss_20210301-1835
# ignoring SheafE_Multisection_64embdim_64esdim_64sec_2norm_1000epochs_SoftplusLossloss_20210301-2121
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_10epochs_SoftplusLossloss_geometric_20210503-1451
# ignoring SheafE_Multisection_64embdim_64esdim_64sec_2norm_0.1orthogonal_1000epochs_SoftplusLossloss_20210214-1803
# ignoring SheafE_Multisection_16embdim_16esdim_1sec_2norm_1epochs_SoftplusLossloss_neighborhood_20210504-2124
# ignoring SheafE_Multisection_64embdim_64esdim_24sec_2norm_0.5orthogonal_1000epochs_SoftplusLossloss_20210228-1540
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_25epochs_SoftplusLossloss_neighborhood_20210503-2006
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_1epochs_SoftplusLossloss_geometric_20210503-1406
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_50epochs_SoftplusLossloss_geometric_20210503-1259
# ignoring SheafE_Multisection_64embdim_64esdim_8sec_2norm_0.5orthogonal_1000epochs_SoftplusLossloss_20210228-1540
# ignoring SheafE_Multisection_25sec_1000epochs_64embdim_SoftplusLossloss_1234seed_20210203-1958
# ignoring SheafE_Multisection_64embdim_64esdim_24sec_2norm_1000epochs_SoftplusLossloss_20210228-1912
# ignoring SheafE_Multisection_64embdim_64esdim_16sec_2norm_0.001orthogonal_1000epochs_SoftplusLossloss_20210225-0903
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_5epochs_SoftplusLossloss_20210301-2028
# ignoring SheafE_Multisection_64embdim_64esdim_8sec_2norm_0.001orthogonal_1000epochs_SoftplusLossloss_20210225-0903
# ignoring SheafE_Multisection_64embdim_64esdim_64sec_2norm_1000epochs_SoftplusLossloss_20210228-1911
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_1epochs_SoftplusLossloss_neighborhood_20210505-1533
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_10epochs_SoftplusLossloss_geometric_20210503-1458
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_50epochs_SoftplusLossloss_neighborhood_20210503-1039
# ignoring SheafE_Multisection_64embdim_64esdim_24sec_2norm_1e-05orthogonal_1000epochs_SoftplusLossloss_20210225-0906
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_100epochs_SoftplusLossloss_neighborhood_20210506-1500
# ignoring SheafE_Multisection_16embdim_16esdim_1sec_2norm_1epochs_SoftplusLossloss_neighborhood_20210505-1829
# ignoring SheafE_Multisection_16embdim_16esdim_1sec_2norm_1epochs_SoftplusLossloss_neighborhood_20210505-1946
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_1norm_1000epochs_SoftplusLossloss_20210304-1923
# ignoring SheafE_Translational_64embdim_64esdim_64sec_1norm_1000epochs_SoftplusLossloss_20210303-1631
# ignoring SheafE_Multisection_16embdim_64esdim_1sec_2norm_1000epochs_SoftplusLossloss_schlichtkrull_20210501-1123
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_1epochs_SoftplusLossloss_neighborhood_20210505-2032
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_100epochs_SoftplusLossloss_neighborhood_20210505-2046
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_100epochs_SoftplusLossloss_neighborhood_20210502-1258
# ignoring SheafE_Translational_64embdim_64esdim_32sec_2norm_1000epochs_SoftplusLossloss_20210301-1428
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_100epochs_SoftplusLossloss_None_20210501-1135
# ignoring SheafE_Translational_64embdim_64esdim_8sec_2norm_1000epochs_SoftplusLossloss_20210301-1428
# ignoring SheafE_Translational_64embdim_64esdim_1sec_2norm_1000epochs_SoftplusLossloss_20210301-1428
# ignoring SheafE_Multisection_64embdim_64esdim_72sec_2norm_1000epochs_SoftplusLossloss_20210301-1108
# ignoring SheafE_Multisection_64embdim_64esdim_24sec_2norm_0.0001orthogonal_1000epochs_SoftplusLossloss_20210225-0903
# ignoring SheafE_Multisection_64embdim_64esdim_8sec_2norm_0.3orthogonal_1000epochs_SoftplusLossloss_20210228-1538
# ignoring SheafE_Multisection_16embdim_16esdim_1sec_2norm_1epochs_SoftplusLossloss_neighborhood_20210504-2122
# ignoring SheafE_Multisection_64embdim_96esdim_1sec_2norm_1000epochs_SoftplusLossloss_20210208-1109
# ignoring SheafE_Multisection_50sec_1000epochs_64embdim_SoftplusLossloss_1235seed_20210202-0825
# ignoring SheafE_Multisection_64embdim_64esdim_110sec_2norm_1000epochs_SoftplusLossloss_20210301-1030
# ignoring SheafE_Multisection_64embdim_64esdim_4sec_2norm_0.5orthogonal_1000epochs_SoftplusLossloss_20210228-1540
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_10epochs_SoftplusLossloss_geometric_20210503-1441
# ignoring SheafE_Multisection_64embdim_64esdim_24sec_2norm_1.0orthogonal_1000epochs_SoftplusLossloss_20210228-1539
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_50epochs_SoftplusLossloss_geometric_20210505-1020
# ignoring SheafE_Multisection_64embdim_64esdim_8sec_2norm_1000epochs_SoftplusLossloss_20210301-1958
# ignoring SheafE_Multisection_32embdim_64esdim_1sec_2norm_50epochs_SoftplusLossloss_neighborhood_20210503-1056
# ignoring SheafE_Multisection_64embdim_64esdim_128sec_2norm_1000epochs_SoftplusLossloss_20210228-1913
# ignoring SheafE_Multisection_16embdim_16esdim_1sec_2norm_100epochs_SoftplusLossloss_neighborhood_20210504-2141
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_10epochs_SoftplusLossloss_neighborhood_20210505-1128
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_25epochs_SoftplusLossloss_neighborhood_20210503-1959
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_25epochs_SoftplusLossloss_neighborhood_20210503-1948
# ignoring SheafE_Multisection_16embdim_16esdim_1sec_2norm_5epochs_SoftplusLossloss_neighborhood_20210504-2129
# ignoring SheafE_Multisection_64embdim_64esdim_64sec_2norm_1000epochs_SoftplusLossloss_20210301-2201
# ignoring SheafE_Multisection_16embdim_16esdim_1sec_2norm_1epochs_SoftplusLossloss_neighborhood_20210504-1848
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_50epochs_SoftplusLossloss_neighborhood_20210505-1055
# ignoring SheafE_Multisection_64embdim_16esdim_1sec_2norm_1000epochs_SoftplusLossloss_20210208-1057
# ignoring SheafE_Multisection_16embdim_16esdim_1sec_2norm_500epochs_SoftplusLossloss_neighborhood_20210506-1322
# ignoring SheafE_Multisection_64embdim_64esdim_88sec_2norm_1000epochs_SoftplusLossloss_20210301-1108
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_500epochs_SoftplusLossloss_neighborhood_20210506-1414
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_1epochs_SoftplusLossloss_neighborhood_20210503-1033
# ignoring SheafE_Multisection_64embdim_64esdim_16sec_2norm_1000epochs_SoftplusLossloss_20210228-1913
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_25epochs_SoftplusLossloss_neighborhood_20210503-1845
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_1000epochs_SoftplusLossloss_20210208-1157
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_10epochs_SoftplusLossloss_neighborhood_20210503-1820
# ignoring SheafE_Multisection_64embdim_64esdim_8sec_2norm_0.1orthogonal_1000epochs_SoftplusLossloss_20210214-1458
# ignoring SheafE_Translational_64embdim_64esdim_1sec_1norm_1000epochs_SoftplusLossloss_20210303-1631
# ignoring SheafE_Multisection_16embdim_16esdim_1sec_2norm_100epochs_SoftplusLossloss_neighborhood_20210503-2040
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_1000epochs_SoftplusLossloss_neighborhood_20210504-2149
# ignoring SheafE_Translational_Identity_Complex_Queries_64embdim_64esdim_1sec_2norm_50epochs_SoftplusLoss_20210430-1750
# ignoring SheafE_Multisection_64embdim_64esdim_8sec_2norm_1.0orthogonal_1000epochs_SoftplusLossloss_20210228-1538
# ignoring SheafE_Multisection_64embdim_32esdim_1sec_2norm_1000epochs_SoftplusLossloss_20210208-1057
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_500epochs_SoftplusLossloss_neighborhood_20210502-2313
# ignoring SheafE_Multisection_16embdim_64esdim_1sec_2norm_25epochs_SoftplusLossloss_neighborhood_20210503-2017
# ignoring SheafE_Multisection_16embdim_16esdim_1sec_2norm_5epochs_SoftplusLossloss_neighborhood_20210504-2131
# ignoring SheafE_Multisection_64embdim_64esdim_1sec_2norm_1epochs_SoftplusLossloss_geometric_20210503-1252

# %%
tdf = df[(df['epochs'] == 250)&(df['loss'] == 'MarginRankingLoss')]
tdf
# Out:
#       id    dataset    gc_mrr     gc_10   class          model  embdim  esdim  \
# 2      2  FB15k-237  0.083767  0.119581  SheafE   Multisection      64     64
# 5      5  FB15k-237  0.101673  0.258636  SheafE  Translational      64     64
# 7      7  FB15k-237  0.211377  0.395709  SheafE  Translational      64     64
# 8      8  FB15k-237  0.091088  0.224092  SheafE  Translational      64     64
# 11    11  FB15k-237  0.207479  0.346462  SheafE   Multisection      64     32
# ..   ...        ...       ...       ...     ...            ...     ...    ...
# 302  302    NELL995  0.000189  0.000105  SheafE   Multisection      32     32
# 303  303    NELL995  0.101661  0.189896  SheafE   Multisection      32     16
# 304  304    NELL995  0.071934  0.109378  SheafE   Multisection      64     64
# 305  305    NELL995  0.000709  0.000701  SheafE  Translational      32     32
# 306  306    NELL995  0.000281  0.000333  SheafE   Multisection      32     32
#
#      sec  norm  ...  epochs               loss sampler       date  time  \
# 2     16     2  ...     250  MarginRankingLoss    None 2021-05-26   818
# 5     64     2  ...     250  MarginRankingLoss    None 2021-05-27  2103
# 7      1     2  ...     250  MarginRankingLoss    None 2021-05-27  1849
# 8     16     2  ...     250  MarginRankingLoss    None 2021-05-27  1456
# 11     1     2  ...     250  MarginRankingLoss    None 2021-05-26  2245
# ..   ...   ...  ...     ...                ...     ...        ...   ...
# 302    1     2  ...     250  MarginRankingLoss    None 2021-05-27   909
# 303    1     2  ...     250  MarginRankingLoss    None 2021-05-26   905
# 304   16     2  ...     250  MarginRankingLoss    None 2021-05-26  1033
# 305   16     2  ...     250  MarginRankingLoss    None 2021-05-27   302
# 306    8     2  ...     250  MarginRankingLoss    None 2021-05-27   519
#
#                                                      1  \
# 2    {'1p': 0.014874080438167856, '2p': 8.717724710...
# 5    {'1p': 6.195812456887471e-05, '2p': 0.00788861...
# 7    {'1p': 0.048034068707429614, '2p': 0.006772002...
# 8    {'1p': 3.304433310339985e-05, '2p': 0.00216181...
# 11   {'1p': 0.04622489147001847, '2p': 9.7378839856...
# ..                                                 ...
# 302  {'1p': 0.09982503794066756, '2p': 1.2866590610...
# 303  {'1p': 3.866564847125693e-05, '2p': 8.57772707...
# 304  {'1p': 2.899923635344269e-05, '2p': 1.07221588...
# 305  {'1p': 0.00021266106659191308, '2p': 0.0006004...
# 306  {'1p': 0.24524654184106484, '2p': 3.0022044758...
#
#                                                     10  \
# 2    {'1p': 0.03534917533736199, '2p': 0.0006964905...
# 5    {'1p': 0.3079979677735141, '2p': 0.09891649810...
# 7    {'1p': 0.21378444355408324, '2p': 0.0356017038...
# 8    {'1p': 0.09521311529580874, '2p': 0.0173046835...
# 11   {'1p': 0.19835273999479552, '2p': 0.0008615708...
# ..                                                 ...
# 302  {'1p': 0.3639694154720592, '2p': 0.00015225465...
# 303  {'1p': 0.00020299465447409882, '2p': 0.0001372...
# 304  {'1p': 0.00018366183023847042, '2p': 0.0001458...
# 305  {'1p': 0.00039632289683038345, '2p': 0.0008577...
# 306  {'1p': 0.6127635305603619, '2p': 0.00017798783...
#
#                                                    mrr orthogonal  seed
# 2    {'1p': 0.022465451246184414, '2p': 0.000738137...       1.00  1234
# 5    {'1p': 0.10815869263452142, '2p': 0.0408387581...       0.00    11
# 7    {'1p': 0.101526761133875, '2p': 0.018825811310...       0.00    11
# 8    {'1p': 0.03208190681743316, '2p': 0.0084451183...       0.01    11
# 11   {'1p': 0.09508062333229382, '2p': 0.0008007281...       0.00    22
# ..                                                 ...        ...   ...
# 302  {'1p': 0.1873675777058704, '2p': 0.00013942063...       0.00    33
# 303  {'1p': 0.00020534029265171244, '2p': 0.0001668...       0.00  1234
# 304  {'1p': 0.00020446760381509496, '2p': 0.0001811...       1.00  1234
# 305  {'1p': 0.0004097018271520152, '2p': 0.00080331...      10.00    11
# 306  {'1p': 0.3650828275584577, '2p': 0.00020045160...       0.00    11
#
# [117 rows x 21 columns]

# %%
fb_df = tdf[tdf['dataset'] == 'FB15k-237'].reset_index(drop=True)

# %%
nell_df = tdf[(tdf['dataset'] == 'NELL995')&(tdf['10'].apply(lambda x: x['1p'] > 0.001))].reset_index(drop=True)

# %%
for complex_metric in complex_metrics:
    joined = fb_df.join(pd.DataFrame(fb_df[complex_metric].values.tolist()))
    grouped = joined.groupby(groupby_cols)
    sv = grouped.mean()
    embdim = 64
    sv = sv[sv.index.get_level_values('embdim') == embdim].droplevel('embdim',axis=0)
    sv = sv[sv.index.get_level_values('orthogonal').isin(orthogonals)]
    sv[resnames] = 100*sv[resnames].round(4)
    sv = sv[resnames]
    sv.to_excel(f'FB15k-237/{complex_metric}.xlsx')

# %%
sv
# Out:
#                                        1p    2p    3p     2i     3i    ip  \
# model         esdim sec orthogonal
# Multisection  16    1   0.00         8.62  0.08  0.09   0.57   0.38  0.05
#               32    1   0.00         9.44  0.08  0.08   0.92   0.58  0.06
#               64    1   0.00        10.16  0.08  0.08   1.16   0.69  0.06
#                     16  0.00        20.28  0.07  0.08  15.95  10.04  0.07
#                         0.01        16.70  0.07  0.07  10.18   6.86  0.07
#                         0.10         6.13  0.07  0.07   3.05   2.95  0.07
#                     32  0.00        22.89  0.07  0.08  17.05   9.94  0.07
#                         0.01         9.18  0.07  0.07   3.75   2.93  0.07
#                         0.10         5.76  0.07  0.07   2.64   2.53  0.07
#                     64  0.00        24.70  0.07  0.08  18.74  11.06  0.07
#                         0.01         0.49  0.07  0.08   0.43   0.46  0.07
# Translational 64    1   0.00        10.16  1.88  1.48   1.52   1.44  3.18
#                     16  0.00        10.90  4.02  3.77   1.34   1.06  4.15
#                         0.01         3.21  0.84  0.94   0.62   0.68  0.78
#                         0.10         0.59  0.10  0.08   0.07   0.08  0.21
#                     32  0.00        10.93  3.91  3.86   1.30   1.09  4.52
#                         0.01         3.93  1.21  1.35   0.85   0.86  1.65
#                         0.10         1.21  0.21  0.21   0.26   0.33  0.38
#                     64  0.00        10.90  3.98  3.93   1.08   1.00  5.17
#                         0.01         4.16  1.82  1.95   1.03   1.00  3.01
#                         0.10         1.46  0.42  0.44   0.56   0.84  0.81
#
#                                       pi
# model         esdim sec orthogonal
# Multisection  16    1   0.00        0.05
#               32    1   0.00        0.06
#               64    1   0.00        0.06
#                     16  0.00        0.06
#                         0.01        0.07
#                         0.10        0.07
#                     32  0.00        0.07
#                         0.01        0.07
#                         0.10        0.07
#                     64  0.00        0.07
#                         0.01        0.07
# Translational 64    1   0.00        2.38
#                     16  0.00        3.51
#                         0.01        0.66
#                         0.10        0.10
#                     32  0.00        3.36
#                         0.01        1.67
#                         0.10        0.36
#                     64  0.00        3.28
#                         0.01        2.38
#                         0.10        0.96

# %%
for complex_metric in complex_metrics:
    joined = nell_df.join(pd.DataFrame(nell_df[complex_metric].values.tolist()))
    grouped = joined.groupby(groupby_cols)
    sv = grouped.mean()
    embdim = 32
    sv = sv[sv.index.get_level_values('embdim') == embdim].droplevel('embdim',axis=0)
    sv = sv[sv.index.get_level_values('orthogonal').isin(orthogonals)]
    sv[resnames] = 100*sv[resnames].round(4)
    sv = sv[resnames]
    sv.to_excel(f'NELL995/{complex_metric}.xlsx')

# %%
grouped.mean()
# Out:
#                                                    id    gc_mrr     gc_10  \
# model         embdim esdim sec orthogonal
# Multisection  32     8     1   0.00        274.250000  0.000176  0.000114
#                      16    1   0.00        255.000000  0.000194  0.000166
#                      32    1   0.00        251.750000  0.000219  0.000223
#                            8   0.00        280.000000  0.000294  0.000327
#                                0.01        236.000000  0.000215  0.000228
#                                0.10        238.000000  0.000196  0.000158
#                                1.00        271.000000  0.000173  0.000175
#                                10.00       229.000000  0.000137  0.000070
#                            16  0.00        255.666667  0.000306  0.000345
#                                0.01        250.000000  0.000182  0.000123
#                                0.10        231.000000  0.000193  0.000140
#                                1.00        296.000000  0.000229  0.000263
#                                10.00       290.000000  0.000206  0.000193
#                            32  0.00        253.666667  0.000396  0.000456
#                                0.01        214.000000  0.000209  0.000175
#                                0.10        289.000000  0.000205  0.000140
#                                1.00        294.000000  0.000297  0.000263
#               64     64    16  10.00       263.000000  0.116077  0.161071
#                            32  0.01        239.000000  0.029284  0.060892
# Translational 32     32    1   0.00        253.500000  0.011895  0.028173
#                            8   0.00        269.666667  0.000945  0.001297
#                                0.01        230.000000  0.000861  0.001051
#                                0.10        226.000000  0.000728  0.000736
#                            16  0.00        232.000000  0.000922  0.001250
#                                0.01        284.000000  0.001274  0.001945
#                                0.10        228.000000  0.000726  0.000771
#                            32  0.00        251.333333  0.000991  0.001402
#                                0.01        243.000000  0.001787  0.003102
#                                0.10        279.000000  0.000734  0.000701
#
#                                            norm  lbda  epochs         time  \
# model         embdim esdim sec orthogonal
# Multisection  32     8     1   0.00         2.0   0.0   250.0  1142.500000
#                      16    1   0.00         2.0   0.0   250.0  1088.000000
#                      32    1   0.00         2.0   0.0   250.0  1050.500000
#                            8   0.00         2.0   0.0   250.0   630.333333
#                                0.01         2.0   0.0   250.0   433.000000
#                                0.10         2.0   0.0   250.0   613.000000
#                                1.00         2.0   0.0   250.0   751.000000
#                                10.00        2.0   0.0   250.0   934.000000
#                            16  0.00         2.0   0.0   250.0   923.333333
#                                0.01         2.0   0.0   250.0  2358.000000
#                                0.10         2.0   0.0   250.0   253.000000
#                                1.00         2.0   0.0   250.0   539.000000
#                                10.00        2.0   0.0   250.0   835.000000
#                            32  0.00         2.0   0.0   250.0   641.000000
#                                0.01         2.0   0.0   250.0   212.000000
#                                0.10         2.0   0.0   250.0   850.000000
#                                1.00         2.0   0.0   250.0  1459.000000
#               64     64    16  10.00        2.0   0.0   250.0  1624.000000
#                            32  0.01         2.0   0.0   250.0  1149.000000
# Translational 32     32    1   0.00         2.0   0.0   250.0  1400.500000
#                            8   0.00         2.0   0.0   250.0  2272.666667
#                                0.01         2.0   0.0   250.0  2232.000000
#                                0.10         2.0   0.0   250.0    14.000000
#                            16  0.00         2.0   0.0   250.0  2299.666667
#                                0.01         2.0   0.0   250.0  2226.000000
#                                0.10         2.0   0.0   250.0  2359.000000
#                            32  0.00         2.0   0.0   250.0  1544.666667
#                                0.01         2.0   0.0   250.0  2232.000000
#                                0.10         2.0   0.0   250.0    48.000000
#
#                                                  1p        2p        3p  \
# model         embdim esdim sec orthogonal
# Multisection  32     8     1   0.00        0.148962  0.000116  0.000580
#                      16    1   0.00        0.172117  0.000105  0.000161
#                      32    1   0.00        0.187777  0.000141  0.000192
#                            8   0.00        0.363871  0.000203  0.000225
#                                0.01        0.060893  0.000200  0.000189
#                                0.10        0.030060  0.000189  0.000197
#                                1.00        0.029665  0.000201  0.000185
#                                10.00       0.038304  0.000188  0.000181
#                            16  0.00        0.384833  0.000203  0.000218
#                                0.01        0.053038  0.000203  0.000192
#                                0.10        0.023656  0.000178  0.000185
#                                1.00        0.027304  0.000191  0.000185
#                                10.00       0.037230  0.000170  0.000185
#                            32  0.00        0.409392  0.000197  0.000208
#                                0.01        0.007718  0.000195  0.000190
#                                0.10        0.006823  0.000180  0.000188
#                                1.00        0.006939  0.000173  0.000177
#               64     64    16  10.00       0.066973  0.000182  0.000181
#                            32  0.01        0.246787  0.000167  0.000201
# Translational 32     32    1   0.00        0.147533  0.000126  0.000111
#                            8   0.00        0.121774  0.000401  0.000086
#                                0.01        0.021966  0.000300  0.000055
#                                0.10        0.000742  0.000342  0.000110
#                            16  0.00        0.118366  0.000625  0.000150
#                                0.01        0.037703  0.000596  0.000130
#                                0.10        0.001181  0.000741  0.000167
#                            32  0.00        0.125950  0.000905  0.000263
#                                0.01        0.102203  0.000839  0.000268
#                                0.10        0.002032  0.001080  0.000276
#
#                                                  2i        3i        ip  \
# model         embdim esdim sec orthogonal
# Multisection  32     8     1   0.00        0.001460  0.001058  0.000084
#                      16    1   0.00        0.003329  0.002775  0.000115
#                      32    1   0.00        0.005826  0.004973  0.000174
#                            8   0.00        0.053027  0.048521  0.000187
#                                0.01        0.013406  0.015432  0.000179
#                                0.10        0.005734  0.006659  0.000186
#                                1.00        0.004819  0.006195  0.000182
#                                10.00       0.004939  0.005728  0.000188
#                            16  0.00        0.054691  0.048447  0.000201
#                                0.01        0.011444  0.013150  0.000184
#                                0.10        0.004678  0.005475  0.000194
#                                1.00        0.004695  0.006122  0.000199
#                                10.00       0.005353  0.006261  0.000188
#                            32  0.00        0.055063  0.050906  0.000195
#                                0.01        0.001338  0.000922  0.000180
#                                0.10        0.001045  0.000675  0.000177
#                                1.00        0.001406  0.000836  0.000191
#               64     64    16  10.00       0.010915  0.012015  0.000182
#                            32  0.01        0.012363  0.015672  0.000188
# Translational 32     32    1   0.00        0.056414  0.048361  0.000285
#                            8   0.00        0.085261  0.089401  0.002190
#                                0.01        0.009145  0.010845  0.002119
#                                0.10        0.000437  0.000393  0.002249
#                            16  0.00        0.072564  0.078070  0.002295
#                                0.01        0.011656  0.011620  0.002190
#                                0.10        0.000520  0.000555  0.002248
#                            32  0.00        0.069058  0.076343  0.002324
#                                0.01        0.020857  0.009971  0.002234
#                                0.10        0.000555  0.000583  0.002226
#
#                                                  pi
# model         embdim esdim sec orthogonal
# Multisection  32     8     1   0.00        0.000036
#                      16    1   0.00        0.000037
#                      32    1   0.00        0.000061
#                            8   0.00        0.000116
#                                0.01        0.000133
#                                0.10        0.000164
#                                1.00        0.000179
#                                10.00       0.000179
#                            16  0.00        0.000076
#                                0.01        0.000126
#                                0.10        0.000158
#                                1.00        0.000146
#                                10.00       0.000179
#                            32  0.00        0.000069
#                                0.01        0.000158
#                                0.10        0.000148
#                                1.00        0.000162
#               64     64    16  10.00       0.000159
#                            32  0.01        0.000101
# Translational 32     32    1   0.00        0.001253
#                            8   0.00        0.000479
#                                0.01        0.000120
#                                0.10        0.000140
#                            16  0.00        0.000484
#                                0.01        0.000259
#                                0.10        0.000219
#                            32  0.00        0.000596
#                                0.01        0.000670
#                                0.10        0.000364

# %%
sv = grouped.mean()
embdim = 32
sv = sv[sv.index.get_level_values('embdim') == embdim].droplevel('embdim',axis=0)
sv = sv[sv.index.get_level_values('orthogonal').isin(orthogonals)]
sv[resnames] = 100*sv[resnames].round(4)
sv = sv[resnames]
sv
# Out:
#                                        1p    2p    3p    2i    3i    ip    pi
# model         esdim sec orthogonal
# Multisection  8     1   0.00        14.90  0.01  0.06  0.15  0.11  0.01  0.00
#               16    1   0.00        17.21  0.01  0.02  0.33  0.28  0.01  0.00
#               32    1   0.00        18.78  0.01  0.02  0.58  0.50  0.02  0.01
#                     8   0.00        36.39  0.02  0.02  5.30  4.85  0.02  0.01
#                         0.01         6.09  0.02  0.02  1.34  1.54  0.02  0.01
#                         0.10         3.01  0.02  0.02  0.57  0.67  0.02  0.02
#                     16  0.00        38.48  0.02  0.02  5.47  4.84  0.02  0.01
#                         0.01         5.30  0.02  0.02  1.14  1.32  0.02  0.01
#                         0.10         2.37  0.02  0.02  0.47  0.55  0.02  0.02
#                     32  0.00        40.94  0.02  0.02  5.51  5.09  0.02  0.01
#                         0.01         0.77  0.02  0.02  0.13  0.09  0.02  0.02
#                         0.10         0.68  0.02  0.02  0.10  0.07  0.02  0.01
# Translational 32    1   0.00        14.75  0.01  0.01  5.64  4.84  0.03  0.13
#                     8   0.00        12.18  0.04  0.01  8.53  8.94  0.22  0.05
#                         0.01         2.20  0.03  0.01  0.91  1.08  0.21  0.01
#                         0.10         0.07  0.03  0.01  0.04  0.04  0.22  0.01
#                     16  0.00        11.84  0.06  0.01  7.26  7.81  0.23  0.05
#                         0.01         3.77  0.06  0.01  1.17  1.16  0.22  0.03
#                         0.10         0.12  0.07  0.02  0.05  0.06  0.22  0.02
#                     32  0.00        12.60  0.09  0.03  6.91  7.63  0.23  0.06
#                         0.01        10.22  0.08  0.03  2.09  1.00  0.22  0.07
#                         0.10         0.20  0.11  0.03  0.06  0.06  0.22  0.04
