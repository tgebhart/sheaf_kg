# %%
import os
import time
import pandas as pd
import numpy as np

# %%
dataset = 'FB15k-237'
savedir = '/home/gebhart/projects/sheaf_kg/data'
filename = 'HolE_1000epochs_128dim_CrossEntropyLossloss_1234seed_20210127-1733'

# %%
df = pd.read_csv(os.path.join(savedir,dataset,filename +'.csv'))

# %%
df
# Out:
#     Unnamed: 0  Side   Type                Metric        Value
# 0            0  both    avg    adjusted_mean_rank     0.178953
# 1            1  head    avg    adjusted_mean_rank     0.278802
# 2            2  tail    avg    adjusted_mean_rank     0.079105
# 3            3  both  worst             mean_rank  1250.046800
# 4            4  both  worst  mean_reciprocal_rank     0.166755
# 5            5  both  worst             hits_at_1     0.113587
# 6            6  both  worst             hits_at_3     0.181427
# 7            7  both  worst             hits_at_5     0.220031
# 8            8  both  worst            hits_at_10     0.273461
# 9            9  both    avg             mean_rank  1250.046617
# 10          10  both    avg  mean_reciprocal_rank     0.166755
# 11          11  both    avg             hits_at_1     0.113587
# 12          12  both    avg             hits_at_3     0.181427
# 13          13  both    avg             hits_at_5     0.220031
# ...
