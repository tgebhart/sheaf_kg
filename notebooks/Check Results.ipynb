# %%
import os
import time
import pandas as pd
import numpy as np

# %%
dataset = 'FB15k-237'
savedir = '/home/gebhart/projects/sheaf_kg/data'
filename = 'HolE_1000epochs_64dim_SoftplusLossloss_1234seed_20210126-1646'

# %%
df = pd.read_csv(os.path.join(savedir,dataset,filename +'.csv'))

# %%
df
# Out:
#     Unnamed: 0  Side   Type                Metric       Value
# 0            0  tail    avg    adjusted_mean_rank    0.047820
# 1            1  both    avg    adjusted_mean_rank    0.063760
# 2            2  head    avg    adjusted_mean_rank    0.079700
# 3            3  tail   best             mean_rank  345.772678
# 4            4  tail   best  mean_reciprocal_rank    0.163561
# 5            5  tail   best             hits_at_1    0.083423
# 6            6  tail   best             hits_at_3    0.184607
# 7            7  tail   best             hits_at_5    0.241609
# 8            8  tail   best            hits_at_10    0.324591
# 9            9  tail    avg             mean_rank  345.772678
# 10          10  tail    avg  mean_reciprocal_rank    0.163561
# 11          11  tail    avg             hits_at_1    0.083423
# 12          12  tail    avg             hits_at_3    0.184607
# 13          13  tail    avg             hits_at_5    0.241609
# 14          14  tail    avg            hits_at_10    0.324591
# 15          15  tail  worst             mean_rank  345.772678
# 16          16  tail  worst  mean_reciprocal_rank    0.163561
# 17          17  tail  worst             hits_at_1    0.083423
# 18          18  tail  worst             hits_at_3    0.184607
# 19          19  tail  worst             hits_at_5    0.241609
# 20          20  tail  worst            hits_at_10    0.324591
# 21          21  both   best             mean_rank  442.423623
# 22          22  both   best  mean_reciprocal_rank    0.116642
# 23          23  both   best             hits_at_1    0.054775
# 24          24  both   best             hits_at_3    0.125281
# 25          25  both   best             hits_at_5    0.168069
# 26          26  both   best            hits_at_10    0.239162
# 27          27  both    avg             mean_rank  442.423647
# 28          28  both    avg  mean_reciprocal_rank    0.116642
# 29          29  both    avg             hits_at_1    0.054775
# 30          30  both    avg             hits_at_3    0.125281
# 31          31  both    avg             hits_at_5    0.168069
# 32          32  both    avg            hits_at_10    0.239162
# 33          33  both  worst             mean_rank  442.423672
# 34          34  both  worst  mean_reciprocal_rank    0.116642
# 35          35  both  worst             hits_at_1    0.054775
# 36          36  both  worst             hits_at_3    0.125281
# 37          37  both  worst             hits_at_5    0.168069
# 38          38  both  worst            hits_at_10    0.239162
# 39          39  head   best             mean_rank  539.074567
# 40          40  head   best  mean_reciprocal_rank    0.069724
# 41          41  head   best             hits_at_1    0.026128
# 42          42  head   best             hits_at_3    0.065956
# 43          43  head   best             hits_at_5    0.094530
# 44          44  head   best            hits_at_10    0.153733
# 45          45  head    avg             mean_rank  539.074616
# 46          46  head    avg  mean_reciprocal_rank    0.069724
# 47          47  head    avg             hits_at_1    0.026128
# 48          48  head    avg             hits_at_3    0.065956
# 49          49  head    avg             hits_at_5    0.094530
# 50          50  head    avg            hits_at_10    0.153733
# 51          51  head  worst             mean_rank  539.074665
# 52          52  head  worst  mean_reciprocal_rank    0.069724
# 53          53  head  worst             hits_at_1    0.026128
# 54          54  head  worst             hits_at_3    0.065956
# 55          55  head  worst             hits_at_5    0.094530
# 56          56  head  worst            hits_at_10    0.153733
