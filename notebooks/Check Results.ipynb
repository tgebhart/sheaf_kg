# %%
import os
import time
import pandas as pd
import numpy as np

# %%
dataset = 'WN18RR'
savedir = '/home/gebhart/projects/sheaf_kg/data'
filename = 'TransE_1000epochs_64dim_SoftplusLossloss_1234seed_20210126-1431'

# %%
df = pd.read_csv(os.path.join(savedir,dataset,filename +'.csv'))

# %%
df
# Out:
#     Unnamed: 0  Side   Type                Metric        Value
# 0            0  tail    avg    adjusted_mean_rank     0.141376
# 1            1  head    avg    adjusted_mean_rank     0.185734
# 2            2  both    avg    adjusted_mean_rank     0.163555
# 3            3  tail    avg             mean_rank  2866.035055
# 4            4  tail    avg  mean_reciprocal_rank     0.151351
# 5            5  tail    avg             hits_at_1     0.013338
# 6            6  tail    avg             hits_at_3     0.224008
# 7            7  tail    avg             hits_at_5     0.313611
# 8            8  tail    avg            hits_at_10     0.422025
# 9            9  tail  worst             mean_rank  2866.036936
# 10          10  tail  worst  mean_reciprocal_rank     0.151351
# 11          11  tail  worst             hits_at_1     0.013338
# 12          12  tail  worst             hits_at_3     0.224008
# 13          13  tail  worst             hits_at_5     0.313611
# 14          14  tail  worst            hits_at_10     0.422025
# 15          15  tail   best             mean_rank  2866.033174
# 16          16  tail   best  mean_reciprocal_rank     0.151352
# 17          17  tail   best             hits_at_1     0.013338
# 18          18  tail   best             hits_at_3     0.224008
# 19          19  tail   best             hits_at_5     0.313611
# 20          20  tail   best            hits_at_10     0.422025
# 21          21  head    avg             mean_rank  3764.279583
# 22          22  head    avg  mean_reciprocal_rank     0.144632
# 23          23  head    avg             hits_at_1     0.007524
# 24          24  head    avg             hits_at_3     0.227086
# 25          25  head    avg             hits_at_5     0.313611
# 26          26  head    avg            hits_at_10     0.406293
# 27          27  head  worst             mean_rank  3764.281464
# 28          28  head  worst  mean_reciprocal_rank     0.144632
# 29          29  head  worst             hits_at_1     0.007524
# 30          30  head  worst             hits_at_3     0.227086
# 31          31  head  worst             hits_at_5     0.313611
# 32          32  head  worst            hits_at_10     0.406293
# 33          33  head   best             mean_rank  3764.277702
# 34          34  head   best  mean_reciprocal_rank     0.144632
# 35          35  head   best             hits_at_1     0.007524
# 36          36  head   best             hits_at_3     0.227086
# 37          37  head   best             hits_at_5     0.313611
# 38          38  head   best            hits_at_10     0.406293
# 39          39  both    avg             mean_rank  3315.157319
# 40          40  both    avg  mean_reciprocal_rank     0.147992
# 41          41  both    avg             hits_at_1     0.010431
# 42          42  both    avg             hits_at_3     0.225547
# 43          43  both    avg             hits_at_5     0.313611
# 44          44  both    avg            hits_at_10     0.414159
# 45          45  both  worst             mean_rank  3315.159200
# 46          46  both  worst  mean_reciprocal_rank     0.147992
# 47          47  both  worst             hits_at_1     0.010431
# 48          48  both  worst             hits_at_3     0.225547
# 49          49  both  worst             hits_at_5     0.313611
# 50          50  both  worst            hits_at_10     0.414159
# 51          51  both   best             mean_rank  3315.155438
# 52          52  both   best  mean_reciprocal_rank     0.147992
# 53          53  both   best             hits_at_1     0.010431
# 54          54  both   best             hits_at_3     0.225547
# 55          55  both   best             hits_at_5     0.313611
# 56          56  both   best            hits_at_10     0.414159
