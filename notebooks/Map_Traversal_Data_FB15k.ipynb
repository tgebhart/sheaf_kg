# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
import time

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pykeen
import torch

import json

from pykeen.pipeline import pipeline

# %%
# nltk.download('wordnet')

# %%
dataset = 'FB15k'

# %%
ds = pykeen.datasets.get_dataset(dataset=dataset)

training = ds.training.mapped_triples
testing = ds.testing.mapped_triples
ds.training.relation_id_to_label
# Out:
# {0: '/american_football/football_coach/coaching_history./american_football/football_historical_coach_position/position',
#  1: '/american_football/football_coach/coaching_history./american_football/football_historical_coach_position/team',
#  2: '/american_football/football_coach_position/coaches_holding_this_position./american_football/football_historical_coach_position/coach',
#  3: '/american_football/football_coach_position/coaches_holding_this_position./american_football/football_historical_coach_position/team',
#  4: '/american_football/football_player/current_team./american_football/football_roster_position/position',
#  5: '/american_football/football_player/current_team./american_football/football_roster_position/team',
#  6: '/american_football/football_player/current_team./sports/sports_team_roster/team',
#  7: '/american_football/football_player/former_teams./american_football/football_historical_roster_position/position_s',
#  8: '/american_football/football_player/former_teams./american_football/football_historical_roster_position/team',
#  9: '/american_football/football_player/former_teams./sports/sports_team_roster/position',
#  10: '/american_football/football_player/former_teams./sports/sports_team_roster/team',
#  11: '/american_football/football_player/games./american_football/player_game_statistics/season',
#  12: '/american_football/football_player/games./american_football/player_game_statistics/team',
#  13: '/american_football/football_player/passing./american_football/player_passing_statistics/season',
#  14: '/american_football/football_player/passing./american_football/player_passing_statistics/team',
#  15: '/american_football/football_player/position_s',
#  16: '/american_football/football_player/receiving./american_football/player_receiving_statistics/season',
#  17: '/american_football/football_player/receiving./american_football/player_receiving_statistics/team',
#  18: '/american_football/football_player/rushing./american_football/player_rushing_statistics/season',
#  19: '/american_football/football_player/rushing./american_football/player_rushing_statistics/team',
#  20: '/american_football/football_position/players',
#  21: '/american_football/football_team/current_roster./american_football/football_roster_position/player',
#  22: '/american_football/football_team/current_roster./american_football/football_roster_position/position',
#  23: '/american_football/football_team/current_roster./sports/sports_team_roster/player',
#  24: '/american_football/football_team/current_roster./sports/sports_team_roster/position',
#  25: '/american_football/football_team/historical_coaching_staff./american_football/football_historical_coach_position/coach',
#  26: '/american_football/football_team/historical_coaching_staff./american_football/football_historical_coach_position/position',
#  27: '/american_football/football_team/historical_roster./american_football/football_historical_roster_position/player',
#  28: '/american_football/football_team/historical_roster./american_football/football_historical_roster_position/position_s',
#  29: '/american_football/football_team/historical_roster./sports/sports_team_roster/player',
#  30: '/american_football/football_team/historical_roster./sports/sports_team_roster/position',
#  31: '/architecture/architect/architectural_style',
#  32: '/architecture/architect/structures_designed',
#  33: '/architecture/architectural_structure_owner/structures_owned./architecture/ownership/structure',
#  34: '/architecture/architectural_style/architects',
#  35: '/architecture/architectural_style/examples',
#  36: '/architecture/building/building_function',
#  37: '/architecture/building_function/buildings',
#  38: '/architecture/museum/address./location/mailing_address/citytown',
#  39: '/architecture/museum/address./location/mailing_address/state_province_region',
#  40: '/architecture/museum/type_of_museum',
#  41: '/architecture/structure/address./location/mailing_address/citytown',
#  42: '/architecture/structure/address./location/mailing_address/state_province_region',
#  43: '/architecture/structure/architect',
#  44: '/architecture/structure/architectural_style',
#  45: '/architecture/structure/construction_cost./measurement_unit/money_value/currency',
#  46: '/architecture/structure/owner./architecture/ownership/owner',
#  47: '/architecture/type_of_museum/museums',
#  48: '/astronomy/celestial_object/category',
#  49: '/astronomy/celestial_object_category/objects',
#  50: '/astronomy/orbital_relationship/orbited_by',
#  51: '/astronomy/orbital_relationship/orbits',
#  52: '/astronomy/star_system/planetary_system',
#  53: '/astronomy/star_system_body/star_system',
#  54: '/aviation/aircraft_manufacturer/aircraft_models_made',
#  55: '/aviation/aircraft_model/aircraft_type',
#  56: '/aviation/aircraft_model/number_owned_by./aviation/aircraft_ownership_count/aircraft_owner',
#  57: '/aviation/aircraft_owner/aircraft_fleet_composition./aviation/aircraft_ownership_count/aircraft_model',
#  58: '/aviation/aircraft_type/aircraft_of_this_type',
#  59: '/aviation/airline/airports_served./aviation/airline_airport_presence/airport',
#  60: '/aviation/airline/airports_served./aviation/airline_airport_presence/cities_served',
#  61: '/aviation/airline/alliance',
#  62: '/aviation/airline/focus_cities',
#  63: '/aviation/airline/hubs',
#  64: '/aviation/airline_alliance/member_airlines',
#  65: '/aviation/airliner_accident/flight_destination',
#  66: '/aviation/airport/airlines./aviation/airline_airport_presence/airline',
#  67: '/aviation/airport/airlines./aviation/airline_airport_presence/cities_served',
#  68: '/aviation/airport/focus_city_for',
#  69: '/aviation/airport/hub_for',
#  70: '/aviation/airport/serves',
#  71: '/award/award/category',
#  72: '/award/award/presented_by',
#  73: '/award/award_category/category_of',
#  74: '/award/award_category/disciplines_or_subjects',
#  75: '/award/award_category/long_lists./award/long_list_nomination/nominee',
#  76: '/award/award_category/nominees./award/award_nomination/award_nominee',
#  77: '/award/award_category/nominees./award/award_nomination/nominated_for',
#  78: '/award/award_category/presenting_organization',
#  79: '/award/award_category/winners./award/award_honor/award_winner',
#  80: '/award/award_category/winners./award/award_honor/ceremony',
#  81: '/award/award_category/winners./award/award_honor/honored_for',
#  82: '/award/award_ceremony/awards_presented./award/award_honor/award',
#  83: '/award/award_ceremony/awards_presented./award/award_honor/award_winner',
#  84: '/award/award_ceremony/awards_presented./award/award_honor/honored_for',
#  85: '/award/award_discipline/awards_in_this_discipline',
#  86: '/award/award_nominated_work/award_nominations./award/award_nomination/award',
#  87: '/award/award_nominated_work/award_nominations./award/award_nomination/award_nominee',
#  88: '/award/award_nominated_work/award_nominations./award/award_nomination/nominated_for',
#  89: '/award/award_nominee/award_nominations./award/award_nomination/award',
#  90: '/award/award_nominee/award_nominations./award/award_nomination/award_nominee',
#  91: '/award/award_nominee/award_nominations./award/award_nomination/nominated_for',
#  92: '/award/award_presenting_organization/award_categories_presented',
#  93: '/award/award_presenting_organization/awards_presented',
#  94: '/award/award_winner/awards_won./award/award_honor/award',
#  95: '/award/award_winner/awards_won./award/award_honor/award_winner',
#  96: '/award/award_winner/awards_won./award/award_honor/ceremony',
#  97: '/award/award_winner/awards_won./award/award_honor/honored_for',
#  98: '/award/award_winning_work/awards_won./award/award_honor/award',
#  99: '/award/award_winning_work/awards_won./award/award_honor/award_winner',
#  100: '/award/award_winning_work/awards_won./award/award_honor/ceremony',
#  101: '/award/award_winning_work/awards_won./award/award_honor/honored_for',
#  102: '/award/competition/instance_of_recurring_competition',
#  103: '/award/hall_of_fame/discipline',
#  104: '/award/hall_of_fame/inductees./award/hall_of_fame_induction/inductee',
#  105: '/award/hall_of_fame_discipline/halls_of_fame',
#  106: '/award/hall_of_fame_inductee/hall_of_fame_inductions./award/hall_of_fame_induction/category',
#  107: '/award/hall_of_fame_inductee/hall_of_fame_inductions./award/hall_of_fame_induction/hall_of_fame',
#  108: '/award/hall_of_fame_induction_category/inductees./award/hall_of_fame_induction/inductee',
#  109: '/award/long_list_nominee/long_list_nominations./award/long_list_nomination/award',
#  110: '/award/ranked_item/appears_in_ranked_lists./award/ranking/list',
#  111: '/award/ranked_list/ranked_list_items./award/ranking/item',
#  112: '/award/recurring_competition/individual_competitions',
#  113: '/base/aareas/schema/administrative_area/administrative_area_type',
#  114: '/base/aareas/schema/administrative_area/administrative_children',
#  115: '/base/aareas/schema/administrative_area/administrative_parent',
#  116: '/base/aareas/schema/administrative_area/capital',
#  117: '/base/academyawards/host_of_oscar_show/oscar_show_hosted',
#  118: '/base/activism/activism_issue/activist_organizations',
#  119: '/base/activism/activism_issue/activists',
#  120: '/base/activism/activist/area_of_activism',
#  121: '/base/activism/organization/area_of_activism',
#  122: '/base/americancomedy/celebrity_impressionist/celebrities_impersonated',
#  123: '/base/americancomedy/comedian/comedy_genres',
#  124: '/base/americancomedy/comedy_genre/comedians_in_this_genre',
#  125: '/base/americancomedy/comedy_group/members./base/americancomedy/comedy_group_membership/member',
#  126: '/base/americancomedy/comedy_group_member/belongs_to./base/americancomedy/comedy_group_membership/group',
#  127: '/base/americancomedy/impersonated_celebrity/impersonated_by',
#  128: '/base/argumentmaps/abstract_moral_dispute/particular_instances',
#  129: '/base/argumentmaps/innovator/original_ideas',
#  130: '/base/argumentmaps/morally_disputed_activity/instance_of_abstract_moral_dispute',
#  131: '/base/argumentmaps/original_idea/innovator',
#  132: '/base/biblioness/bibs_location/city',
#  133: '/base/biblioness/bibs_location/country',
#  134: '/base/biblioness/bibs_location/state',
#  135: '/base/bioventurist/bv_medical_condition/company_involved',
#  136: '/base/bioventurist/science_or_technology_company/develops_treatments_for_disease',
#  137: '/base/collectives/collective/members./base/collectives/collective_membership/member',
#  138: '/base/collectives/collective_member/member_of./base/collectives/collective_membership/collective',
#  139: '/base/contractbridge/bridge_player/first_place_finish./base/contractbridge/bridge_tournament_standings/first_place',
#  140: '/base/contractbridge/bridge_player/first_place_finish./base/contractbridge/bridge_tournament_standings/second_place',
#  141: '/base/contractbridge/bridge_player/first_place_finish./base/contractbridge/bridge_tournament_standings/tournament',
#  142: '/base/contractbridge/bridge_player/second_place_finish./base/contractbridge/bridge_tournament_standings/first_place',
#  143: '/base/contractbridge/bridge_player/second_place_finish./base/contractbridge/bridge_tournament_standings/second_place',
#  144: '/base/contractbridge/bridge_player/second_place_finish./base/contractbridge/bridge_tournament_standings/tournament',
#  145: '/base/contractbridge/bridge_player/teammates./base/contractbridge/bridge_player_teammates/teammate',
#  146: '/base/contractbridge/bridge_tournament/standing./base/contractbridge/bridge_tournament_standings/first_place',
#  147: '/base/contractbridge/bridge_tournament/standing./base/contractbridge/bridge_tournament_standings/second_place',
#  148: '/base/crime/convicted_criminal/convictions./base/crime/criminal_conviction/guilty_of',
#  149: '/base/crime/convicted_criminal/convictions./base/crime/criminal_conviction/sentence_type',
#  150: '/base/crime/crime/victim_s',
#  151: '/base/crime/crime_victim/crime',
#  152: '/base/crime/crime_victim/crime_type',
#  153: '/base/culturalevent/event/entity_involved',
#  154: '/base/disaster2/tactic/attacks_of_this_form./base/disaster2/attack_process/attack_event',
#  155: '/base/eating/diets/people_who_follow_this_diet',
#  156: '/base/eating/practicer_of_diet/diet',
#  157: '/base/ecology/ecosystem/ecosystem_members',
#  158: '/base/ecology/food_web_member/belongs_to_ecosystem_s',
#  159: '/base/endorsements/endorsee/newspaper_endorsements./base/endorsements/newspaper_endorsement/newspaper',
#  160: '/base/endorsements/endorsing_newspaper/endorsements./base/endorsements/newspaper_endorsement/election',
#  161: '/base/endorsements/endorsing_newspaper/endorsements./base/endorsements/newspaper_endorsement/endorsee',
#  162: '/base/events/festival_series/type_of_festival',
#  163: '/base/events/performer/performances./base/events/performance/performer',
#  164: '/base/events/type_of_festival/recurring_festivals_of_this_type',
#  165: '/base/famouspets/pet_owner/pets_owned./base/famouspets/pet_ownership/owner',
#  166: '/base/fashionmodels/fashion_model/hair_color',
#  167: '/base/fashionmodels/hair_color/fashion_models_with_this_hair_color',
#  168: '/base/fight/crime_type/included_in_crimes',
#  169: '/base/fight/crime_type/includes_crimes',
#  170: '/base/fight/crime_type/people_convicted_of_this_crime./base/crime/criminal_conviction/convicted_person',
#  171: '/base/fight/crime_type/people_convicted_of_this_crime./base/crime/criminal_conviction/guilty_of',
#  172: '/base/fight/crime_type/victims_of_this_crime_type',
#  173: '/base/fight/sentence/convictions./base/crime/criminal_conviction/convicted_person',
#  174: '/base/fight/sports_official/sport',
#  175: '/base/folklore/mythical_creature/mythology',
#  176: '/base/folklore/mythology/mythical_creatures',
#  177: '/base/infrastructure/power_plant_type/power_station',
#  178: '/base/infrastructure/power_station/fuel_type',
#  179: '/base/localfood/food_producing_region/seasonal_availability./base/localfood/produce_availability/produce',
#  180: '/base/localfood/produce/availability./base/localfood/produce_availability/location',
#  181: '/base/localfood/produce/availability./base/localfood/produce_availability/seasonal_months',
#  182: '/base/localfood/seasonal_month/produce_available./base/localfood/produce_availability/produce',
#  183: '/base/localfood/seasonal_month/produce_available./base/localfood/produce_availability/seasonal_months',
#  184: '/base/locations/continents/countries_within',
#  185: '/base/locations/countries/continent',
#  186: '/base/marchmadness/ncaa_basketball_team/ncaa_tournament_seeds./base/marchmadness/ncaa_tournament_seed/tournament',
#  187: '/base/marchmadness/ncaa_basketball_tournament/seeds./base/marchmadness/ncaa_tournament_seed/team',
#  188: '/base/newsevents/news_reported_event/news_report_s./base/newsevents/news_report/news_reporting_organisation',
#  189: '/base/newsevents/news_reporting_organisation/news_reports./base/newsevents/news_report/event',
#  190: '/base/nobelprizes/nobel_prize_winner/nobel_honor./base/nobelprizes/nobel_honor/subject_area',
#  191: '/base/nobelprizes/nobel_subject_area/nobel_awards./base/nobelprizes/nobel_honor/nobel_prize_winner',
#  192: '/base/nobelprizes/nobel_subject_area/nobel_awards./base/nobelprizes/nobel_honor/subject_area',
#  193: '/base/onephylogeny/type_of_thing/included_in',
#  194: '/base/onephylogeny/type_of_thing/includes',
#  195: '/base/onephylogeny/type_of_thing/things_of_this_type',
#  196: '/base/parody/parodied_subject/parodies',
#  197: '/base/parody/parody/parody_of',
#  198: '/base/patronage/client/related_patron./base/patronage/patron_client_relationship/patron',
#  199: '/base/patronage/patron/related_client./base/patronage/patron_client_relationship/client',
#  200: '/base/petbreeds/city_with_dogs/top_breeds./base/petbreeds/dog_city_relationship/dog_breed',
#  201: '/base/petbreeds/dog_breed/cities_where_this_dog_is_popular./base/petbreeds/dog_city_relationship/cities',
#  202: '/base/petbreeds/dog_breed/color',
#  203: '/base/petbreeds/dog_breed/group',
#  204: '/base/petbreeds/dog_breed/size./base/petbreeds/dog_size/gender',
#  205: '/base/petbreeds/dog_breed_group/dog_breeds',
#  206: '/base/petbreeds/dog_coat_color/dog_breeds',
#  207: '/base/popstra/business_location/customer./base/popstra/hangout/customer',
#  208: '/base/popstra/celebrity/bought./base/popstra/product_choice/product',
#  209: '/base/popstra/celebrity/breakup./base/popstra/breakup/participant',
#  210: '/base/popstra/celebrity/canoodled./base/popstra/canoodled/participant',
#  211: '/base/popstra/celebrity/dated./base/popstra/dated/participant',
#  212: '/base/popstra/celebrity/eats_at./base/popstra/restaurant_choice/restaurant',
#  213: '/base/popstra/celebrity/endorsements./base/popstra/paid_support/company',
#  214: '/base/popstra/celebrity/friendship./base/popstra/friendship/participant',
#  215: '/base/popstra/celebrity/hangout./base/popstra/hangout/business_location',
#  216: '/base/popstra/celebrity/lived_with./base/popstra/lived_with/participant',
#  217: '/base/popstra/celebrity/religion./base/popstra/religion_choice/religion',
#  218: '/base/popstra/celebrity/shops_at./base/popstra/shopping_choice/company',
#  219: '/base/popstra/celebrity/supporter./base/popstra/support/supported_organization',
#  220: '/base/popstra/celebrity/vacations_in./base/popstra/vacation_choice/location',
#  221: '/base/popstra/celebrity/wears./base/popstra/fashion_choice/designer',
#  222: '/base/popstra/company/fashion_choice./base/popstra/fashion_choice/fashion_wearer',
#  223: '/base/popstra/company/product_endorser./base/popstra/paid_support/endorser',
#  224: '/base/popstra/company/shopping_choice./base/popstra/shopping_choice/shopper',
#  225: '/base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer',
#  226: '/base/popstra/organization/supporter./base/popstra/support/supporter',
#  227: '/base/popstra/product/sold_to./base/popstra/product_choice/consumer',
#  228: '/base/popstra/religion/membership./base/popstra/religion_choice/member',
#  229: '/base/popstra/restaurant/restaurant_choice./base/popstra/restaurant_choice/diner',
#  230: '/base/rugby/rugby_player/type_of_rugby',
#  231: '/base/saints/saint/venerated_in',
#  232: '/base/saturdaynightlive/snl_cast_member/seasons./base/saturdaynightlive/snl_season_tenure/cast_members',
#  233: '/base/schemastaging/athlete_extra/salary./base/schemastaging/athlete_salary/currency',
#  234: '/base/schemastaging/athlete_extra/salary./base/schemastaging/athlete_salary/team',
#  235: '/base/schemastaging/fish/found_in',
#  236: '/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_open_times/time_zone',
#  237: '/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/contact_category',
#  238: '/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/product_or_service',
#  239: '/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_language',
#  240: '/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location',
#  241: '/base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency',
#  242: '/base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/source',
#  243: '/base/schemastaging/tv_actor_extra/regular_dubbing_performances./base/schemastaging/tv_star_dubbing_performance/character',
#  244: '/base/schemastaging/tv_actor_extra/regular_dubbing_performances./base/schemastaging/tv_star_dubbing_performance/language',
#  245: '/base/schemastaging/tv_actor_extra/regular_dubbing_performances./base/schemastaging/tv_star_dubbing_performance/program',
#  246: '/base/schemastaging/tv_character_extra/regular_dubbing_performances./base/schemastaging/tv_star_dubbing_performance/actor',
#  247: '/base/schemastaging/tv_character_extra/regular_dubbing_performances./base/schemastaging/tv_star_dubbing_performance/language',
#  248: '/base/schemastaging/tv_character_extra/regular_dubbing_performances./base/schemastaging/tv_star_dubbing_performance/program',
#  249: '/base/schemastaging/tv_program_extra/regular_dubbing_performances./base/schemastaging/tv_star_dubbing_performance/actor',
#  250: '/base/schemastaging/tv_program_extra/regular_dubbing_performances./base/schemastaging/tv_star_dubbing_performance/character',
#  251: '/base/schemastaging/tv_program_extra/regular_dubbing_performances./base/schemastaging/tv_star_dubbing_performance/language',
#  252: '/base/thoroughbredracing/thoroughbred_racehorse/color',
#  253: '/base/thoroughbredracing/thoroughbred_racehorse/country',
#  254: '/base/thoroughbredracing/thoroughbred_racehorse/sex',
#  255: '/base/thoroughbredracing/thoroughbred_racehorse_color/horses_of_this_color',
#  256: '/base/thoroughbredracing/thoroughbred_racehorse_origin/horses_from_this_location',
#  257: '/base/thoroughbredracing/thoroughbred_racehorse_sex/horses_of_this_sex',
#  258: '/base/twinnedtowns/twinned_town/twinned_with./base/twinnedtowns/town_twinning/twinned_towns',
#  259: '/base/usnationalparks/us_national_park/state',
#  260: '/base/wrestling/professional_wrestler/member_of_team',
#  261: '/base/wrestling/solo_wrestler_or_team/members',
#  262: '/base/x2010fifaworldcupsouthafrica/world_cup_participant/world_cup_team./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/current_club',
#  263: '/base/x2010fifaworldcupsouthafrica/world_cup_participant/world_cup_team./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/national_team',
#  264: '/base/x2010fifaworldcupsouthafrica/world_cup_participant/world_cup_team./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/position',
#  265: '/base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/current_club',
#  266: '/base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/players',
#  267: '/base/x2010fifaworldcupsouthafrica/world_cup_squad/current_world_cup_squad./base/x2010fifaworldcupsouthafrica/current_world_cup_squad/position',
#  268: '/base/yalebase/secret_society/notable_members./base/yalebase/secret_society_membership/member',
#  269: '/base/yalebase/secret_society_member/belonged_to./base/yalebase/secret_society_membership/society',
#  270: '/baseball/baseball_league/teams',
#  271: '/baseball/baseball_player/batting_stats./baseball/batting_statistics/season',
#  272: '/baseball/baseball_player/batting_stats./baseball/batting_statistics/team',
#  273: '/baseball/baseball_player/current_team./baseball/baseball_roster_position/position',
#  274: '/baseball/baseball_player/current_team./baseball/baseball_roster_position/team',
#  275: '/baseball/baseball_player/current_team./sports/sports_team_roster/position',
#  276: '/baseball/baseball_player/current_team./sports/sports_team_roster/team',
#  277: '/baseball/baseball_player/former_teams./baseball/baseball_historical_roster_position/team',
#  278: '/baseball/baseball_player/former_teams./sports/sports_team_roster/team',
#  279: '/baseball/baseball_player/lifetime_batting_statistics./baseball/lifetime_batting_statistics/ending_season',
#  280: '/baseball/baseball_player/lifetime_batting_statistics./baseball/lifetime_batting_statistics/last_statistics_season',
#  281: '/baseball/baseball_player/lifetime_batting_statistics./baseball/lifetime_batting_statistics/starting_season',
#  282: '/baseball/baseball_player/position_s',
#  283: '/baseball/baseball_position/players',
#  284: '/baseball/baseball_team/current_roster./baseball/baseball_roster_position/player',
#  285: '/baseball/baseball_team/current_roster./baseball/baseball_roster_position/position',
#  286: '/baseball/baseball_team/current_roster./sports/sports_team_roster/player',
#  287: '/baseball/baseball_team/current_roster./sports/sports_team_roster/position',
#  288: '/baseball/baseball_team/historical_roster./baseball/baseball_historical_roster_position/player',
#  289: '/baseball/baseball_team/historical_roster./sports/sports_team_roster/player',
#  290: '/baseball/baseball_team/league',
#  291: '/baseball/baseball_team/team_stats./baseball/baseball_team_stats/season',
#  292: '/basketball/basketball_player/former_teams./basketball/basketball_historical_roster_position/team',
#  293: '/basketball/basketball_player/former_teams./sports/sports_team_roster/team',
#  294: '/basketball/basketball_player/player_statistics./basketball/basketball_player_stats/team',
#  295: '/basketball/basketball_player/position_s',
#  296: '/basketball/basketball_player/team./basketball/basketball_roster_position/position',
#  297: '/basketball/basketball_player/team./basketball/basketball_roster_position/team',
#  298: '/basketball/basketball_player/team./sports/sports_team_roster/position',
#  299: '/basketball/basketball_player/team./sports/sports_team_roster/team',
#  300: '/basketball/basketball_position/player_roster_position./basketball/basketball_roster_position/player',
#  301: '/basketball/basketball_position/player_roster_position./basketball/basketball_roster_position/team',
#  302: '/basketball/basketball_position/player_roster_position./sports/sports_team_roster/player',
#  303: '/basketball/basketball_position/player_roster_position./sports/sports_team_roster/team',
#  304: '/basketball/basketball_position/players',
#  305: '/basketball/basketball_team/historical_roster./basketball/basketball_historical_roster_position/player',
#  306: '/basketball/basketball_team/historical_roster./sports/sports_team_roster/player',
#  307: '/basketball/basketball_team/roster./basketball/basketball_roster_position/player',
#  308: '/basketball/basketball_team/roster./basketball/basketball_roster_position/position',
#  309: '/basketball/basketball_team/roster./sports/sports_team_roster/player',
#  310: '/basketball/basketball_team/roster./sports/sports_team_roster/position',
#  311: '/biology/animal_breed/breed_of',
#  312: '/biology/animal_breed/place_of_origin',
#  313: '/biology/animal_breed/registered_with./biology/breed_registration/breed_group',
#  314: '/biology/animal_breed/registered_with./biology/breed_registration/registry',
#  315: '/biology/breed_group/breeds_in_this_group./biology/breed_registration/breed',
#  316: '/biology/breed_origin/breeds_originating_here',
#  317: '/biology/breed_registry/recognized_breeds./biology/breed_registration/breed',
#  318: '/biology/domesticated_animal/breeds',
#  319: '/biology/organism/organism_type',
#  320: '/biology/organism/sex',
#  321: '/biology/organism_classification/higher_classification',
#  322: '/biology/organism_classification/lower_classifications',
#  323: '/biology/organism_classification/organisms_of_this_type',
#  324: '/biology/organism_classification/rank',
#  325: '/biology/organism_classification_rank/organism_classifications',
#  326: '/book/author/school_or_movement',
#  327: '/book/author/series_written_or_contributed_to',
#  328: '/book/author/works_written',
#  329: '/book/book/genre',
#  330: '/book/book_subject/works',
#  331: '/book/literary_series/author_s',
#  332: '/book/magazine/genre',
#  333: '/book/magazine_genre/magazines_in_this_genre',
#  334: '/book/newspaper/circulation_areas',
#  335: '/book/newspaper/headquarters./location/mailing_address/citytown',
#  336: '/book/newspaper/headquarters./location/mailing_address/state_province_region',
#  337: '/book/newspaper/owner',
#  338: '/book/newspaper_owner/newspapers_owned',
#  339: '/book/periodical/publisher./book/periodical_publisher_period/publisher',
#  340: '/book/periodical/subjects',
#  341: '/book/periodical_format/periodicals_in_this_format./book/periodical_format_period/periodical',
#  342: '/book/periodical_publisher/periodicals_published./book/periodical_publisher_period/periodical',
#  343: '/book/periodical_subject/periodicals',
#  344: '/book/school_or_movement/associated_authors',
#  345: '/book/written_work/author',
#  346: '/book/written_work/original_language',
#  347: '/book/written_work/subjects',
#  348: '/broadcast/artist/content',
#  349: '/broadcast/broadcast/area_served',
#  350: '/broadcast/broadcast/content',
#  351: '/broadcast/broadcast/distributor',
#  352: '/broadcast/content/artist',
#  353: '/broadcast/content/broadcast',
#  354: '/broadcast/content/genre',
#  355: '/broadcast/content/language',
#  356: '/broadcast/content/location',
#  357: '/broadcast/content/producer',
#  358: '/broadcast/distributor/distributes',
#  359: '/broadcast/genre/content',
#  360: '/broadcast/producer/produces',
#  361: '/broadcast/radio_format/stations',
#  362: '/broadcast/radio_station/format',
#  363: '/broadcast/radio_station/owner',
#  364: '/broadcast/radio_station_owner/radio_stations',
#  365: '/broadcast/tv_station/owner',
#  366: '/broadcast/tv_station_owner/tv_stations',
#  367: '/business/asset/owners./business/asset_ownership/owner',
#  368: '/business/asset_owner/assets_owned./business/asset_ownership/owned_asset',
#  369: '/business/board_member/leader_of./organization/leadership/organization',
#  370: '/business/board_member/leader_of./organization/leadership/role',
#  371: '/business/board_member/organization_board_memberships./organization/organization_board_membership/organization',
#  372: '/business/board_member/organization_board_memberships./organization/organization_board_membership/role',
#  373: '/business/brand/owner_s./business/company_brand_relationship/company',
#  374: '/business/business_operation/assets./measurement_unit/dated_money_value/currency',
#  375: '/business/business_operation/cash./measurement_unit/dated_money_value/currency',
#  376: '/business/business_operation/current_assets./measurement_unit/dated_money_value/currency',
#  377: '/business/business_operation/current_liabilities./measurement_unit/dated_money_value/currency',
#  378: '/business/business_operation/industry',
#  379: '/business/business_operation/liabilities./measurement_unit/dated_money_value/currency',
#  380: '/business/business_operation/net_profit./measurement_unit/dated_money_value/currency',
#  381: '/business/business_operation/operating_income./measurement_unit/dated_money_value/currency',
#  382: '/business/business_operation/retained_earnings./measurement_unit/dated_money_value/currency',
#  383: '/business/business_operation/revenue./measurement_unit/dated_money_value/currency',
#  384: '/business/company_type/companies_of_this_type',
#  385: '/business/consumer_company/brands./business/company_brand_relationship/brand',
#  386: '/business/consumer_company/products./business/company_product_relationship/consumer_product',
#  387: '/business/consumer_product/company./business/company_product_relationship/company',
#  388: '/business/employer/employees./business/employment_tenure/person',
#  389: '/business/employer/employees./business/employment_tenure/title',
#  390: '/business/industry/companies',
#  391: '/business/job_title/people_with_this_title./business/employment_tenure/company',
#  392: '/business/job_title/people_with_this_title./business/employment_tenure/person',
#  393: '/business/sponsor/sponsorship./business/sponsorship/sponsored_recipient',
#  394: '/business/sponsored_recipient/sponsorship./business/sponsorship/sponsored_by',
#  395: '/celebrities/celebrity/celebrity_friends./celebrities/friendship/friend',
#  396: '/celebrities/celebrity/sexual_orientation./celebrities/sexual_orientation_phase/sexual_orientation',
#  397: '/celebrities/celebrity/sexual_relationships./celebrities/romantic_relationship/celebrity',
#  398: '/celebrities/sexual_orientation/celebrities./celebrities/sexual_orientation_phase/celebrity',
#  399: '/chemistry/chemical_compound/solubility./chemistry/solubility_relationship/solvent',
#  400: '/comic_books/comic_book_character/created_by',
#  401: '/comic_books/comic_book_character/primary_universe',
#  402: '/comic_books/comic_book_character/regular_featured_appearances',
#  403: '/comic_books/comic_book_creator/characters_created',
#  404: '/comic_books/comic_book_creator/series_created',
#  405: '/comic_books/comic_book_fictional_universe/characters_primarily_appearing_in_this_universe',
#  406: '/comic_books/comic_book_publisher/comic_book_series_published',
#  407: '/comic_books/comic_book_series/created_by',
#  408: '/comic_books/comic_book_series/featured_characters',
#  409: '/comic_books/comic_book_series/publisher',
#  410: '/common/annotation_category/annotations',
#  411: '/common/annotation_category/annotations./common/webpage/topic',
#  412: '/common/resource/annotations./common/webpage/category',
#  413: '/common/resource/annotations./common/webpage/topic',
#  414: '/common/topic/subject_of',
#  415: '/common/topic/subjects',
#  416: '/common/topic/webpage./common/webpage/category',
#  417: '/common/topic/webpage./common/webpage/resource',
#  418: '/common/topic/webpage./common/webpage/topic',
#  419: '/common/webpage/category',
#  420: '/common/webpage/topic',
#  421: '/computer/computer/compatible_oses./computer/os_compatibility/operating_system',
#  422: '/computer/computer/manufacturer',
#  423: '/computer/computer_manufacturer_brand/computer_models',
#  424: '/computer/operating_system/developer',
#  425: '/computer/operating_system/includes_os_versions',
#  426: '/computer/operating_system/parent_os',
#  427: '/computer/operating_system_developer/operating_systems_developed',
#  428: '/computer/programming_language/dialects',
#  429: '/computer/programming_language/influenced',
#  430: '/computer/programming_language/influenced_by',
#  431: '/computer/programming_language/language_designers',
#  432: '/computer/programming_language/language_paradigms',
#  433: '/computer/programming_language/parent_language',
#  434: '/computer/programming_language_designer/languages_designed',
#  435: '/computer/programming_language_paradigm/languages',
#  436: '/computer/software/compatible_oses./computer/software_compatibility/operating_system',
#  437: '/computer/software/developer',
#  438: '/computer/software/languages_used',
#  439: '/computer/software/license',
#  440: '/computer/software/software_genre',
#  441: '/computer/software_developer/software',
#  442: '/computer/software_genre/software_in_genre',
#  443: '/cvg/computer_game_subject/games',
#  444: '/cvg/computer_videogame/characters./cvg/game_performance/character',
#  445: '/cvg/computer_videogame/characters./cvg/game_performance/voice_actor',
#  446: '/cvg/computer_videogame/cvg_genre',
#  447: '/cvg/computer_videogame/designers',
#  448: '/cvg/computer_videogame/developer',
#  449: '/cvg/computer_videogame/game_series',
#  450: '/cvg/computer_videogame/gameplay_modes',
#  451: '/cvg/computer_videogame/prequel',
#  452: '/cvg/computer_videogame/publisher',
#  453: '/cvg/computer_videogame/sequel',
#  454: '/cvg/computer_videogame/subjects',
#  455: '/cvg/cvg_designer/games_designed',
#  456: '/cvg/cvg_developer/games_developed',
#  457: '/cvg/cvg_genre/games',
#  458: '/cvg/cvg_publisher/games_published',
#  459: '/cvg/game_character/games./cvg/game_performance/game',
#  460: '/cvg/game_character/games./cvg/game_performance/voice_actor',
#  461: '/cvg/game_series/games_in_series',
#  462: '/cvg/game_voice_actor/computer_game_voice_performances./cvg/game_performance/character',
#  463: '/cvg/game_voice_actor/computer_game_voice_performances./cvg/game_performance/game',
#  464: '/cvg/gameplay_mode/games_with_this_mode',
#  465: '/dataworld/gardening_hint/split_to',
#  466: '/dining/cuisine/dishes',
#  467: '/dining/cuisine/ingredients',
#  468: '/dining/cuisine/restaurant',
#  469: '/dining/restaurant/cuisine',
#  470: '/education/academic/advisees',
#  471: '/education/academic/advisors',
#  472: '/education/academic/appointments_fellowships_etc./education/academic_post/institution',
#  473: '/education/academic/research_areas',
#  474: '/education/academic_institution/visiting_scholars_fellows_etc./education/academic_post/person',
#  475: '/education/educational_degree/people_with_this_degree./education/education/institution',
#  476: '/education/educational_degree/people_with_this_degree./education/education/major_field_of_study',
#  477: '/education/educational_degree/people_with_this_degree./education/education/minor',
#  478: '/education/educational_degree/people_with_this_degree./education/education/specialization',
#  479: '/education/educational_degree/people_with_this_degree./education/education/student',
#  480: '/education/educational_institution/campuses',
#  481: '/education/educational_institution/colors',
#  482: '/education/educational_institution/mascot',
#  483: '/education/educational_institution/parent_institution',
#  484: '/education/educational_institution/school_type',
#  485: '/education/educational_institution/sexes_accepted./education/gender_enrollment/sex',
#  486: '/education/educational_institution/sports_teams',
#  487: '/education/educational_institution/students_graduates./education/education/degree',
#  488: '/education/educational_institution/students_graduates./education/education/major_field_of_study',
#  489: '/education/educational_institution/students_graduates./education/education/minor',
#  490: '/education/educational_institution/students_graduates./education/education/specialization',
#  491: '/education/educational_institution/students_graduates./education/education/student',
#  492: '/education/educational_institution/subsidiary_or_constituent_schools',
#  493: '/education/educational_institution_campus/educational_institution',
#  494: '/education/field_of_study/academics_in_this_field',
#  495: '/education/field_of_study/students_majoring./education/education/degree',
#  496: '/education/field_of_study/students_majoring./education/education/institution',
#  497: '/education/field_of_study/students_majoring./education/education/major_field_of_study',
#  498: '/education/field_of_study/students_majoring./education/education/minor',
#  499: '/education/field_of_study/students_majoring./education/education/specialization',
#  500: '/education/field_of_study/students_majoring./education/education/student',
#  501: '/education/field_of_study/subdiscipline_of',
#  502: '/education/field_of_study/subdisciplines',
#  503: '/education/fraternity_sorority/colleges_and_universities',
#  504: '/education/fraternity_sorority/colors',
#  505: '/education/fraternity_sorority/founded_location',
#  506: '/education/school/highest_grade_taught',
#  507: '/education/school/lowest_grade_taught',
#  508: '/education/school/school_district',
#  509: '/education/school_category/schools_of_this_kind',
#  510: '/education/school_district/locations_served',
#  511: '/education/school_district/schools',
#  512: '/education/school_mascot/school',
#  513: '/education/university/domestic_tuition./measurement_unit/dated_money_value/currency',
#  514: '/education/university/fraternities_and_sororities',
#  515: '/education/university/international_tuition./measurement_unit/dated_money_value/currency',
#  516: '/education/university/local_tuition./measurement_unit/dated_money_value/currency',
#  517: '/exhibitions/exhibition_sponsor/exhibitions_sponsored./exhibitions/exhibition_run/sponsor',
#  518: '/exhibitions/exhibition_sponsor/exhibitions_sponsored./exhibitions/exhibition_run/venue',
#  519: '/exhibitions/exhibition_venue/exhibitions_at_this_venue./exhibitions/exhibition_run/sponsor',
#  520: '/fictional_universe/character_gender/characters_of_this_gender',
#  521: '/fictional_universe/character_occupation/characters_with_this_occupation',
#  522: '/fictional_universe/character_powers/characters_with_this_ability',
#  523: '/fictional_universe/character_rank/characters_of_this_rank',
#  524: '/fictional_universe/character_species/characters_of_this_species',
#  525: '/fictional_universe/ethnicity_in_fiction/characters_of_this_ethnicity',
#  526: '/fictional_universe/fictional_character/appears_in_these_fictional_universes',
#  527: '/fictional_universe/fictional_character/based_on',
#  528: '/fictional_universe/fictional_character/character_created_by',
#  529: '/fictional_universe/fictional_character/children',
#  530: '/fictional_universe/fictional_character/employers./fictional_universe/fictional_employment_tenure/title',
#  531: '/fictional_universe/fictional_character/ethnicity',
#  532: '/fictional_universe/fictional_character/gender',
#  533: '/fictional_universe/fictional_character/married_to./fictional_universe/marriage_of_fictional_characters/spouses',
#  534: '/fictional_universe/fictional_character/occupation',
#  535: '/fictional_universe/fictional_character/parents',
#  536: '/fictional_universe/fictional_character/place_of_birth',
#  537: '/fictional_universe/fictional_character/powers_or_abilities',
#  538: '/fictional_universe/fictional_character/rank',
#  539: '/fictional_universe/fictional_character/romantically_involved_with./fictional_universe/romantic_involvement/partner',
#  540: '/fictional_universe/fictional_character/siblings./fictional_universe/sibling_relationship_of_fictional_characters/siblings',
#  541: '/fictional_universe/fictional_character/species',
#  542: '/fictional_universe/fictional_character_creator/fictional_characters_created',
#  543: '/fictional_universe/fictional_job_title/fictional_characters_with_this_job./fictional_universe/fictional_employment_tenure/employee',
#  544: '/fictional_universe/fictional_setting/fictional_characters_born_here',
#  545: '/fictional_universe/fictional_setting/works_set_here',
#  546: '/fictional_universe/fictional_universe/characters',
#  547: '/fictional_universe/fictional_universe/works_set_here',
#  548: '/fictional_universe/person_in_fiction/representations_in_fiction',
#  549: '/fictional_universe/work_of_fiction/part_of_these_fictional_universes',
#  550: '/fictional_universe/work_of_fiction/setting',
#  551: '/film/actor/dubbing_performances./film/dubbing_performance/character',
#  552: '/film/actor/dubbing_performances./film/dubbing_performance/film',
#  553: '/film/actor/dubbing_performances./film/dubbing_performance/language',
#  554: '/film/actor/film./film/performance/character',
#  555: '/film/actor/film./film/performance/film',
#  556: '/film/actor/film./film/performance/special_performance_type',
#  557: '/film/cinematographer/film',
#  558: '/film/director/film',
#  559: '/film/editor/film',
#  560: '/film/film/cinematography',
#  561: '/film/film/costume_design_by',
#  562: '/film/film/country',
#  563: '/film/film/directed_by',
#  564: '/film/film/distributors./film/film_film_distributor_relationship/distributor',
#  565: '/film/film/distributors./film/film_film_distributor_relationship/film_distribution_medium',
#  566: '/film/film/distributors./film/film_film_distributor_relationship/region',
#  567: '/film/film/dubbing_performances./film/dubbing_performance/actor',
#  568: '/film/film/dubbing_performances./film/dubbing_performance/character',
#  569: '/film/film/dubbing_performances./film/dubbing_performance/language',
#  570: '/film/film/edited_by',
#  571: '/film/film/estimated_budget./measurement_unit/dated_money_value/currency',
#  572: '/film/film/executive_produced_by',
#  573: '/film/film/featured_film_locations',
#  574: '/film/film/film_art_direction_by',
#  575: '/film/film/film_casting_director',
#  576: '/film/film/film_festivals',
#  577: '/film/film/film_format',
#  578: '/film/film/film_production_design_by',
#  579: '/film/film/film_series',
#  580: '/film/film/film_set_decoration_by',
#  581: '/film/film/genre',
#  582: '/film/film/gross_revenue./measurement_unit/dated_money_value/currency',
#  583: '/film/film/language',
#  584: '/film/film/music',
#  585: '/film/film/other_crew./film/film_crew_gig/crewmember',
#  586: '/film/film/other_crew./film/film_crew_gig/film_crew_role',
#  587: '/film/film/other_film_companies./film/film_film_company_relationship/film_company',
#  588: '/film/film/personal_appearances./film/personal_film_appearance/person',
#  589: '/film/film/personal_appearances./film/personal_film_appearance/type_of_appearance',
#  590: '/film/film/prequel',
#  591: '/film/film/produced_by',
#  592: '/film/film/production_companies',
#  593: '/film/film/release_date_s./film/film_regional_release_date/film_regional_debut_venue',
#  594: '/film/film/release_date_s./film/film_regional_release_date/film_release_distribution_medium',
#  595: '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#  596: '/film/film/runtime./film/film_cut/film_release_region',
#  597: '/film/film/runtime./film/film_cut/type_of_film_cut',
#  598: '/film/film/sequel',
#  599: '/film/film/starring./film/performance/actor',
#  600: '/film/film/starring./film/performance/character',
#  601: '/film/film/starring./film/performance/special_performance_type',
#  602: '/film/film/story_by',
#  603: '/film/film/subjects',
#  604: '/film/film/written_by',
#  605: '/film/film_art_director/films_art_directed',
#  606: '/film/film_casting_director/films_casting_directed',
#  607: '/film/film_character/portrayed_in_films./film/performance/actor',
#  608: '/film/film_character/portrayed_in_films./film/performance/film',
#  609: '/film/film_character/portrayed_in_films./film/performance/special_performance_type',
#  610: '/film/film_character/portrayed_in_films_dubbed./film/dubbing_performance/actor',
#  611: '/film/film_character/portrayed_in_films_dubbed./film/dubbing_performance/film',
#  612: '/film/film_character/portrayed_in_films_dubbed./film/dubbing_performance/language',
#  613: '/film/film_company/films./film/film_film_company_relationship/film',
#  614: '/film/film_costumer_designer/costume_design_for_film',
#  615: '/film/film_crewmember/films_crewed./film/film_crew_gig/film',
#  616: '/film/film_crewmember/films_crewed./film/film_crew_gig/film_crew_role',
#  617: '/film/film_distribution_medium/films_distributed_in_this_medium./film/film_film_distributor_relationship/film',
#  618: '/film/film_distributor/films_distributed./film/film_film_distributor_relationship/film',
#  619: '/film/film_featured_song/performed_by',
#  620: '/film/film_festival/individual_festivals',
#  621: '/film/film_festival/location',
#  622: '/film/film_festival_event/festival',
#  623: '/film/film_festival_event/films',
#  624: '/film/film_format/film_format',
#  625: '/film/film_genre/films_in_this_genre',
#  626: '/film/film_job/films_with_this_crew_job./film/film_crew_gig/crewmember',
#  627: '/film/film_job/films_with_this_crew_job./film/film_crew_gig/film',
#  628: '/film/film_location/featured_in_films',
#  629: '/film/film_production_designer/films_production_designed',
#  630: '/film/film_series/films_in_series',
#  631: '/film/film_set_designer/film_sets_designed',
#  632: '/film/film_story_contributor/film_story_credits',
#  633: '/film/film_subject/films',
#  634: '/film/music_contributor/film',
#  635: '/film/person_or_entity_appearing_in_film/films./film/personal_film_appearance/film',
#  636: '/film/person_or_entity_appearing_in_film/films./film/personal_film_appearance/type_of_appearance',
#  637: '/film/personal_film_appearance_type/film_appearances./film/personal_film_appearance/film',
#  638: '/film/personal_film_appearance_type/film_appearances./film/personal_film_appearance/person',
#  639: '/film/producer/film',
#  640: '/film/producer/films_executive_produced',
#  641: '/film/production_company/films',
#  642: '/film/special_film_performance_type/film_performance_type./film/performance/actor',
#  643: '/film/special_film_performance_type/film_performance_type./film/performance/character',
#  644: '/film/special_film_performance_type/film_performance_type./film/performance/film',
#  645: '/film/writer/film',
#  646: '/finance/currency/countries_formerly_used',
#  647: '/finance/currency/countries_used',
#  648: '/food/diet/followers',
#  649: '/food/diet_follower/follows_diet',
#  650: '/food/dietary_restriction/compatible_ingredients',
#  651: '/food/dietary_restriction/incompatible_ingredients',
#  652: '/food/dish/cuisine',
#  653: '/food/dish/ingredients',
#  654: '/food/food/nutrients./food/nutrition_fact/nutrient',
#  655: '/food/ingredient/compatible_with_dietary_restrictions',
#  656: '/food/ingredient/cuisine',
#  657: '/food/ingredient/dishes',
#  658: '/food/ingredient/incompatible_with_dietary_restrictions',
#  659: '/games/game_genre/boardgames',
#  660: '/geography/body_of_water/islands',
#  661: '/geography/geographical_feature/category',
#  662: '/geography/geographical_feature_category/features',
#  663: '/geography/island/body_of_water',
#  664: '/geography/island/island_group',
#  665: '/geography/island_group/islands_in_group',
#  666: '/geography/lake/basin_countries',
#  667: '/geography/lake/cities',
#  668: '/geography/lake/lake_type',
#  669: '/geography/lake_type/lakes_of_this_type',
#  670: '/geography/river/basin_countries',
#  671: '/geography/river/cities',
#  672: '/geography/river/mouth',
#  673: '/government/election/office',
#  674: '/government/form_of_government/countries',
#  675: '/government/government_agency/jurisdiction',
# ...
#  771: '/language/human_language/main_country',
#  772: '/language/human_language/region',
#  773: '/language/human_language/writing_system',
#  774: '/language/language_dialect/language',
#  775: '/language/language_family/languages',
#  776: '/language/language_writing_system/languages',
#  777: '/law/court/judges./law/judicial_tenure/judge',
#  778: '/law/invention/inventor',
#  779: '/law/inventor/inventions',
#  780: '/law/judge/courts./law/judicial_tenure/court',
#  781: '/location/administrative_division/capital./location/administrative_division_capital_relationship/capital',
#  782: '/location/administrative_division/country',
#  783: '/location/administrative_division/first_level_division_of',
#  784: '/location/administrative_division/second_level_division_of',
#  785: '/location/capital_of_administrative_division/capital_of./location/administrative_division_capital_relationship/administrative_division',
#  786: '/location/country/administrative_divisions',
#  787: '/location/country/capital',
#  788: '/location/country/currency_formerly_used',
#  789: '/location/country/currency_used',
#  790: '/location/country/first_level_divisions',
#  791: '/location/country/form_of_government',
#  792: '/location/country/languages_spoken',
#  793: '/location/country/official_language',
#  794: '/location/country/second_level_divisions',
#  795: '/location/hud_county_place/county',
#  796: '/location/hud_county_place/place',
#  797: '/location/hud_foreclosure_area/estimated_number_foreclosures./measurement_unit/dated_integer/source',
#  798: '/location/hud_foreclosure_area/estimated_number_of_mortgages./measurement_unit/dated_integer/source',
#  799: '/location/hud_foreclosure_area/hhuniv./measurement_unit/dated_integer/source',
#  800: '/location/hud_foreclosure_area/total_90_day_vacant_residential_addresses./measurement_unit/dated_integer/source',
#  801: '/location/hud_foreclosure_area/total_residential_addresses./measurement_unit/dated_integer/source',
#  802: '/location/it_province/capital',
#  803: '/location/location/adjoin_s./location/adjoining_relationship/adjoins',
#  804: '/location/location/containedby',
#  805: '/location/location/contains',
#  806: '/location/location/events',
#  807: '/location/location/nearby_airports',
#  808: '/location/location/partially_containedby',
#  809: '/location/location/partially_contains',
#  810: '/location/location/people_born_here',
#  811: '/location/location/street_address./location/mailing_address/citytown',
#  812: '/location/location/street_address./location/mailing_address/state_province_region',
#  813: '/location/location/time_zones',
#  814: '/location/neighborhood/neighborhood_of',
#  815: '/location/place_with_neighborhoods/neighborhoods',
#  816: '/location/statistical_region/gdp_nominal./measurement_unit/dated_money_value/currency',
#  817: '/location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency',
#  818: '/location/statistical_region/gdp_real./measurement_unit/adjusted_money_value/adjustment_currency',
#  819: '/location/statistical_region/gni_in_ppp_dollars./measurement_unit/dated_money_value/currency',
#  820: '/location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency',
#  821: '/location/statistical_region/places_exported_to./location/imports_and_exports/exported_to',
#  822: '/location/statistical_region/places_imported_from./location/imports_and_exports/imported_from',
#  823: '/location/statistical_region/population./measurement_unit/dated_integer/source',
#  824: '/location/statistical_region/religions./location/religion_percentage/religion',
#  825: '/location/statistical_region/rent50_0./measurement_unit/dated_money_value/currency',
#  826: '/location/statistical_region/rent50_1./measurement_unit/dated_money_value/currency',
#  827: '/location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency',
#  828: '/location/statistical_region/rent50_3./measurement_unit/dated_money_value/currency',
#  829: '/location/statistical_region/rent50_4./measurement_unit/dated_money_value/currency',
#  830: '/location/symbol_of_administrative_division/official_symbol_of./location/location_symbol_relationship/administrative_division',
#  831: '/location/us_county/county_seat',
#  832: '/location/us_county/hud_county_place',
#  833: '/martial_arts/martial_art/well_known_practitioner',
#  834: '/martial_arts/martial_artist/martial_art',
#  835: '/media_common/adaptation/adapted_from',
#  836: '/media_common/adapted_work/adaptations',
#  837: '/media_common/dedicated_work/dedication./media_common/dedication/dedicated_by',
#  838: '/media_common/dedicated_work/dedication./media_common/dedication/dedicated_to',
#  839: '/media_common/dedicatee/dedications./media_common/dedication/dedicated_by',
#  840: '/media_common/dedicatee/dedications./media_common/dedication/work_dedicated',
#  841: '/media_common/dedicator/dedications./media_common/dedication/dedicated_to',
#  842: '/media_common/dedicator/dedications./media_common/dedication/work_dedicated',
#  843: '/media_common/literary_genre/books_in_this_genre',
#  844: '/media_common/media_genre/child_genres',
#  845: '/media_common/media_genre/parent_genre',
#  846: '/media_common/netflix_genre/titles',
#  847: '/media_common/netflix_title/netflix_genres',
#  848: '/medicine/condition_prevention_factors/conditions_this_may_prevent',
#  849: '/medicine/disease/causes',
#  850: '/medicine/disease/includes_diseases',
#  851: '/medicine/disease/medical_specialties',
#  852: '/medicine/disease/notable_people_with_this_condition',
#  853: '/medicine/disease/parent_disease',
#  854: '/medicine/disease/prevention_factors',
#  855: '/medicine/disease/risk_factors',
#  856: '/medicine/disease/symptoms',
#  857: '/medicine/disease/treatments',
#  858: '/medicine/disease_cause/diseases',
#  859: '/medicine/drug/active_moieties',
#  860: '/medicine/drug/drug_class',
#  861: '/medicine/drug/legal_status',
#  862: '/medicine/drug_class/drugs',
#  863: '/medicine/drug_ingredient/active_moiety_of_drug',
#  864: '/medicine/drug_ingredient/more_general_ingredient',
#  865: '/medicine/drug_ingredient/more_specific_ingredient',
#  866: '/medicine/icd_9_cm_classification/includes_classifications',
#  867: '/medicine/icd_9_cm_classification/parent_classification',
#  868: '/medicine/infectious_disease/infectious_agent_type',
#  869: '/medicine/medical_specialty/diseases_treated',
#  870: '/medicine/medical_treatment/side_effects',
#  871: '/medicine/medical_treatment/used_to_treat',
#  872: '/medicine/notable_person_with_medical_condition/condition',
#  873: '/medicine/risk_factor/diseases',
#  874: '/medicine/symptom/side_effect_of',
#  875: '/medicine/symptom/symptom_of',
#  876: '/medicine/type_of_infectious_agent/diseases',
#  877: '/metropolitan_transit/transit_line/service_type',
#  878: '/metropolitan_transit/transit_service_type/transit_lines',
#  879: '/metropolitan_transit/transit_system/area_served',
#  880: '/military/armed_force/military_posts./military/military_post_use/military_post',
#  881: '/military/armed_force/personnel./military/military_service/military_person',
#  882: '/military/armed_force/personnel./military/military_service/rank',
#  883: '/military/military_combatant/casualties./military/casualties/military_conflict',
#  884: '/military/military_combatant/force_deployments./military/force_strength/combatant',
#  885: '/military/military_combatant/force_deployments./military/force_strength/military_conflict',
#  886: '/military/military_combatant/military_commanders./military/military_command/military_commander',
#  887: '/military/military_combatant/military_commanders./military/military_command/military_conflict',
#  888: '/military/military_combatant/military_conflicts./military/military_combatant_group/combatants',
#  889: '/military/military_combatant/military_conflicts./military/military_combatant_group/conflict',
#  890: '/military/military_commander/military_commands./military/military_command/military_combatant',
#  891: '/military/military_commander/military_commands./military/military_command/military_conflict',
#  892: '/military/military_conflict/casualties./military/casualties/combatant',
#  893: '/military/military_conflict/combatants./military/military_combatant_group/combatants',
#  894: '/military/military_conflict/commanders./military/military_command/military_combatant',
#  895: '/military/military_conflict/commanders./military/military_command/military_commander',
#  896: '/military/military_conflict/force_strengths./military/force_strength/combatant',
#  897: '/military/military_conflict/military_personnel_involved',
#  898: '/military/military_person/participated_in_conflicts',
#  899: '/military/military_person/service./military/military_service/military_force',
#  900: '/military/military_person/service./military/military_service/rank',
#  901: '/military/military_post/used_by_armed_forces./military/military_post_use/armed_force',
#  902: '/military/rank/used_by_services./military/military_service/military_force',
#  903: '/military/rank/used_by_services./military/military_service/military_person',
#  904: '/music/album/artist',
#  905: '/music/album/genre',
#  906: '/music/album_release_type/albums',
#  907: '/music/artist/album',
#  908: '/music/artist/contribution./music/recording_contribution/performance_role',
#  909: '/music/artist/genre',
#  910: '/music/artist/label',
#  911: '/music/artist/origin',
#  912: '/music/artist/supporting_artists',
#  913: '/music/artist/track_contributions./music/track_contribution/role',
#  914: '/music/concert_tour/artist',
#  915: '/music/conducted_ensemble/conductors./music/conducting_tenure/conductor',
#  916: '/music/conductor/groups./music/conducting_tenure/ensemble',
#  917: '/music/genre/albums',
#  918: '/music/genre/artists',
#  919: '/music/genre/parent_genre',
#  920: '/music/genre/subgenre',
#  921: '/music/group_member/artists_supported',
#  922: '/music/group_member/instruments_played',
#  923: '/music/group_member/membership./music/group_membership/group',
#  924: '/music/group_member/membership./music/group_membership/role',
#  925: '/music/group_member/vocal_range',
#  926: '/music/instrument/family',
#  927: '/music/instrument/instrumentalists',
#  928: '/music/instrument/variation',
#  929: '/music/musical_group/member./music/group_membership/member',
#  930: '/music/musical_group/member./music/group_membership/role',
#  931: '/music/performance_role/guest_performances./music/recording_contribution/contributor',
#  932: '/music/performance_role/guest_performances./music/recording_contribution/performance_role',
#  933: '/music/performance_role/regular_performances./music/group_membership/group',
#  934: '/music/performance_role/regular_performances./music/group_membership/member',
#  935: '/music/performance_role/regular_performances./music/group_membership/role',
#  936: '/music/performance_role/track_performances./music/track_contribution/contributor',
#  937: '/music/performance_role/track_performances./music/track_contribution/role',
#  938: '/music/record_label/artist',
#  939: '/music/voice/singers',
#  940: '/olympics/olympic_athlete/country./olympics/olympic_athlete_affiliation/country',
#  941: '/olympics/olympic_athlete/country./olympics/olympic_athlete_affiliation/olympics',
#  942: '/olympics/olympic_athlete/country./olympics/olympic_athlete_affiliation/sport',
#  943: '/olympics/olympic_athlete/medals_won./olympics/olympic_medal_honor/country',
#  944: '/olympics/olympic_athlete/medals_won./olympics/olympic_medal_honor/medal',
#  945: '/olympics/olympic_athlete/medals_won./olympics/olympic_medal_honor/medalist',
#  946: '/olympics/olympic_athlete/medals_won./olympics/olympic_medal_honor/olympics',
#  947: '/olympics/olympic_games/athletes./olympics/olympic_athlete_affiliation/athlete',
#  948: '/olympics/olympic_games/athletes./olympics/olympic_athlete_affiliation/country',
#  949: '/olympics/olympic_games/athletes./olympics/olympic_athlete_affiliation/sport',
#  950: '/olympics/olympic_games/medals_awarded./olympics/olympic_medal_honor/country',
#  951: '/olympics/olympic_games/medals_awarded./olympics/olympic_medal_honor/medal',
#  952: '/olympics/olympic_games/medals_awarded./olympics/olympic_medal_honor/medalist',
#  953: '/olympics/olympic_games/participating_countries',
#  954: '/olympics/olympic_games/sports',
#  955: '/olympics/olympic_medal/medal_winners./olympics/olympic_medal_honor/country',
#  956: '/olympics/olympic_medal/medal_winners./olympics/olympic_medal_honor/medalist',
#  957: '/olympics/olympic_medal/medal_winners./olympics/olympic_medal_honor/olympics',
#  958: '/olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/athlete',
#  959: '/olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics',
#  960: '/olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/sport',
#  961: '/olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/medal',
#  962: '/olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/medalist',
#  963: '/olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/olympics',
#  964: '/olympics/olympic_participating_country/olympics_participated_in',
#  965: '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/athlete',
#  966: '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country',
#  967: '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/olympics',
#  968: '/olympics/olympic_sport/olympic_games_contested',
#  969: '/organization/endowed_organization/endowment./measurement_unit/dated_money_value/currency',
#  970: '/organization/membership_organization/members./organization/organization_membership/member',
#  971: '/organization/non_profit_organization/registered_with./organization/non_profit_registration/registering_agency',
#  972: '/organization/organization/acquired_by./business/acquisition/acquiring_company',
#  973: '/organization/organization/board_members./organization/organization_board_membership/member',
#  974: '/organization/organization/board_members./organization/organization_board_membership/role',
#  975: '/organization/organization/child./organization/organization_relationship/child',
#  976: '/organization/organization/companies_acquired./business/acquisition/company_acquired',
#  977: '/organization/organization/founders',
#  978: '/organization/organization/geographic_scope',
#  979: '/organization/organization/headquarters./location/mailing_address/citytown',
#  980: '/organization/organization/headquarters./location/mailing_address/country',
#  981: '/organization/organization/headquarters./location/mailing_address/state_province_region',
#  982: '/organization/organization/involved_in_merger./organization/organization_merger/became_organization',
#  983: '/organization/organization/involved_in_merger./organization/organization_merger/organizations_merging',
#  984: '/organization/organization/leadership./organization/leadership/person',
#  985: '/organization/organization/leadership./organization/leadership/role',
#  986: '/organization/organization/legal_structure',
#  987: '/organization/organization/organization_type',
#  988: '/organization/organization/parent./organization/organization_relationship/parent',
#  989: '/organization/organization/phone_number./common/phone_number/category',
#  990: '/organization/organization/phone_number./common/phone_number/service_location',
#  991: '/organization/organization/place_founded',
#  992: '/organization/organization/product_of_merger./organization/organization_merger/organizations_merging',
#  993: '/organization/organization/sectors',
#  994: '/organization/organization/spin_offs./organization/organization_spin_off/child_company',
#  995: '/organization/organization/spun_off_from./organization/organization_spin_off/parent_company',
#  996: '/organization/organization_founder/organizations_founded',
#  997: '/organization/organization_member/member_of./organization/organization_membership/organization',
#  998: '/organization/organization_scope/organizations_with_this_scope',
#  999: '/organization/organization_sector/organizations_in_this_sector',
#  ...}

# %%
id2idx = {v:k for k,v in ds.training.entity_id_to_label.items()}
id2idx
# Out:
# {'/m/010016': 0,
#  '/m/0100mt': 1,
#  '/m/0102t4': 2,
#  '/m/0104lr': 3,
#  '/m/0105y2': 4,
#  '/m/0106dv': 5,
#  '/m/0108xl': 6,
#  '/m/0109vk': 7,
#  '/m/010bnr': 8,
#  '/m/010bxh': 9,
#  '/m/010cw1': 10,
#  '/m/010dft': 11,
#  '/m/010h9y': 12,
#  '/m/010hn': 13,
#  '/m/010m55': 14,
#  '/m/010nlt': 15,
#  '/m/010p3': 16,
#  '/m/010r6f': 17,
#  '/m/010rvx': 18,
#  '/m/010t4v': 19,
#  '/m/010tkc': 20,
#  '/m/010v8k': 21,
#  '/m/010xjr': 22,
#  '/m/010y34': 23,
#  '/m/010z5n': 24,
#  '/m/0113sg': 25,
#  '/m/0114m0': 26,
#  '/m/0118d3': 27,
#  '/m/0118v': 28,
#  '/m/011_3s': 29,
#  '/m/011_6p': 30,
#  '/m/011_vz': 31,
#  '/m/011hdn': 32,
#  '/m/011hq1': 33,
#  '/m/011j5x': 34,
#  '/m/011k11': 35,
#  '/m/011k1h': 36,
#  '/m/011k4g': 37,
#  '/m/011k_j': 38,
#  '/m/011kn2': 39,
#  '/m/011lpr': 40,
#  '/m/011lvx': 41,
#  '/m/011pcj': 42,
#  '/m/011s0': 43,
#  '/m/011s9r': 44,
#  '/m/011v3': 45,
#  '/m/011vx3': 46,
#  '/m/011w20': 47,
#  '/m/011w4n': 48,
#  '/m/011w54': 49,
#  '/m/011wdm': 50,
#  '/m/011wtv': 51,
#  '/m/011x_4': 52,
#  '/m/011xg5': 53,
#  '/m/011xhx': 54,
#  '/m/011xjd': 55,
#  '/m/011xy1': 56,
#  '/m/011ycb': 57,
#  '/m/011yd2': 58,
#  '/m/011ydl': 59,
#  '/m/011yfd': 60,
#  '/m/011yg9': 61,
#  '/m/011yhm': 62,
#  '/m/011ykb': 63,
#  '/m/011yl_': 64,
#  '/m/011yn5': 65,
#  '/m/011yph': 66,
#  '/m/011ypx': 67,
#  '/m/011yqc': 68,
#  '/m/011yr9': 69,
#  '/m/011yrp': 70,
#  '/m/011ys5': 71,
#  '/m/011ysn': 72,
#  '/m/011yth': 73,
#  '/m/011ywj': 74,
#  '/m/011yxg': 75,
#  '/m/011yxy': 76,
#  '/m/011z3g': 77,
#  '/m/011zd3': 78,
#  '/m/011zdm': 79,
#  '/m/011zf2': 80,
#  '/m/011zwl': 81,
#  '/m/01200d': 82,
#  '/m/01213c': 83,
#  '/m/0121c1': 84,
#  '/m/0121h7': 85,
#  '/m/0121rx': 86,
#  '/m/0121sr': 87,
#  '/m/012201': 88,
#  '/m/0122wc': 89,
#  '/m/0123_x': 90,
#  '/m/0123gq': 91,
#  '/m/0123j6': 92,
#  '/m/0123qq': 93,
#  '/m/0123r4': 94,
#  '/m/01242_': 95,
#  '/m/01243b': 96,
#  '/m/0124jj': 97,
#  '/m/0124k9': 98,
#  '/m/0124ld': 99,
#  '/m/0124qd': 100,
#  '/m/0125ny': 101,
#  '/m/0125q1': 102,
#  '/m/0125xq': 103,
#  '/m/0126hc': 104,
#  '/m/0126rp': 105,
#  '/m/0126t5': 106,
#  '/m/0126y2': 107,
#  '/m/01271h': 108,
#  '/m/01279v': 109,
#  '/m/0127c4': 110,
#  '/m/0127gn': 111,
#  '/m/0127m7': 112,
#  '/m/0127ps': 113,
#  '/m/0127s7': 114,
#  '/m/0127xk': 115,
#  '/m/012_53': 116,
#  '/m/012b30': 117,
#  '/m/012bk': 118,
#  '/m/012c6j': 119,
#  '/m/012c6x': 120,
#  '/m/012cj0': 121,
#  '/m/012cph': 122,
#  '/m/012d40': 123,
#  '/m/012d9h': 124,
#  '/m/012dr7': 125,
#  '/m/012dtf': 126,
#  '/m/012f86': 127,
#  '/m/012fvq': 128,
#  '/m/012fzm': 129,
#  '/m/012g92': 130,
#  '/m/012gbb': 131,
#  '/m/012gk9': 132,
#  '/m/012gq6': 133,
#  '/m/012gx2': 134,
#  '/m/012gyf': 135,
#  '/m/012h0y': 136,
#  '/m/012hw': 137,
#  '/m/012j5h': 138,
#  '/m/012j8z': 139,
#  '/m/012jc': 140,
#  '/m/012jfb': 141,
#  '/m/012k_9': 142,
#  '/m/012ky3': 143,
#  '/m/012kyx': 144,
#  '/m/012ljv': 145,
#  '/m/012lzc': 146,
#  '/m/012lzr': 147,
#  '/m/012m_': 148,
#  '/m/012mrr': 149,
#  '/m/012mzw': 150,
#  '/m/012pd4': 151,
#  '/m/012q4n': 152,
#  '/m/012q8y': 153,
#  '/m/012qdp': 154,
#  '/m/012qjw': 155,
#  '/m/012qxv': 156,
#  '/m/012rng': 157,
#  '/m/012rrr': 158,
#  '/m/012s1d': 159,
#  '/m/012s5j': 160,
#  '/m/012t1': 161,
#  '/m/012t_z': 162,
#  '/m/012tqm': 163,
#  '/m/012ts': 164,
#  '/m/012v1t': 165,
#  '/m/012v8': 166,
#  '/m/012v9y': 167,
#  '/m/012vby': 168,
#  '/m/012vct': 169,
#  '/m/012vd6': 170,
#  '/m/012vf6': 171,
#  '/m/012vm6': 172,
#  '/m/012vwb': 173,
#  '/m/012w3': 174,
#  '/m/012w70': 175,
#  '/m/012wg': 176,
#  '/m/012wgb': 177,
#  '/m/012wvj': 178,
#  '/m/012wxt': 179,
#  '/m/012wyq': 180,
#  '/m/012x03': 181,
#  '/m/012x1l': 182,
#  '/m/012x2b': 183,
#  '/m/012x4t': 184,
#  '/m/012x7b': 185,
#  '/m/012x8m': 186,
#  '/m/012xdf': 187,
#  '/m/012xsy': 188,
#  '/m/012yc': 189,
#  '/m/012ycy': 190,
#  '/m/012ykt': 191,
#  '/m/012z8_': 192,
#  '/m/012zng': 193,
#  '/m/01304j': 194,
#  '/m/01309x': 195,
#  '/m/0130sy': 196,
#  '/m/0130xz': 197,
#  '/m/01314k': 198,
#  '/m/0131kb': 199,
#  '/m/01323p': 200,
#  '/m/0132_h': 201,
#  '/m/0132k4': 202,
#  '/m/01336l': 203,
#  '/m/01337_': 204,
#  '/m/0133_p': 205,
#  '/m/0133ch': 206,
#  '/m/0133h8': 207,
#  '/m/0133jj': 208,
#  '/m/0133k0': 209,
#  '/m/0133sq': 210,
#  '/m/0133x7': 211,
#  '/m/013423': 212,
#  '/m/0134bf': 213,
#  '/m/0134pk': 214,
#  '/m/0134s5': 215,
#  '/m/0134tg': 216,
#  '/m/0134w7': 217,
#  '/m/0134wr': 218,
#  '/m/01352_': 219,
#  '/m/0135cw': 220,
#  '/m/0135dr': 221,
#  '/m/0135g': 222,
#  '/m/0135k2': 223,
#  '/m/0135nb': 224,
#  '/m/0135p7': 225,
#  '/m/0135xb': 226,
#  '/m/01364q': 227,
#  '/m/0136g9': 228,
#  '/m/0136jw': 229,
#  '/m/0136kr': 230,
#  '/m/0136p1': 231,
#  '/m/0136pk': 232,
#  '/m/013719': 233,
#  '/m/0137g1': 234,
#  '/m/0137hn': 235,
#  '/m/0137k8': 236,
#  '/m/0137n0': 237,
#  '/m/013807': 238,
#  '/m/01385g': 239,
#  '/m/01386_': 240,
#  '/m/0138kk': 241,
#  '/m/0138mv': 242,
#  '/m/0138t4': 243,
#  '/m/01399x': 244,
#  '/m/0139q5': 245,
#  '/m/013_5c': 246,
#  '/m/013_gg': 247,
#  '/m/013_vh': 248,
#  '/m/013b2h': 249,
#  '/m/013b6_': 250,
#  '/m/013bd1': 251,
#  '/m/013bqg': 252,
#  '/m/013c2f': 253,
#  '/m/013c6x': 254,
#  '/m/013cr': 255,
#  '/m/013crh': 256,
#  '/m/013cz2': 257,
#  '/m/013d7t': 258,
#  '/m/013d_f': 259,
#  '/m/013dy7': 260,
#  '/m/013f1h': 261,
#  '/m/013f9v': 262,
#  '/m/013fn': 263,
#  '/m/013g3': 264,
#  '/m/013gwb': 265,
#  '/m/013gxt': 266,
#  '/m/013gz': 267,
#  '/m/013h1c': 268,
#  '/m/013h9': 269,
#  '/m/013hvr': 270,
#  '/m/013hxv': 271,
#  '/m/013jz2': 272,
#  '/m/013kcv': 273,
#  '/m/013km': 274,
#  '/m/013knm': 275,
#  '/m/013ksx': 276,
#  '/m/013l6l': 277,
#  '/m/013m43': 278,
#  '/m/013m4v': 279,
#  '/m/013m_x': 280,
#  '/m/013mj_': 281,
#  '/m/013mtx': 282,
#  '/m/013mzh': 283,
#  '/m/013n0n': 284,
#  '/m/013n2h': 285,
#  '/m/013n60': 286,
#  '/m/013nky': 287,
#  '/m/013nty': 288,
#  '/m/013nv_': 289,
#  '/m/013nws': 290,
#  '/m/013p59': 291,
#  '/m/013pk3': 292,
#  '/m/013pp3': 293,
#  '/m/013q07': 294,
#  '/m/013q0p': 295,
#  '/m/013qvn': 296,
#  '/m/013rds': 297,
#  '/m/013rfk': 298,
#  '/m/013rxq': 299,
#  '/m/013sg6': 300,
#  '/m/013t2y': 301,
#  '/m/013t85': 302,
#  '/m/013t9y': 303,
#  '/m/013tcv': 304,
#  '/m/013tjc': 305,
#  '/m/013v5j': 306,
#  '/m/013vdl': 307,
#  '/m/013w2r': 308,
#  '/m/013w7j': 309,
#  '/m/013w8y': 310,
#  '/m/013wf1': 311,
#  '/m/013x0b': 312,
#  '/m/013xh7': 313,
#  '/m/013xrm': 314,
#  '/m/013y1f': 315,
#  '/m/013ybx': 316,
#  '/m/013yq': 317,
#  '/m/013zdg': 318,
#  '/m/013zs9': 319,
#  '/m/013zyw': 320,
#  '/m/01400v': 321,
#  '/m/0140g4': 322,
#  '/m/0140t7': 323,
#  '/m/0140xf': 324,
#  '/m/014162': 325,
#  '/m/0141kz': 326,
#  '/m/01423b': 327,
#  '/m/0142rn': 328,
#  '/m/01438g': 329,
#  '/m/0143hl': 330,
#  '/m/0143q0': 331,
#  '/m/0143wl': 332,
#  '/m/01445t': 333,
#  '/m/014488': 334,
#  '/m/0144l1': 335,
#  '/m/0144wg': 336,
#  '/m/01453': 337,
#  '/m/0145m': 338,
#  '/m/0145rs': 339,
#  '/m/014635': 340,
#  '/m/0146bp': 341,
#  '/m/0146hc': 342,
#  '/m/0146mv': 343,
#  '/m/0146pg': 344,
#  '/m/0147dk': 345,
#  '/m/0147fv': 346,
#  '/m/0147gr': 347,
#  '/m/0147jt': 348,
#  '/m/0147sh': 349,
#  '/m/0147w8': 350,
#  '/m/0148d': 351,
#  '/m/0148nj': 352,
#  '/m/0148xv': 353,
#  '/m/0149xx': 354,
#  '/m/014_24': 355,
#  '/m/014_lq': 356,
#  '/m/014_x2': 357,
#  '/m/014_xj': 358,
#  '/m/014b4h': 359,
#  '/m/014b6c': 360,
#  '/m/014bmh': 361,
#  '/m/014bpd': 362,
#  '/m/014ck4': 363,
#  '/m/014clr': 364,
#  '/m/014cnc': 365,
#  '/m/014cw2': 366,
#  '/m/014d4v': 367,
#  '/m/014d7f': 368,
#  '/m/014dd0': 369,
#  '/m/014dfn': 370,
#  '/m/014dgf': 371,
#  '/m/014dm6': 372,
#  '/m/014dq7': 373,
#  '/m/014dsx': 374,
#  '/m/014g22': 375,
#  '/m/014g91': 376,
#  '/m/014g9y': 377,
#  '/m/014g_s': 378,
#  '/m/014gf8': 379,
#  '/m/014gjp': 380,
#  '/m/014hdb': 381,
#  '/m/014hr0': 382,
#  '/m/014j0w': 383,
#  '/m/014j1m': 384,
#  '/m/014j83': 385,
#  '/m/014jyk': 386,
#  '/m/014kbl': 387,
#  '/m/014kg4': 388,
#  '/m/014kj2': 389,
#  '/m/014kkm': 390,
#  '/m/014knw': 391,
#  '/m/014kq6': 392,
#  '/m/014ktf': 393,
#  '/m/014kyy': 394,
#  '/m/014l4w': 395,
#  '/m/014l6_': 396,
#  '/m/014l7h': 397,
#  '/m/014lc_': 398,
#  '/m/014m1m': 399,
#  '/m/014mlp': 400,
#  '/m/014nq4': 401,
#  '/m/014nvr': 402,
#  '/m/014nzp': 403,
#  '/m/014pg1': 404,
#  '/m/014ps4': 405,
#  '/m/014q2g': 406,
#  '/m/014tss': 407,
#  '/m/014v1q': 408,
#  '/m/014v6f': 409,
#  '/m/014vk4': 410,
#  '/m/014vm4': 411,
#  '/m/014w_8': 412,
#  '/m/014wxc': 413,
#  '/m/014x77': 414,
#  '/m/014xf6': 415,
#  '/m/014y6': 416,
#  '/m/014yzm': 417,
#  '/m/014z8v': 418,
#  '/m/014zcr': 419,
#  '/m/014zfs': 420,
#  '/m/014zn0': 421,
#  '/m/014zwb': 422,
#  '/m/014zws': 423,
#  '/m/014zz1': 424,
#  '/m/015010': 425,
#  '/m/01505k': 426,
#  '/m/015076': 427,
#  '/m/01507p': 428,
#  '/m/0150jk': 429,
#  '/m/0150n': 430,
#  '/m/0150t6': 431,
#  '/m/01515d': 432,
#  '/m/01515w': 433,
#  '/m/01516r': 434,
#  '/m/01518s': 435,
#  '/m/015196': 436,
#  '/m/0151b0': 437,
#  '/m/0151ns': 438,
#  '/m/0151w_': 439,
#  '/m/0151xv': 440,
#  '/m/0151zx': 441,
#  '/m/01520h': 442,
#  '/m/0152cw': 443,
#  '/m/0152n0': 444,
#  '/m/0152x_': 445,
#  '/m/01531': 446,
#  '/m/0153nq': 447,
#  '/m/01540': 448,
#  '/m/015401': 449,
#  '/m/01541z': 450,
#  '/m/0154d7': 451,
#  '/m/0154fs': 452,
#  '/m/0154gx': 453,
#  '/m/0154j': 454,
#  '/m/0154qm': 455,
#  '/m/0154yf': 456,
#  '/m/0155j3': 457,
#  '/m/0155w': 458,
#  '/m/0156q': 459,
#  '/m/0156ts': 460,
#  '/m/0157g9': 461,
#  '/m/0157m': 462,
#  '/m/01585b': 463,
#  '/m/015882': 464,
#  '/m/0159h6': 465,
#  '/m/0159r9': 466,
#  '/m/015_1q': 467,
#  '/m/015_30': 468,
#  '/m/015_z1': 469,
#  '/m/015bpl': 470,
#  '/m/015btn': 471,
#  '/m/015bwt': 472,
#  '/m/015c1b': 473,
#  '/m/015c2f': 474,
#  '/m/015c4g': 475,
#  '/m/015cbq': 476,
#  '/m/015cj9': 477,
#  '/m/015cjr': 478,
#  '/m/015cl6': 479,
#  '/m/015cqh': 480,
#  '/m/015cxv': 481,
#  '/m/015cz0': 482,
#  '/m/015czt': 483,
#  '/m/015d3h': 484,
#  '/m/015dcj': 485,
#  '/m/015dnt': 486,
#  '/m/015dqj': 487,
#  '/m/015dvh': 488,
#  '/m/015dxd': 489,
#  '/m/015f47': 490,
#  '/m/015f7': 491,
#  '/m/015fr': 492,
#  '/m/015fs3': 493,
#  '/m/015fsv': 494,
#  '/m/015g1w': 495,
#  '/m/015g28': 496,
#  '/m/015g7': 497,
#  '/m/015g_7': 498,
#  '/m/015gjr': 499,
#  '/m/015gm8': 500,
#  '/m/015grj': 501,
#  '/m/015gsv': 502,
#  '/m/015gw6': 503,
#  '/m/015gy7': 504,
#  '/m/015h31': 505,
#  '/m/015hr': 506,
#  '/m/015j7': 507,
#  '/m/015jr': 508,
#  '/m/015k7': 509,
#  '/m/015kg1': 510,
#  '/m/015l4k': 511,
#  '/m/015lhm': 512,
#  '/m/015ll': 513,
#  '/m/015ln1': 514,
#  '/m/015m08': 515,
#  '/m/015mlw': 516,
#  '/m/015mrk': 517,
#  '/m/015n8': 518,
#  '/m/015nhn': 519,
#  '/m/015njf': 520,
#  '/m/015nl4': 521,
#  '/m/015np0': 522,
#  '/m/015npr': 523,
#  '/m/015nvj': 524,
#  '/m/015p1m': 525,
#  '/m/015p37': 526,
#  '/m/015p3p': 527,
#  '/m/015p6': 528,
#  '/m/015pdg': 529,
#  '/m/015pkc': 530,
#  '/m/015pkt': 531,
#  '/m/015pnb': 532,
#  '/m/015ppk': 533,
#  '/m/015pvh': 534,
#  '/m/015pxr': 535,
#  '/m/015q02': 536,
#  '/m/015q1n': 537,
#  '/m/015q43': 538,
#  '/m/015qh': 539,
#  '/m/015qq1': 540,
#  '/m/015qqg': 541,
#  '/m/015qsq': 542,
#  '/m/015qt5': 543,
#  '/m/015qy1': 544,
#  '/m/015qyf': 545,
#  '/m/015rhv': 546,
#  '/m/015rkw': 547,
#  '/m/015rmq': 548,
#  '/m/015srx': 549,
#  '/m/015t56': 550,
#  '/m/015t7v': 551,
#  '/m/015v3r': 552,
#  '/m/015vgc': 553,
#  '/m/015vq_': 554,
#  '/m/015vql': 555,
#  '/m/015w8_': 556,
#  '/m/015w9s': 557,
#  '/m/015wc0': 558,
#  '/m/015wd7': 559,
#  '/m/015wfg': 560,
#  '/m/015whm': 561,
#  '/m/015wnl': 562,
#  '/m/015wy_': 563,
#  '/m/015x1f': 564,
#  '/m/015x74': 565,
#  '/m/015xp4': 566,
#  '/m/015y2q': 567,
#  '/m/015y3j': 568,
#  '/m/015y_n': 569,
#  '/m/015ynm': 570,
#  '/m/015z4j': 571,
#  '/m/015zql': 572,
#  '/m/015zxh': 573,
#  '/m/015zyd': 574,
#  '/m/016017': 575,
#  '/m/0160nk': 576,
#  '/m/0160w': 577,
#  '/m/0161c': 578,
#  '/m/0161c2': 579,
#  '/m/0161h5': 580,
#  '/m/0161jj': 581,
#  '/m/0161rf': 582,
#  '/m/0161sp': 583,
#  '/m/0162b': 584,
#  '/m/0162c8': 585,
#  '/m/0162kb': 586,
#  '/m/0162v': 587,
#  '/m/01633c': 588,
#  '/m/01634x': 589,
#  '/m/016376': 590,
#  '/m/0163kf': 591,
#  '/m/0163m1': 592,
#  '/m/0163r3': 593,
#  '/m/0163t3': 594,
#  '/m/0163v': 595,
#  '/m/0163zw': 596,
#  '/m/01645p': 597,
#  '/m/016475': 598,
#  '/m/0164b': 599,
#  '/m/0164nb': 600,
#  '/m/0164qt': 601,
#  '/m/0164r9': 602,
#  '/m/0164v': 603,
#  '/m/0164w8': 604,
#  '/m/0164y7': 605,
#  '/m/0165b': 606,
#  '/m/0165v': 607,
#  '/m/016622': 608,
#  '/m/01664_': 609,
#  '/m/01669b': 610,
#  '/m/01669t': 611,
#  '/m/0166b': 612,
#  '/m/0166b8': 613,
#  '/m/0166c7': 614,
#  '/m/0166v': 615,
#  '/m/016722': 616,
#  '/m/016732': 617,
#  '/m/01679d': 618,
#  '/m/0167_s': 619,
#  '/m/0167bx': 620,
#  '/m/0167km': 621,
#  '/m/0167q3': 622,
#  '/m/0167v': 623,
#  '/m/0167v4': 624,
#  '/m/0167xy': 625,
#  '/m/016890': 626,
#  '/m/0168cl': 627,
#  '/m/0168dy': 628,
#  '/m/0168ls': 629,
#  '/m/0168nq': 630,
#  '/m/0168ql': 631,
#  '/m/0168t': 632,
#  '/m/01693z': 633,
#  '/m/01699': 634,
#  '/m/0169dl': 635,
#  '/m/0169t': 636,
#  '/m/016_mj': 637,
#  '/m/016_nr': 638,
#  '/m/016_rm': 639,
#  '/m/016_v3': 640,
#  '/m/016bx2': 641,
#  '/m/016cff': 642,
#  '/m/016chh': 643,
#  '/m/016cjb': 644,
#  '/m/016ckq': 645,
#  '/m/016clz': 646,
#  '/m/016cyt': 647,
#  '/m/016dgz': 648,
#  '/m/016dj8': 649,
#  '/m/016dmx': 650,
#  '/m/016dp0': 651,
#  '/m/016dsy': 652,
#  '/m/016fjj': 653,
#  '/m/016fly': 654,
#  '/m/016fmf': 655,
#  '/m/016fnb': 656,
#  '/m/016fyc': 657,
#  '/m/016g2_': 658,
#  '/m/016gb5': 659,
#  '/m/016ggh': 660,
#  '/m/016ghw': 661,
#  '/m/016gkf': 662,
#  '/m/016gp5': 663,
#  '/m/016gr2': 664,
#  '/m/016h4r': 665,
#  '/m/016h5l': 666,
#  '/m/016h9b': 667,
#  '/m/016hjr': 668,
#  '/m/016hvl': 669,
#  '/m/016j2t': 670,
#  '/m/016j68': 671,
#  '/m/016jfw': 672,
#  '/m/016jhr': 673,
#  '/m/016jll': 674,
#  '/m/016jny': 675,
#  '/m/016k4x': 676,
#  '/m/016k62': 677,
#  '/m/016k6x': 678,
#  '/m/016kb7': 679,
#  '/m/016kft': 680,
#  '/m/016khd': 681,
#  '/m/016kjs': 682,
#  '/m/016kkx': 683,
#  '/m/016ks5': 684,
#  '/m/016ks_': 685,
#  '/m/016ksk': 686,
#  '/m/016kv6': 687,
#  '/m/016ky6': 688,
#  '/m/016kz1': 689,
#  '/m/016l09': 690,
#  '/m/016lh0': 691,
#  '/m/016lj_': 692,
#  '/m/016lmg': 693,
#  '/m/016lv3': 694,
#  '/m/016m5c': 695,
#  '/m/016m9h': 696,
#  '/m/016mhd': 697,
#  '/m/016n7b': 698,
#  '/m/016ndm': 699,
#  '/m/016nff': 700,
#  '/m/016ntp': 701,
#  '/m/016nvh': 702,
#  '/m/016pjk': 703,
#  '/m/016pns': 704,
#  '/m/016ppr': 705,
#  '/m/016qtt': 706,
#  '/m/016qwt': 707,
#  '/m/016r9z': 708,
#  '/m/016s0m': 709,
#  '/m/016s_5': 710,
#  '/m/016sd3': 711,
#  '/m/016sp_': 712,
#  '/m/016sqs': 713,
#  '/m/016srn': 714,
#  '/m/016szr': 715,
#  '/m/016t00': 716,
#  '/m/016t0h': 717,
#  '/m/016t_3': 718,
#  '/m/016tb7': 719,
#  '/m/016tbr': 720,
#  '/m/016tt2': 721,
#  '/m/016tvq': 722,
#  '/m/016tw3': 723,
#  '/m/016v46': 724,
#  '/m/016vg8': 725,
#  '/m/016vh2': 726,
#  '/m/016vj5': 727,
#  '/m/016vn3': 728,
#  '/m/016vqk': 729,
#  '/m/016w7b': 730,
#  '/m/016wrq': 731,
#  '/m/016wtf': 732,
#  '/m/016wvy': 733,
#  '/m/016wyn': 734,
#  '/m/016wzw': 735,
#  '/m/016xh5': 736,
#  '/m/016xk5': 737,
#  '/m/016y3j': 738,
#  '/m/016y_f': 739,
#  '/m/016ybr': 740,
#  '/m/016ynj': 741,
#  '/m/016ypb': 742,
#  '/m/016yr0': 743,
#  '/m/016yvw': 744,
#  '/m/016ywb': 745,
#  '/m/016ywr': 746,
#  '/m/016yxn': 747,
#  '/m/016yzz': 748,
#  '/m/016z1c': 749,
#  '/m/016z1t': 750,
#  '/m/016z2j': 751,
#  '/m/016z43': 752,
#  '/m/016z4k': 753,
#  '/m/016z51': 754,
#  '/m/016z5x': 755,
#  '/m/016z68': 756,
#  '/m/016z7s': 757,
#  '/m/016z9n': 758,
#  '/m/016zdd': 759,
#  '/m/016zfm': 760,
#  '/m/016zgj': 761,
#  '/m/016zp5': 762,
#  '/m/016ztl': 763,
#  '/m/016zwt': 764,
#  '/m/016zxr': 765,
#  '/m/0170_p': 766,
#  '/m/0170k0': 767,
#  '/m/0170pk': 768,
#  '/m/0170qf': 769,
#  '/m/0170s4': 770,
#  '/m/0170th': 771,
#  '/m/0170vn': 772,
#  '/m/0170xl': 773,
#  '/m/0170yd': 774,
#  '/m/0170z3': 775,
#  '/m/01713c': 776,
#  '/m/017149': 777,
#  '/m/017180': 778,
#  '/m/01718w': 779,
#  '/m/01719t': 780,
#  '/m/0171b8': 781,
#  '/m/0171c7': 782,
#  '/m/0171cm': 783,
#  '/m/0171lb': 784,
#  '/m/01722w': 785,
#  '/m/017236': 786,
#  '/m/0172jm': 787,
#  '/m/0172rj': 788,
#  '/m/01730d': 789,
#  '/m/017323': 790,
#  '/m/017371': 791,
#  '/m/01738f': 792,
#  '/m/01738w': 793,
#  '/m/0173b0': 794,
#  '/m/0173kj': 795,
#  '/m/0173s9': 796,
#  '/m/0174qm': 797,
#  '/m/01750n': 798,
#  '/m/017510': 799,
#  '/m/01756d': 800,
#  '/m/017575': 801,
#  '/m/0175rc': 802,
#  '/m/0175tv': 803,
#  '/m/0175wg': 804,
#  '/m/0175yg': 805,
#  '/m/0175zz': 806,
#  '/m/01771z': 807,
#  '/m/01773g': 808,
#  '/m/0177g': 809,
#  '/m/0177gl': 810,
#  '/m/0177s6': 811,
#  '/m/0177sq': 812,
#  '/m/0177z': 813,
#  '/m/0178_w': 814,
#  '/m/0178g': 815,
#  '/m/0178kd': 816,
#  '/m/0178rl': 817,
#  '/m/017959': 818,
#  '/m/01795t': 819,
#  '/m/01796z': 820,
#  '/m/01797x': 821,
#  '/m/0179q0': 822,
#  '/m/0179qv': 823,
#  '/m/017_1x': 824,
#  '/m/017_29': 825,
#  '/m/017_4z': 826,
#  '/m/017_cl': 827,
#  '/m/017_hq': 828,
#  '/m/017_pb': 829,
#  '/m/017_qw': 830,
#  '/m/017b2p': 831,
#  '/m/017c87': 832,
#  '/m/017cjb': 833,
#  '/m/017cw': 834,
#  '/m/017cy9': 835,
#  '/m/017d77': 836,
#  '/m/017d93': 837,
#  '/m/017dbx': 838,
#  '/m/017dcd': 839,
#  '/m/017dpj': 840,
#  '/m/017drs': 841,
#  '/m/017dtf': 842,
#  '/m/017f3m': 843,
#  '/m/017f4y': 844,
#  '/m/017fp': 845,
#  '/m/017fx5': 846,
#  '/m/017g21': 847,
#  '/m/017g2y': 848,
#  '/m/017gl1': 849,
#  '/m/017gm7': 850,
#  '/m/017gry': 851,
#  '/m/017gxw': 852,
#  '/m/017hnw': 853,
#  '/m/017ht': 854,
#  '/m/017j4q': 855,
#  '/m/017j6': 856,
#  '/m/017j69': 857,
#  '/m/017j7y': 858,
#  '/m/017jd9': 859,
#  '/m/017jq': 860,
#  '/m/017jv5': 861,
#  '/m/017kct': 862,
#  '/m/017khj': 863,
#  '/m/017kz7': 864,
#  '/m/017l4': 865,
#  '/m/017l66': 866,
#  '/m/017l96': 867,
#  '/m/017lb_': 868,
#  '/m/017lqp': 869,
#  '/m/017lvd': 870,
#  '/m/017m2y': 871,
#  '/m/017mbb': 872,
#  '/m/017n9': 873,
#  '/m/017r13': 874,
#  '/m/017r2': 875,
#  '/m/017rbx': 876,
#  '/m/017s11': 877,
#  '/m/017s1k': 878,
#  '/m/017t44': 879,
#  '/m/017v3q': 880,
#  '/m/017v71': 881,
#  '/m/017v_': 882,
#  '/m/017vb_': 883,
#  '/m/017vdg': 884,
#  '/m/017vkx': 885,
#  '/m/017w_': 886,
#  '/m/017wh': 887,
#  '/m/017xm3': 888,
#  '/m/017y26': 889,
#  '/m/017y6l': 890,
#  '/m/017yfz': 891,
#  '/m/017yxq': 892,
#  '/m/017yzc': 893,
#  '/m/017z49': 894,
#  '/m/017z88': 895,
#  '/m/017znw': 896,
#  '/m/017zq0': 897,
#  '/m/017ztv': 898,
#  '/m/018009': 899,
#  '/m/01803s': 900,
#  '/m/0180mw': 901,
#  '/m/0180w8': 902,
#  '/m/01817f': 903,
#  '/m/0181dw': 904,
#  '/m/0181hw': 905,
#  '/m/0182r9': 906,
#  '/m/0183z2': 907,
#  '/m/018417': 908,
#  '/m/01846t': 909,
#  '/m/0184dt': 910,
#  '/m/0184jc': 911,
#  '/m/0184jw': 912,
#  '/m/0184tc': 913,
#  '/m/0187nd': 914,
#  '/m/0187wh': 915,
#  '/m/0187x8': 916,
#  '/m/0187y5': 917,
#  '/m/018_7x': 918,
#  '/m/018_lb': 919,
#  '/m/018_q8': 920,
#  '/m/018c_r': 921,
#  '/m/018ckn': 922,
#  '/m/018cqq': 923,
#  '/m/018ctl': 924,
#  '/m/018cvf': 925,
#  '/m/018cwm': 926,
#  '/m/018d5b': 927,
#  '/m/018d6l': 928,
#  '/m/018db8': 929,
#  '/m/018dcy': 930,
#  '/m/018dh3': 931,
#  '/m/018dhx': 932,
#  '/m/018djs': 933,
#  '/m/018dk_': 934,
#  '/m/018dnt': 935,
#  '/m/018dx9': 936,
#  '/m/018dyl': 937,
#  '/m/018f8': 938,
#  '/m/018f94': 939,
#  '/m/018fmr': 940,
#  '/m/018fq': 941,
#  '/m/018fwv': 942,
#  '/m/018gkb': 943,
#  '/m/018gm9': 944,
#  '/m/018gmr': 945,
#  '/m/018gqj': 946,
#  '/m/018grr': 947,
#  '/m/018gz8': 948,
#  '/m/018h2': 949,
#  '/m/018h8j': 950,
#  '/m/018hzk': 951,
#  '/m/018j2': 952,
#  '/m/018jcq': 953,
#  '/m/018jk2': 954,
#  '/m/018jkl': 955,
#  '/m/018jmn': 956,
#  '/m/018jn4': 957,
#  '/m/018js4': 958,
#  '/m/018jz': 959,
#  '/m/018k8r': 960,
#  '/m/018kcp': 961,
#  '/m/018l5l': 962,
#  '/m/018lbg': 963,
#  '/m/018lc_': 964,
#  '/m/018ldw': 965,
#  '/m/018lg0': 966,
#  '/m/018ljb': 967,
#  '/m/018lkp': 968,
#  '/m/018m5q': 969,
#  '/m/018mlg': 970,
#  '/m/018mm4': 971,
#  '/m/018mmj': 972,
#  '/m/018mmw': 973,
#  '/m/018mrd': 974,
#  '/m/018mxj': 975,
#  '/m/018n1k': 976,
#  '/m/018n6m': 977,
#  '/m/018ndc': 978,
#  '/m/018nnz': 979,
#  '/m/018p4y': 980,
#  '/m/018p5f': 981,
#  '/m/018phr': 982,
#  '/m/018pj3': 983,
#  '/m/018q42': 984,
#  '/m/018q7': 985,
#  '/m/018qb4': 986,
#  '/m/018qd6': 987,
#  '/m/018qpb': 988,
#  '/m/018qpq': 989,
#  '/m/018qql': 990,
#  '/m/018qt8': 991,
#  '/m/018r_v': 992,
#  '/m/018rn4': 993,
#  '/m/018s4': 994,
#  '/m/018s6c': 995,
#  '/m/018sg9': 996,
#  '/m/018swb': 997,
#  '/m/018t8f': 998,
#  '/m/018td': 999,
#  ...}

# %%
e2dta_loc = '/home/gebhart/projects/traversing_knowledge_graphs/data/freebase/entity2wikidata.json'
with open(e2dta_loc) as f_in:
    entity2wiki = json.load(f_in)

# %%
n2fbid = {}
for k in entity2wiki:
    name = entity2wiki[k]['label']
    reformat_name = name.lower().replace(' ', '_')
    n2fbid[reformat_name] = k
n2fbid
# Out:
# {'denton': '/m/010016',
#  'el_paso': '/m/0100mt',
#  'marshall': '/m/0102t4',
#  'beaumont': '/m/0104lr',
#  'lubbock': '/m/0105y2',
#  'waco': '/m/0106dv',
#  'tyler': '/m/0108xl',
#  'san_angelo': '/m/0109vk',
#  'laredo': '/m/010bnr',
#  'wichita_falls': '/m/010bxh',
#  'hackensack,_new_jersey': '/m/010cw1',
#  'logan': '/m/010dft',
#  'ogden': '/m/010h9y',
#  'amy_grant': '/m/010hn',
#  'mclean': '/m/010m55',
#  'monte_carlo': '/m/010nlt',
#  'adam_carolla': '/m/010p3',
#  'bellevue': '/m/010r6f',
#  'bremerton': '/m/010rvx',
#  'tacoma': '/m/010t4v',
#  'everett': '/m/010tkc',
#  'spokane': '/m/010v8k',
#  'richard_harris': '/m/010xjr',
#  'morgantown': '/m/010y34',
#  'parkersburg': '/m/010z5n',
#  'nikolai_gogol': '/m/0113sg',
#  'la_crosse': '/m/0114m0',
#  'racine': '/m/0118d3',
#  'lily_tomlin': '/m/011_3s',
#  'kazoo': '/m/011_6p',
#  'faith_no_more': '/m/011_vz',
#  'alice_cooper': '/m/011hdn',
#  'sikkim': '/m/011hq1',
#  'post-punk': '/m/011j5x',
#  'decca_records': '/m/011k11',
#  'emi': '/m/011k1h',
#  'carl_stalling': '/m/011k4g',
#  'timpani': '/m/011k_j',
#  'university_of_ottawa': '/m/011kn2',
#  'jack_webb': '/m/011lpr',
#  'laurie_anderson': '/m/011lvx',
#  'dumfries_and_galloway': '/m/011pcj',
#  'advertising': '/m/011s0',
#  'joe_shuster': '/m/011s9r',
#  'a.c._milan': '/m/011v3',
#  'pete_seeger': '/m/011vx3',
#  'bill_finger': '/m/011w20',
#  'nancy': '/m/011w4n',
#  'sveriges_riksbank_prize_in_economic_sciences_in_memory_of_alfred_nobel': '/m/011w54',
#  'boulogne-billancourt': '/m/011wdm',
#  'minority_report': '/m/011wtv',
#  'groundhog_day': '/m/011x_4',
#  'a.i._artificial_intelligence': '/m/011xg5',
#  'kiss': '/m/011xhx',
#  'lon_chaney,_jr.': '/m/011xjd',
#  'trinity_college_dublin': '/m/011xy1',
#  'quiz_show': '/m/011ycb',
#  'apollo_13': '/m/011yd2',
#  'babe': '/m/011ydl',
#  'il_postino:_the_postman': '/m/011yfd',
#  'sense_and_sensibility': '/m/011yg9',
#  'fargo': '/m/0ynfz',
#  'jerry_maguire': '/m/011ykb',
#  'shine': '/m/011yl_',
#  'as_good_as_it_gets': '/m/011yn5',
#  'the_full_monty': '/m/011yph',
#  'good_will_hunting': '/m/011ypx',
#  'l.a._confidential': '/m/011yqc',
#  'elizabeth': '/m/0xszy',
#  'life_is_beautiful': '/m/011yrp',
#  'farce': '/m/011ys5',
#  'the_thin_red_line': '/m/011ysn',
#  'the_insider': '/m/011yth',
#  'gosford_park': '/m/011ywj',
#  'moulin_rouge!': '/m/011yxg',
#  'cries_and_whispers': '/m/011yxy',
#  'outkast': '/m/011z3g',
#  'lucy_liu': '/m/011zd3',
#  'peritonitis': '/m/011zdm',
#  'yo-yo_ma': '/m/011zf2',
#  'douglas_haig,_1st_earl_haig': '/m/011zwl',
#  'wallace_beery': '/m/01200d',
#  'argyll_and_bute': '/m/01213c',
#  'west_sussex': '/m/0121c1',
#  'county_laois': '/m/0121h7',
#  'jackie_gleason': '/m/0121rx',
#  'gujarati': '/m/0121sr',
#  'nino_rota': '/m/012201',
#  'real_sociedad': '/m/0122wc',
#  'barcelona_province': '/m/0123_x',
#  'harbin': '/m/0123gq',
#  'bethesda_softworks': '/m/0123j6',
#  'angel': '/m/0123qq',
#  'band_aid': '/m/0123r4',
#  'mrs._brown': '/m/01242_',
#  'indie_rock': '/m/01243b',
#  'perth_and_kinross': '/m/0124jj',
#  'the_larry_sanders_show': '/m/0124k9',
#  '1952_winter_olympics': '/m/0124ld',
#  'inner_hebrides': '/m/0124qd',
#  'lake_district': '/m/0125ny',
#  'north_yorkshire': '/m/0125q1',
#  'the_fifth_element': '/m/0125xq',
#  'fulham': '/m/0126hc',
#  'eddie_izzard': '/m/0126rp',
#  'instrumental_rock': '/m/0126t5',
#  'ja_rule': '/m/0126y2',
#  'trent_reznor': '/m/01271h',
#  'county_tipperary': '/m/01279v',
#  'tyne_and_wear': '/m/0127c4',
#  'vladimir_horowitz': '/m/0127gn',
#  'kevin_costner': '/m/0127m7',
#  'conspiracy_theory': '/m/0127ps',
#  'christina_aguilera': '/m/0127s7',
#  'steve_allen': '/m/0127xk',
#  'melissa_joan_hart': '/m/012_53',
#  'sub_pop': '/m/012b30',
#  'ariel_sharon': '/m/012bk',
#  'adolphe_menjou': '/m/012c6j',
#  'jackie_cooper': '/m/012c6x',
#  'steve_mcqueen': '/m/012cj0',
#  'dashiell_hammett': '/m/012cph',
#  'jackie_chan': '/m/012d40',
#  'inverness': '/m/012d9h',
#  'william_powell': '/m/012dr7',
#  'franchot_tone': '/m/012dtf',
#  'ukrainians': '/m/012f86',
#  'swarthmore_college': '/m/012fvq',
#  'torquay': '/m/012fzm',
#  'isabelle_huppert': '/m/012g92',
#  'marlene_dietrich': '/m/012gbb',
#  'star_trek_v:_the_final_frontier': '/m/012gk9',
#  'bob_newhart': '/m/012gq6',
#  'joe_biden': '/m/012gx2',
#  'national_autonomous_university_of_mexico': '/m/012gyf',
#  'attack': '/m/012hw',
#  'raymond_massey': '/m/012j5h',
#  'walter_pidgeon': '/m/012j8z',
#  'alcoholism': '/m/012jc',
#  'bowling_for_columbine': '/m/012jfb',
#  'michel_legrand': '/m/012ky3',
#  '28_days_later': '/m/012kyx',
#  'gabriel_yared': '/m/012ljv',
#  'self-help': '/m/012lzc',
#  'university_of_new_south_wales': '/m/012lzr',
#  'austria-hungary': '/m/012m_',
#  'close_encounters_of_the_third_kind': '/m/012mrr',
#  'university_of_notre_dame': '/m/012mzw',
#  'scott_bradley': '/m/012pd4',
#  'peter_stormare': '/m/012q4n',
#  'fremantle': '/m/012q8y',
#  'military_officer': '/m/012qdp',
#  'vomiting': '/m/012qjw',
#  'county_sligo': '/m/012qxv',
#  'norman_jewison': '/m/012rng',
#  'upper_austria': '/m/012rrr',
#  'spider-man': '/m/06ys2',
#  'raquel_welch': '/m/012s5j',
#  'arthur_laurents': '/m/012t1',
#  'businessperson': '/m/012t_z',
#  'auckland': '/m/012ts',
#  'nancy_pelosi': '/m/012v1t',
#  'albanian': '/m/012v8',
#  'william_holden': '/m/012v9y',
#  'mervyn_leroy': '/m/012vby',
#  'george_stevens': '/m/012vct',
#  'aretha_franklin': '/m/012vd6',
#  'myrna_loy': '/m/012vf6',
#  'the_moody_blues': '/m/012vm6',
#  'clemson_university': '/m/012vwb',
#  'yue_chinese': '/m/012w70',
#  'alan_jay_lerner': '/m/012wg',
#  'ireland': '/m/03rt9',
#  'vj': '/m/012wxt',
#  'middlesex': '/m/012wyq',
#  'the_temptations': '/m/012x03',
#  'the_pretenders': '/m/012x1l',
#  'simon_pegg': '/m/012x2b',
#  'stevie_wonder': '/m/012x4t',
#  'psychedelic_trance': '/m/012x7b',
#  'sst_records': '/m/012x8m',
#  "shaquille_o'neal": '/m/012xdf',
#  'music_of_japan': '/m/012xsy',
#  'alternative_hip_hop': '/m/012yc',
#  'ian_mackaye': '/m/012ycy',
#  'michelle_yeoh': '/m/012ykt',
#  'marvin_gaye': '/m/012z8_',
#  'mike_watt': '/m/012zng',
#  'carlos_santana': '/m/01304j',
#  'james_taylor': '/m/01309x',
#  'jon_anderson': '/m/0130sy',
#  'general_officer': '/m/0130xz',
#  'kingston_university': '/m/01314k',
#  'donald_pleasence': '/m/0131kb',
#  'duran_duran': '/m/01323p',
#  'yomiuri_giants': '/m/0132_h',
#  'jaco_pastorius': '/m/0132k4',
#  'asian_american': '/m/01336l',
#  'james_coburn': '/m/01337_',
#  'garage_rock': '/m/0133_p',
#  'chesterfield': '/m/0133ch',
#  'lower_austria': '/m/0133h8',
#  'tyrol': '/m/0133jj',
#  'electroclash': '/m/0133k0',
#  'nick_park': '/m/0133sq',
#  'sarah_mclachlan': '/m/0133x7',
#  'carole_king': '/m/013423',
#  'west_yorkshire': '/m/0134bf',
#  'aerosmith': '/m/0134pk',
#  'ac/dc': '/m/0134s5',
#  'allman_brothers_band': '/m/0134tg',
#  'emma_watson': '/m/0134w7',
#  'bee_gees': '/m/0134wr',
#  'brazil_national_football_team': '/m/01352_',
#  'bharatiya_janata_party': '/m/0135cw',
#  'indian_national_congress': '/m/0135dr',
#  'alameda': '/m/0135g',
#  'dortmund': '/m/0135k2',
#  'chris_waddle': '/m/0135nb',
#  'st._joseph': '/m/0135p7',
#  'joe_jackson': '/m/0135xb',
#  'al_green': '/m/01364q',
#  'richard_curtis': '/m/0136g9',
#  'danbury': '/m/0136jw',
#  'liberal_party_of_canada': '/m/0136kr',
#  'donna_summer': '/m/0136p1',
#  'jackson_browne': '/m/0136pk',
#  'monash_university': '/m/013719',
#  'beck': '/m/0137g1',
#  'robin_gibb': '/m/0137hn',
#  'willie_nelson': '/m/0137n0',
#  'san_francisco_state_university': '/m/013807',
#  'michael_redgrave': '/m/01385g',
#  'serj_tankian': '/m/01386_',
#  'dewsbury': '/m/0138kk',
#  'udinese_calcio': '/m/0138mv',
#  'trinity_hall': '/m/0138t4',
#  'q2927648': '/m/01399x',
#  'maggie_cheung': '/m/0139q5',
#  'new_zealand_labour_party': '/m/013_5c',
#  'hildesheim': '/m/013_gg',
#  'daniel_radcliffe': '/m/013_vh',
#  '2002_grammy_awards': '/m/013b2h',
#  'ashkenazi_jews': '/m/013b6_',
#  'david_suchet': '/m/013bd1',
#  'high_wycombe': '/m/013bqg',
#  'ealing': '/m/013c2f',
#  'miss_universe': '/m/013c6x',
#  'albert_brooks': '/m/013cr',
#  'sioux_city': '/m/013crh',
#  'manhattan': '/m/0jyx6',
#  'shreveport': '/m/013d7t',
#  'east_lansing': '/m/013d_f',
#  'midland': '/m/013n2h',
#  'traverse_city': '/m/013f1h',
#  'st._cloud': '/m/013f9v',
#  'australian_broadcasting_corporation': '/m/013fn',
#  'alexandria': '/m/013h9',
#  'springfield': '/m/0ytph',
#  'independence': '/m/013gxt',
#  'joplin': '/m/013h1c',
#  'high_point': '/m/013hvr',
#  'durham': '/m/0hx5f',
#  'youngstown': '/m/013jz2',
#  'tulsa': '/m/013kcv',
#  'akira_toriyama': '/m/013km',
#  'catherine_zeta-jones': '/m/013knm',
#  'bethlehem': '/m/013ksx',
#  'sioux_falls': '/m/013l6l',
#  'garland': '/m/013m43',
#  'plano': '/m/013m4v',
#  'abilene': '/m/013m_x',
#  'odessa': '/m/0ffmp',
#  'longview': '/m/013mtx',
#  'port_arthur': '/m/013mzh',
#  'corpus_christi': '/m/013n0n',
#  'amarillo': '/m/013n60',
#  "king's_college": '/m/013nky',
#  'wheeling': '/m/013nty',
#  'appleton': '/m/013nv_',
#  'eau_claire': '/m/013nws',
#  'merseyside': '/m/013p59',
#  'hugh_laurie': '/m/013pk3',
#  'philip_roth': '/m/013pp3',
#  'austin_powers_in_goldmember': '/m/013q07',
#  'austin_powers:_international_man_of_mystery': '/m/013q0p',
#  'dean_martin': '/m/013qvn',
#  'ziggy_marley': '/m/013rds',
#  'the_cult': '/m/013rfk',
#  'tejano_music': '/m/013rxq',
#  'vincent_price': '/m/013sg6',
#  'wakefield': '/m/013t2y',
#  'pontefract': '/m/013t85',
#  'george_miller': '/m/013t9y',
#  'baz_luhrmann': '/m/013tcv',
#  'don_rickles': '/m/013tjc',
#  'la_toya_jackson': '/m/013v5j',
#  'mae_whitman': '/m/013vdl',
#  'styx': '/m/013w2r',
#  'sean_combs': '/m/013w7j',
#  'dave_matthews_band': '/m/013w8y',
#  'huddersfield': '/m/013wf1',
#  'mushroom_records': '/m/013x0b',
#  'r.s.c._anderlecht': '/m/013xh7',
#  'germans': '/m/013xrm',
#  'organ': '/m/013y1f',
#  'zsa_zsa_gabor': '/m/013ybx',
#  'atlanta': '/m/013yq',
#  'juris_doctor': '/m/013zdg',
#  'jane_horrocks': '/m/013zs9',
#  'wes_craven': '/m/013zyw',
#  'public_policy': '/m/01400v',
#  'rocky_v': '/m/0140g4',
#  'phil_collins': '/m/0140t7',
#  'christmas_music': '/m/0140xf',
#  'east_riding_of_yorkshire': '/m/014162',
#  'john_mills': '/m/0141kz',
#  'chester': '/m/0zygc',
#  'chief_information_officer': '/m/0142rn',
#  'richard_gere': '/m/01438g',
#  'university_of_bath': '/m/0143hl',
#  'afi': '/m/0143q0',
#  'timothy_dalton': '/m/0143wl',
#  'sportsperson': '/m/01445t',
#  'harry_belafonte': '/m/014488',
#  'pete_townshend': '/m/0144l1',
#  'doncaster': '/m/0144wg',
#  'acf_fiorentina': '/m/01453',
#  'afrobeat': '/m/0145m',
#  'contemporary_christian_music': '/m/0145rs',
#  'mark_twain': '/m/014635',
#  'type_2_diabetes_mellitus': '/m/0146bp',
#  'university_of_central_florida': '/m/0146hc',
#  'nickelodeon': '/m/0146mv',
#  'john_williams': '/m/0146pg',
#  'will_smith': '/m/0147dk',
#  'aerospace': '/m/0147gr',
#  'michael_w._smith': '/m/0147jt',
#  'quo_vadis': '/m/0147sh',
#  'the_edge_of_night': '/m/0147w8',
#  'oi!': '/m/0148nj',
#  'hanging': '/m/0148xv',
#  'mstislav_rostropovich': '/m/0149xx',
#  'queens_of_the_stone_age': '/m/014_lq',
#  'city_of_angels': '/m/014_x2',
#  'iron_maiden': '/m/014_xj',
#  'brunel_university_london': '/m/014b4h',
#  'st._charles_county': '/m/014b6c',
#  'heavy_metal': '/m/014bpd',
#  'liaoning': '/m/014ck4',
#  'shaanxi': '/m/014clr',
#  'billy_bragg': '/m/014cw2',
#  'university_of_york': '/m/014d4v',
#  'fluoride_ion': '/m/014d7f',
#  'dischord_records': '/m/014dd0',
#  'speculative_fiction': '/m/014dfn',
#  'sales': '/m/014dgf',
#  'ken_burns': '/m/014dm6',
#  'truman_capote': '/m/014dq7',
#  'travel': '/m/014dsx',
#  'mary_steenburgen': '/m/014g22',
#  'bill_evans': '/m/014g91',
#  'julie_delpy': '/m/014g9y',
#  'dwayne_johnson': '/m/014g_s',
#  'laurence_fishburne': '/m/014gf8',
#  'm*a*s*h': '/m/014gjp',
#  'zhang_yimou': '/m/014hdb',
#  'london_symphony_orchestra': '/m/014hr0',
#  'alternative_tentacles': '/m/014j0w',
#  'apple': '/m/014j1m',
#  'university_of_liverpool': '/m/014jyk',
#  'puppeteer': '/m/014kbl',
#  'arthur_kennedy': '/m/014kg4',
#  'crawley': '/m/014kj2',
#  'the_bad_and_the_beautiful': '/m/014kkm',
#  'stalag_17': '/m/014knw',
#  'die_another_day': '/m/014kq6',
#  'announcer': '/m/014ktf',
#  'steely_dan': '/m/014kyy',
#  'national_film_board_of_canada': '/m/014l4w',
#  'pretty_woman': '/m/014l6_',
#  'news_presenter': '/m/014l7h',
#  'star_trek:_nemesis': '/m/014lc_',
#  'oaxaca': '/m/014m1m',
#  'bachelor_of_arts': '/m/014mlp',
#  'star_trek:_insurrection': '/m/014nq4',
#  'alexandre_dumas': '/m/014nvr',
#  'nottingham_forest_f.c.': '/m/014nzp',
#  'oingo_boingo': '/m/014pg1',
#  'gene_wolfe': '/m/014ps4',
#  'keith_richards': '/m/014q2g',
#  'kingdom_of_great_britain': '/m/014tss',
#  'burl_ives': '/m/014v1q',
#  'cuba_gooding_jr.': '/m/014v6f',
#  'condoleezza_rice': '/m/014vk4',
#  'hangzhou': '/m/014vm4',
#  'sepsis': '/m/014w_8',
#  'hawaiian_islands': '/m/014wxc',
#  'rachel_weisz': '/m/014x77',
#  "king's_college_london": '/m/014xf6',
#  'anthony_head': '/m/014y6',
#  'choline': '/m/014yzm',
#  'george_carlin': '/m/014z8v',
#  'george_clooney': '/m/014zcr',
#  'bill_cosby': '/m/014zfs',
#  'dana_andrews': '/m/014zn0',
#  "you've_got_mail": '/m/014zwb',
#  'harvard_law_school': '/m/014zws',
#  'hurdy-gurdy': '/m/014zz1',
#  'jacqueline_bisset': '/m/015010',
#  'aleppo': '/m/01505k',
#  'river_phoenix': '/m/015076',
#  'david_boreanaz': '/m/01507p',
#  'nickelback': '/m/0150jk',
#  'bonn': '/m/0150n',
#  'hans_zimmer': '/m/0150t6',
#  'edward_norton': '/m/01515w',
#  'melvins': '/m/01516r',
#  'danzig': '/m/01518s',
#  'glenn_danzig': '/m/015196',
#  'triangle': '/m/0151b0',
#  'milla_jovovich': '/m/0151ns',
#  'ben_affleck': '/m/0151w_',
#  'dirk_bogarde': '/m/0151xv',
#  'peter_cushing': '/m/0151zx',
#  'richard_dreyfuss': '/m/01520h',
#  'jewel': '/m/0152cw',
#  'skeleton': '/m/0152n0',
#  'msnbc': '/m/0152x_',
#  'the_bronx': '/m/01531',
#  'dio': '/m/0153nq',
#  'biology': '/m/01540',
#  'university_of_tehran': '/m/015401',
#  'michelle_forbes': '/m/01541z',
#  'mark_hamill': '/m/0154d7',
#  'brampton': '/m/0154fs',
#  'mississauga': '/m/0154gx',
#  'belgium': '/m/0154j',
#  'cate_blanchett': '/m/0154qm',
#  'legion_of_honour': '/m/0154yf',
#  'cebu': '/m/0155j3',
#  'blues': '/m/0155w',
#  'berlin': '/m/0156q',
#  'darlington': '/m/0156ts',
#  'lesser_antilles': '/m/0157g9',
#  'bill_clinton': '/m/0157m',
#  'slasher_film': '/m/01585b',
#  'linda_ronstadt': '/m/015882',
#  'emma_thompson': '/m/0159h6',
#  'gonville_and_caius_college': '/m/0159r9',
#  'columbia_records': '/m/015_1q',
#  'neil_diamond': '/m/015_30',
#  'gillingham_f.c.': '/m/015_z1',
#  'star_trek_vi:_the_undiscovered_country': '/m/015bpl',
#  'critic': '/m/015btn',
#  'boyz_ii_men': '/m/015bwt',
#  'blessed_virgin_mary': '/m/015c1b',
#  'cynthia_nixon': '/m/015c2f',
#  'robert_duvall': '/m/015c4g',
#  'bob_hope': '/m/015cbq',
#  'cheltenham': '/m/015cj9',
#  'television_presenter': '/m/015cjr',
#  'medal_of_honor': '/m/015cl6',
#  'journey': '/m/015cqh',
#  'los_lobos': '/m/015cxv',
#  'tel_aviv_university': '/m/015cz0',
#  'lieutenant': '/m/015czt',
#  'ernest_borgnine': '/m/015d3h',
#  'rock_hudson': '/m/015dcj',
#  'trevor_howard': '/m/015dnt',
#  'maximilian_schell': '/m/015dqj',
#  'national_park_service': '/m/015dvh',
#  'ado_den_haag': '/m/015f47',
#  'britney_spears': '/m/015f7',
#  'brazil': '/m/0jwmp',
#  'western_michigan_university': '/m/015fs3',
#  'eastern_michigan_university': '/m/015fsv',
#  'royal_academy_of_arts': '/m/015g1w',
#  'band_of_brothers': '/m/015g28',
#  'bratislava': '/m/015g7',
#  "ryan_o'neal": '/m/015g_7',
#  'marcello_mastroianni': '/m/015gjr',
#  'hud': '/m/015gm8',
#  'alan_arkin': '/m/015grj',
#  'cliff_robertson': '/m/015gsv',
#  'alan_bates': '/m/015gw6',
#  'melvyn_douglas': '/m/015gy7',
#  'animator': '/m/015h31',
#  'berlin_international_film_festival': '/m/015hr',
#  'bible': '/m/015j7',
#  'british_columbia': '/m/015jr',
#  'gautama_buddha': '/m/015k7',
#  'epitaph_records': '/m/015kg1',
#  '1968_winter_olympics': '/m/015l4k',
#  'chuck_norris': '/m/015lhm',
#  'dulwich_college': '/m/015ln1',
#  'emilia-romagna': '/m/015m08',
#  'american_recordings': '/m/015mlw',
#  'lauryn_hill': '/m/015mrk',
#  'baruch_spinoza': '/m/015n8',
#  'glenda_jackson': '/m/015nhn',
#  'ken_russell': '/m/015njf',
#  'royal_academy_of_dramatic_art': '/m/015nl4',
#  'ralph_richardson': '/m/015np0',
#  'aamir_khan': '/m/015npr',
#  'carol_reed': '/m/015nvj',
#  'investment_bank': '/m/015p1m',
#  'janeane_garofalo': '/m/015p37',
#  'harry_dean_stanton': '/m/015p3p',
#  'bird': '/m/077q8x',
#  'southern_rock': '/m/015pdg',
#  'tobey_maguire': '/m/015pkc',
#  '1960_winter_olympics': '/m/015pkt',
#  'all_in_the_family': '/m/015pnb',
#  'nypd_blue': '/m/015ppk',
#  'bonnie_hunt': '/m/015pvh',
#  'ricky_gervais': '/m/015pxr',
#  'perak': '/m/015q02',
#  'university_of_kansas': '/m/015q1n',
#  'julie_christie': '/m/015q43',
#  'bulgaria': '/m/015qh',
#  'paul_winfield': '/m/015qq1',
#  'julia': '/m/015qqg',
#  'serpico': '/m/015qsq',
#  'art_carney': '/m/015qt5',
#  "mobile_suit_gundam:_char's_counterattack": '/m/015qy1',
#  'james_whitmore': '/m/015qyf',
#  'roddy_mcdowall': '/m/015rhv',
#  'michael_gambon': '/m/015rkw',
#  'georg_solti': '/m/015rmq',
#  'the_jackson_5': '/m/015srx',
#  'elijah_wood': '/m/015t56',
#  'bernard_hill': '/m/015t7v',
#  'ethan_hawke': '/m/015v3r',
#  'carnatic_music': '/m/015vgc',
#  'bob_hoskins': '/m/015vq_',
#  'michael_hordern': '/m/015vql',
#  'tiny_toon_adventures': '/m/015w8_',
#  'television_film': '/m/015w9s',
#  'bernard_herrmann': '/m/015wc0',
#  'chicano_rock': '/m/015wd7',
#  'roy_scheider': '/m/015wfg',
#  'being_there': '/m/015whm',
#  'john_hurt': '/m/015wnl',
#  'goldsmiths,_university_of_london': '/m/015wy_',
#  'curtis_mayfield': '/m/015x1f',
#  'the_adventures_of_baron_munchausen': '/m/015x74',
#  'etta_james': '/m/015xp4',
#  'pune': '/m/015y2q',
#  'dickinson_college': '/m/015y3j',
#  'swing_music': '/m/015y_n',
#  'lilo_&_stitch': '/m/015ynm',
#  'serena_williams': '/m/015z4j',
#  'dan_curtis': '/m/015zql',
#  'la_jolla': '/m/015zxh',
#  'california_institute_of_the_arts': '/m/015zyd',
#  'hercules': '/m/016017',
#  'tulane_university': '/m/0160nk',
#  'the_bahamas': '/m/0160w',
#  'bahrain': '/m/0161c',
#  'avril_lavigne': '/m/0161c2',
#  'angela_lansbury': '/m/0161h5',
#  'bournemouth': '/m/0161jj',
#  'easy_listening': '/m/0161rf',
#  'lenny_kravitz': '/m/0161sp',
#  'bangladesh': '/m/0162b',
#  'brett_ratner': '/m/0162c8',
#  'senate_of_australia': '/m/0162kb',
#  'barbados': '/m/0162v',
#  'in_&_out': '/m/01633c',
#  'manchester_city_f.c.': '/m/01634x',
#  'the_isley_brothers': '/m/016376',
#  'gladys_knight': '/m/0163kf',
#  'earth,_wind_&_fire': '/m/0163m1',
#  'isaac_hayes': '/m/0163r3',
#  'sharon_osbourne': '/m/0163t3',
#  'belarus': '/m/0163v',
#  'electronic_body_music': '/m/0163zw',
#  'persea_americana': '/m/01645p',
#  'picture_book': '/m/016475',
#  'belize': '/m/0164b',
#  'david_hasselhoff': '/m/0164nb',
#  'the_world_is_not_enough': '/m/0164qt',
#  'robert_shaw': '/m/0164r9',
#  'benin': '/m/0164v',
#  'conrad_hall': '/m/0164w8',
#  'frank_loesser': '/m/0164y7',
#  'bermuda': '/m/0165b',
#  'bolivia': '/m/0165v',
#  'tubular_bells': '/m/016622',
#  'natural_history': '/m/01664_',
#  'henan': '/m/01669b',
#  'hunan': '/m/01669t',
#  'bosnia_and_herzegovina': '/m/0166b',
#  'yunnan': '/m/0166b8',
#  'jiangsu': '/m/0166c7',
#  'botswana': '/m/0166v',
#  'jaipur': '/m/016722',
#  'clive_davis': '/m/016732',
#  'toy_piano': '/m/01679d',
#  'uriah_heep': '/m/0167_s',
#  'hepatitis_b': '/m/0167bx',
#  'rick_springfield': '/m/0167km',
#  'bridgeport': '/m/0167q3',
#  'brunei': '/m/0167v',
#  'ryan_adams': '/m/0167v4',
#  'thin_lizzy': '/m/0167xy',
#  'kool_&_the_gang': '/m/016890',
#  'jimmy_buffett': '/m/0168cl',
#  'brittany_murphy': '/m/0168dy',
#  'spartacus': '/m/0168ls',
#  'johnson_&_johnson': '/m/0168nq',
#  'gerry_anderson': '/m/0168ql',
#  'british_virgin_islands': '/m/0168t',
#  'stevie_ray_vaughan': '/m/01693z',
#  'burkina_faso': '/m/01699',
#  'matt_damon': '/m/0169dl',
#  'burundi': '/m/0169t',
#  'chris_rock': '/m/016_mj',
#  'east_coast_hip_hop': '/m/016_nr',
#  'west_coast_hip_hop': '/m/016_rm',
#  'southern_hip_hop': '/m/016_v3',
#  'michael_powell': '/m/016bx2',
#  'venus_williams': '/m/016cff',
#  'gospel_music': '/m/016cjb',
#  'motown_records': '/m/016ckq',
#  'alternative_rock': '/m/016clz',
#  'roots_reggae': '/m/016cyt',
#  'anthony_perkins': '/m/016dgz',
#  'men_in_black': '/m/016dj8',
#  'colin_wilson': '/m/016dmx',
#  'john_osborne': '/m/016dp0',
#  'marianne_faithfull': '/m/016dsy',
#  'christopher_walken': '/m/016fjj',
#  'professor': '/m/016fly',
#  'no_doubt': '/m/016fmf',
#  'gwen_stefani': '/m/016fnb',
#  'the_usual_suspects': '/m/016fyc',
#  'koblenz': '/m/016gb5',
#  'john_gielgud': '/m/016ggh',
#  'alexander_korda': '/m/016ghw',
#  'peter_ustinov': '/m/016gkf',
#  'reading_f.c.': '/m/016gp5',
#  'derek_jacobi': '/m/016gr2',
#  'kris_kristofferson': '/m/016h4r',
#  'kensal_green_cemetery': '/m/016h5l',
#  'maurice_gibb': '/m/016h9b',
#  'continental_army': '/m/016hjr',
#  'pier_paolo_pasolini': '/m/016hvl',
#  'hank_williams_jr.': '/m/016j2t',
#  'denholm_elliott': '/m/016j68',
#  'barry_gibb': '/m/016jfw',
#  'jam_band': '/m/016jhr',
#  'johnny_mercer': '/m/016jll',
#  'folk_rock': '/m/016jny',
#  'british_columbia_liberal_party': '/m/016k4x',
#  'itzhak_perlman': '/m/016k62',
#  'ben_kingsley': '/m/016k6x',
#  'f._murray_abraham': '/m/016kb7',
#  'sam_waterston': '/m/016kft',
#  'william_hurt': '/m/016khd',
#  'lil_wayne': '/m/016kjs',
#  'james_garner': '/m/016kkx',
#  'mona_lisa': '/m/016ks5',
#  'james_woods': '/m/016ks_',
#  'master_p': '/m/016ksk',
#  'salvador': '/m/09wwlj',
#  'big': '/m/016ky6',
#  'flashdance': '/m/016kz1',
#  'the_white_stripes': '/m/016l09',
#  'ron_paul': '/m/016lh0',
#  'sepultura': '/m/016lj_',
#  'the_prodigy': '/m/016lmg',
#  'jonathan_lynn': '/m/016lv3',
#  'judas_priest': '/m/016m5c',
#  'attorneys_in_the_united_states': '/m/016m9h',
#  'billy_elliot': '/m/016mhd',
#  'dessau': '/m/016n7b',
#  'university_of_western_ontario': '/m/016ndm',
#  'julie_walters': '/m/016nff',
#  'pj_harvey': '/m/016ntp',
#  'paul_oakenfold': '/m/016nvh',
#  'nelly': '/m/016pns',
#  "destiny's_child": '/m/016ppr',
#  'billy_ray_cyrus': '/m/016qtt',
#  'south_tyrol': '/m/016qwt',
#  '1900_summer_olympics': '/m/016r9z',
#  'tracy_chapman': '/m/016s0m',
#  'john_fogerty': '/m/016s_5',
#  'stetson_university': '/m/016sd3',
#  'dwight_yoakam': '/m/016sp_',
#  'george_strait': '/m/016sqs',
#  'randy_travis': '/m/016srn',
#  'randy_newman': '/m/016szr',
#  'john_mellencamp': '/m/016t00',
#  'a-ha': '/m/016t0h',
#  "master's_degree": '/m/016t_3',
#  'lisa_kudrow': '/m/016tb7',
#  'david_schwimmer': '/m/016tbr',
#  '20th_century_fox': '/m/016tt2',
#  'the_cosby_show': '/m/016tvq',
#  'universal_studios': '/m/016tw3',
#  'chengdu': '/m/016v46',
#  'heather_graham': '/m/016vg8',
#  'caper_story': '/m/016vh2',
#  'simple_minds': '/m/016vj5',
#  'the_cars': '/m/016vn3',
#  'lionel_richie': '/m/016vqk',
#  'macalester_college': '/m/016w7b',
#  'rotherham': '/m/016wrq',
#  'sailor': '/m/016wtf',
#  'john_cale': '/m/016wvy',
#  'haverford_college': '/m/016wyn',
#  'peru': '/m/016wzw',
#  'hugh_grant': '/m/016xh5',
#  'simon_callow': '/m/016xk5',
#  'shoegazing': '/m/016y3j',
#  'cape_fear': '/m/016y_f',
#  'power_pop': '/m/016ybr',
#  'peter_finch': '/m/016ynj',
#  'hugo_weaving': '/m/016ypb',
#  'edward_james_olmos': '/m/016yr0',
#  'daniel_day-lewis': '/m/016yvw',
#  'henry_v': '/m/016ywb',
#  'jeremy_irons': '/m/016ywr',
#  'reversal_of_fortune': '/m/016yxn',
#  'sam_shepard': '/m/016yzz',
#  'irving_thalberg': '/m/016z1c',
#  'glen_campbell': '/m/016z1t',
#  'robert_downey,_jr.': '/m/016z2j',
#  'the_fisher_king': '/m/016z43',
#  'singer-songwriter': '/m/016z4k',
#  'richard_crenna': '/m/016z51',
#  'chaplin': '/m/016z5x',
#  'stephen_rea': '/m/016z68',
#  'the_madness_of_king_george': '/m/016z7s',
#  'nixon': '/m/016z9n',
#  'leelee_sobieski': '/m/016zdd',
#  'happy_days': '/m/016zfm',
#  'alternative_country': '/m/016zgj',
#  'ian_holm': '/m/016zp5',
#  'porco_rosso': '/m/016ztl',
#  'nepal': '/m/016zwt',
#  'europop': '/m/016zxr',
#  'the_hurricane': '/m/0170_p',
#  'batman:_the_animated_series': '/m/0170k0',
#  'geoffrey_rush': '/m/0170pk',
#  'ralph_fiennes': '/m/0170qf',
#  'woody_harrelson': '/m/0170s4',
#  'the_people_vs._larry_flynt': '/m/0170th',
#  'peter_fonda': '/m/0170vn',
#  'gods_and_monsters': '/m/0170xl',
#  'affliction': '/m/0170yd',
#  'american_history_x': '/m/0170z3',
#  'javier_bardem': '/m/01713c',
#  'ed_harris': '/m/017149',
#  'quills': '/m/017180',
#  'training_day': '/m/01718w',
#  'ali': '/m/02rzmzk',
#  'kaunas': '/m/0171b8',
#  'australian_greens': '/m/0171c7',
#  'tom_wilkinson': '/m/0171cm',
#  'george_seaton': '/m/0171lb',
#  'westminster_school': '/m/01722w',
#  'chongqing': '/m/017236',
#  'colby_college': '/m/0172jm',
#  'doom_metal': '/m/0172rj',
#  'chicago_blues': '/m/01730d',
#  'delta_blues': '/m/017323',
#  'rockabilly': '/m/017371',
#  'funk_metal': '/m/01738f',
#  'small_soldiers': '/m/01738w',
#  'glam_metal': '/m/0173b0',
#  'new_plymouth': '/m/0173kj',
#  'marlborough_college': '/m/0173s9',
#  'eastbourne': '/m/0174qm',
#  'jump_blues': '/m/01750n',
#  'country_blues': '/m/017510',
#  'surf_music': '/m/01756d',
#  'porto_alegre': '/m/017575',
#  'fc_bayern_munich': '/m/0175rc',
#  'hannover_96': '/m/0175tv',
#  'sienna_guillory': '/m/0175wg',
#  'electric_blues': '/m/0175yg',
#  'dream_pop': '/m/0175zz',
#  'cobra': '/m/01771z',
#  'stavanger': '/m/01773g',
#  'benito_mussolini': '/m/0177g',
#  'f.c._porto': '/m/0177gl',
#  'harold_lloyd': '/m/0177s6',
#  'virginia_commonwealth_university': '/m/0177sq',
#  'brussels-capital_region': '/m/0177z',
#  'the_doobie_brothers': '/m/0178_w',
#  'boeing': '/m/0178g',
#  'inxs': '/m/0178kd',
#  'tim_rice': '/m/0178rl',
#  'dire_straits': '/m/017959',
#  'walt_disney_pictures': '/m/01795t',
#  'peter_frampton': '/m/01797x',
#  'richmond': '/m/0p9nv',
#  'huntington': '/m/0n6bs',
#  'molde_fk': '/m/017_1x',
#  'vojvodina': '/m/017_29',
#  'chelmsford': '/m/017_4z',
#  'crewe': '/m/017_cl',
#  "the_b-52's": '/m/017_hq',
#  'james_baldwin': '/m/017_pb',
#  'film_score': '/m/017_qw',
#  'ayumi_hamasaki': '/m/017b2p',
#  'darren_aronofsky': '/m/017c87',
#  'stoke-on-trent': '/m/017cjb',
#  'byzantine_empire': '/m/017cw',
#  'university_of_british_columbia': '/m/017cy9',
#  'hampshire_college': '/m/017d77',
#  '8_mile': '/m/017d93',
#  'power_rangers': '/m/017dbx',
#  'mighty_morphin_power_rangers': '/m/017dcd',
#  'norman_lear': '/m/017dpj',
#  'second_baseman': '/m/02rsl1',
#  'magic_knight_rayearth': '/m/017dtf',
#  'law_&_order': '/m/017f3m',
#  'stephen_stills': '/m/017f4y',
#  'biography': '/m/017fp',
#  'imax': '/m/017fx5',
#  'roger_waters': '/m/017g21',
#  'edward_g._robinson': '/m/017g2y',
#  'the_lord_of_the_rings:_the_fellowship_of_the_ring': '/m/017gl1',
#  'the_lord_of_the_rings:_the_two_towers': '/m/017gm7',
#  'essen': '/m/017gry',
#  'penelope_wilton': '/m/017gxw',
#  'phillips_academy': '/m/017hnw',
#  'bhangra': '/m/017ht',
#  'epsom': '/m/017j4q',
#  'beastie_boys': '/m/017j6',
#  'northwestern_university': '/m/017j69',
#  'surrey': '/m/0cxgc',
#  'the_lord_of_the_rings:_the_return_of_the_king': '/m/017jd9',
#  'british_isles': '/m/017jq',
#  'united_artists': '/m/017jv5',
#  'oh!_what_a_lovely_war': '/m/017kct',
#  'david_warner': '/m/017khj',
#  'willy_wonka_&_the_chocolate_factory': '/m/017kz7',
#  'benny_andersson': '/m/017l4',
#  'capitol_records': '/m/017l96',
#  'blondie': '/m/017lb_',
#  'roger_moore': '/m/017lqp',
#  'university_of_tokyo': '/m/017lvd',
#  'heather_locklear': '/m/017m2y',
#  'def_leppard': '/m/017mbb',
#  'blade_runner': '/m/017n9',
#  'john_malkovich': '/m/017r13',
#  'bertolt_brecht': '/m/017r2',
#  'royal_college_of_music': '/m/017rbx',
#  'columbia_pictures': '/m/017s11',
#  'amyotrophic_lateral_sclerosis': '/m/017s1k',
#  'kansai_region': '/m/017t44',
#  'college_of_william_&_mary': '/m/017v3q',
#  'wellesley_college': '/m/017v71',
#  'bavaria': '/m/017v_',
#  'nine_network': '/m/017vb_',
#  'ayr': '/m/017vdg',
#  'trevor_horn': '/m/017vkx',
#  'bremen': '/m/017w_',
#  'brandenburg': '/m/017wh',
#  'loretta_lynn': '/m/017xm3',
#  'university_of_pennsylvania_law_school': '/m/017y26',
#  'depauw_university': '/m/017y6l',
#  'gil_scott-heron': '/m/017yfz',
#  'tom_green': '/m/017yxq',
#  'house_of_hanover': '/m/017yzc',
#  'memento': '/m/017z49',
#  'juilliard_school': '/m/017z88',
#  'hibernian_f.c.': '/m/017znw',
#  'illinois_state_university': '/m/017zq0',
#  'university_of_copenhagen': '/m/017ztv',
#  'eric_bana': '/m/018009',
#  'immortality': '/m/01803s',
#  'er': '/m/0180mw',
#  'richard_thompson': '/m/0180w8',
#  'carly_simon': '/m/01817f',
#  'rca_records': '/m/0181dw',
#  'mca_inc.': '/m/0181hw',
#  'sheffield_wednesday_f.c.': '/m/0182r9',
#  'chihuahua': '/m/0183z2',
#  'helen_hayes': '/m/018417',
#  'john_rhys-davies': '/m/01846t',
#  'christopher_nolan': '/m/0184dt',
#  'guy_pearce': '/m/0184jc',
#  'curtis_hanson': '/m/0184jw',
#  'labyrinth': '/m/0184tc',
#  'university_of_missouri': '/m/0187nd',
#  'the_wb': '/m/0187wh',
#  'muse': '/m/0187x8',
#  'burt_reynolds': '/m/0187y5',
#  'jena': '/m/018_7x',
#  'kathleen_turner': '/m/018_lb',
#  'viacom': '/m/018_q8',
#  'starbucks': '/m/018c_r',
#  'arunachal_pradesh': '/m/018ckn',
#  'organisation_for_economic_co-operation_and_development': '/m/018cqq',
#  '2010_winter_olympics': '/m/018ctl',
#  'toronto_international_film_festival': '/m/018cvf',
#  'saskatoon': '/m/018d5b',
#  'jack_bruce': '/m/018d6l',
#  'joaquin_phoenix': '/m/018db8',
#  'guelph': '/m/018dcy',
#  'barrie': '/m/018dh3',
#  'belleville': '/m/0sgtz',
#  'brantford': '/m/018djs',
#  'burlington': '/m/0sv6n',
#  'colm_meaney': '/m/018dnt',
#  'klaus_voormann': '/m/018dyl',
#  'blazing_saddles': '/m/018f8',
#  'bochum': '/m/018f94',
#  'lana_turner': '/m/018fmr',
#  'bruce_sterling': '/m/018fq',
#  'matt_frewer': '/m/018fwv',
#  'adrian_belew': '/m/018gkb',
#  'cheap_trick': '/m/018gm9',
#  'markham': '/m/018gmr',
#  'burt_bacharach': '/m/018gqj',
#  'will_ferrell': '/m/018grr',
#  'comedian': '/m/018gz8',
#  'bisexuality': '/m/018h2',
#  'oldham': '/m/018h8j',
#  'cooking_show': '/m/018hzk',
#  'banjo': '/m/018j2',
#  'ōsaka_prefecture': '/m/018jcq',
#  'nagano_prefecture': '/m/018jk2',
#  'miyagi_prefecture': '/m/018jkl',
#  'chiba_prefecture': '/m/018jmn',
#  'hiroshima_prefecture': '/m/018jn4',
#  'top_gun': '/m/018js4',
#  'baseball': '/m/018jz',
#  'thrissur': '/m/018k8r',
#  'stv': '/m/018kcp',
#  'mezzo-soprano': '/m/018l5l',
#  'newmarket': '/m/018lbg',
#  'niagara_falls': '/m/0y3k9',
#  'oakville': '/m/018ldw',
#  'stoner_rock': '/m/018lg0',
#  '1912_summer_olympics': '/m/018ljb',
#  'orange_free_state': '/m/018lkp',
#  'fitzwilliam_college': '/m/018m5q',
#  'holy_cross_cemetery': '/m/018mlg',
#  'westwood_village_memorial_park_cemetery': '/m/018mm4',
#  'forest_lawn_memorial_park': '/m/018mmw',
#  'hollywood_forever_cemetery': '/m/018mrd',
#  'easyjet': '/m/018mxj',
#  'oshawa': '/m/018n1k',
#  'missy_elliott': '/m/018n6m',
#  'dixie_chicks': '/m/018ndc',
#  'the_animatrix': '/m/018nnz',
#  'pierce_brosnan': '/m/018p4y',
#  'iheartmedia': '/m/018p5f',
#  'martie_maguire': '/m/018phr',
#  'emily_robison': '/m/018pj3',
#  'fukuoka_prefecture': '/m/018q42',
#  'bernard_law_montgomery,_1st_viscount_montgomery_of_alamein': '/m/018q7',
#  '1908_summer_olympics': '/m/018qb4',
#  'saitama_prefecture': '/m/018qd6',
#  'rosalind_russell': '/m/018qpb',
#  'shizuoka_prefecture': '/m/018qpq',
#  'robert_young': '/m/018qql',
#  'ibaraki_prefecture': '/m/018qt8',
#  'choreography': '/m/018rn4',
#  'israelis': '/m/018s6c',
#  'university_of_st_andrews': '/m/018sg9',
#  'pete_postlethwaite': '/m/018swb',
#  'colorado_college': '/m/018t8f',
#  'blaxploitation': '/m/018td',
#  'hammer_film_productions': '/m/018tnx',
#  'niigata_prefecture': '/m/018txg',
#  'russ_meyer': '/m/018ty9',
#  'lebanon_war': '/m/018vbf',
#  'bass_guitar': '/m/018vs',
#  'gulf_war': '/m/018w0j',
#  'basketball': '/m/018w8',
#  'academy_award_for_best_sound_editing': '/m/018wdw',
#  'parliamentary_system': '/m/018wl5',
#  'academy_award_for_best_documentary,_short_subject': '/m/018wng',
#  '1904_summer_olympics': '/m/018wrk',
#  'salford': '/m/018x0q',
#  'brian_eno': '/m/018x3',
#  'dave_matthews': '/m/018y2s',
#  'roger_taylor': '/m/018y81',
#  'alec_baldwin': '/m/018ygt',
#  'william_baldwin': '/m/018yj6',
#  'plovdiv': '/m/018ym2',
#  'psychobilly': '/m/018ysx',
#  'cowpunk': '/m/018yv3',
#  'marlee_matlin': '/m/018z_c',
#  'canadian_armed_forces': '/m/018zqj',
#  'canadian_army': '/m/018zsw',
#  'tom_wolfe': '/m/018zvb',
#  'chris_tucker': '/m/01900g',
#  'church_of_scotland': '/m/0190_8',
#  'space_rock': '/m/0190_q',
#  'chess_records': '/m/0190vc',
#  'power_metal': '/m/0190xp',
#  ...}

# %%
rname2idx = {}
for k in ds.training.relation_id_to_label:
    rname = ds.training.relation_id_to_label[k]
    rname_shortened = rname[rname.rfind('/')+1:]
    rname2idx[rname_shortened] = k
rname2idx
# Out:
# {'position': 1325,
#  'team': 1171,
#  'coach': 25,
#  'position_s': 1178,
#  'season': 1194,
#  'players': 1096,
#  'player': 1326,
#  'architectural_style': 44,
#  'structures_designed': 32,
#  'structure': 33,
#  'architects': 34,
#  'examples': 35,
#  'building_function': 36,
#  'buildings': 37,
#  'citytown': 979,
#  'state_province_region': 981,
#  'type_of_museum': 40,
#  'architect': 43,
#  'currency': 1315,
#  'owner': 765,
#  'museums': 47,
#  'category': 989,
#  'objects': 49,
#  'orbited_by': 50,
#  'orbits': 51,
#  'planetary_system': 52,
#  'star_system': 53,
#  'aircraft_models_made': 54,
#  'aircraft_type': 55,
#  'aircraft_owner': 56,
#  'aircraft_model': 57,
#  'aircraft_of_this_type': 58,
#  'airport': 59,
#  'cities_served': 67,
#  'alliance': 61,
#  'focus_cities': 62,
#  'hubs': 63,
#  'member_airlines': 64,
#  'flight_destination': 65,
#  'airline': 66,
#  'focus_city_for': 68,
#  'hub_for': 69,
#  'serves': 70,
#  'presented_by': 72,
#  'category_of': 73,
#  'disciplines_or_subjects': 74,
#  'nominee': 75,
#  'award_nominee': 90,
#  'nominated_for': 91,
#  'presenting_organization': 78,
#  'award_winner': 1155,
#  'ceremony': 100,
#  'honored_for': 101,
#  'award': 1154,
#  'awards_in_this_discipline': 85,
#  'award_categories_presented': 92,
#  'awards_presented': 93,
#  'instance_of_recurring_competition': 102,
#  'discipline': 103,
#  'inductee': 108,
#  'halls_of_fame': 105,
#  'hall_of_fame': 107,
#  'list': 110,
#  'item': 111,
#  'individual_competitions': 112,
#  'administrative_area_type': 113,
#  'administrative_children': 114,
#  'administrative_parent': 115,
#  'capital': 802,
#  'oscar_show_hosted': 117,
#  'activist_organizations': 118,
#  'activists': 119,
#  'area_of_activism': 121,
#  'celebrities_impersonated': 122,
#  'comedy_genres': 123,
#  'comedians_in_this_genre': 124,
#  'member': 1001,
#  'group': 933,
#  'impersonated_by': 127,
#  'particular_instances': 128,
#  'original_ideas': 129,
#  'instance_of_abstract_moral_dispute': 130,
#  'innovator': 131,
#  'city': 132,
#  'country': 1198,
#  'state': 1323,
#  'company_involved': 135,
#  'develops_treatments_for_disease': 136,
#  'collective': 138,
#  'first_place': 146,
#  'second_place': 147,
#  'tournament': 186,
#  'teammate': 145,
#  'guilty_of': 171,
#  'sentence_type': 149,
#  'victim_s': 150,
#  'crime': 151,
#  'crime_type': 152,
#  'entity_involved': 153,
#  'attack_event': 154,
#  'people_who_follow_this_diet': 155,
#  'diet': 156,
#  'ecosystem_members': 157,
#  'belongs_to_ecosystem_s': 158,
#  'newspaper': 159,
#  'election': 160,
#  'endorsee': 161,
#  'type_of_festival': 162,
#  'performer': 163,
#  'recurring_festivals_of_this_type': 164,
#  'hair_color': 166,
#  'fashion_models_with_this_hair_color': 167,
#  'included_in_crimes': 168,
#  'includes_crimes': 169,
#  'convicted_person': 173,
#  'victims_of_this_crime_type': 172,
#  'sport': 1195,
#  'mythology': 175,
#  'mythical_creatures': 176,
#  'power_station': 177,
#  'fuel_type': 178,
#  'produce': 182,
#  'location': 1221,
#  'seasonal_months': 183,
#  'countries_within': 184,
#  'continent': 185,
#  'news_reporting_organisation': 188,
#  'event': 189,
#  'subject_area': 192,
#  'nobel_prize_winner': 191,
#  'included_in': 193,
#  'includes': 1064,
#  'things_of_this_type': 195,
#  'parodies': 196,
#  'parody_of': 197,
#  'patron': 198,
#  'client': 199,
#  'dog_breed': 200,
#  'cities': 671,
#  'color': 252,
#  'gender': 1309,
#  'dog_breeds': 206,
#  'customer': 207,
#  'product': 208,
#  'participant': 1053,
#  'restaurant': 468,
#  'company': 1334,
#  'business_location': 215,
#  'religion': 1062,
#  'supported_organization': 219,
#  'designer': 221,
#  'fashion_wearer': 222,
#  'endorser': 223,
#  'shopper': 224,
#  'vacationer': 225,
#  'supporter': 226,
#  'consumer': 227,
#  'diner': 229,
#  'type_of_rugby': 230,
#  'venerated_in': 231,
#  'cast_members': 232,
#  'found_in': 235,
#  'time_zone': 236,
#  'contact_category': 237,
#  'product_or_service': 238,
#  'service_language': 239,
#  'service_location': 990,
#  'source': 823,
#  'character': 1274,
#  'language': 774,
#  'program': 1264,
#  'actor': 1293,
#  'sex': 485,
#  'horses_of_this_color': 255,
#  'horses_from_this_location': 256,
#  'horses_of_this_sex': 257,
#  'twinned_towns': 258,
#  'member_of_team': 260,
#  'members': 1024,
#  'current_club': 265,
#  'national_team': 263,
#  'society': 269,
#  'teams': 1196,
#  'ending_season': 279,
#  'last_statistics_season': 280,
#  'starting_season': 281,
#  'league': 1175,
#  'breed_of': 311,
#  'place_of_origin': 312,
#  'breed_group': 313,
#  'registry': 314,
#  'breed': 317,
#  'breeds_originating_here': 316,
#  'breeds': 318,
#  'organism_type': 319,
#  'higher_classification': 321,
#  'lower_classifications': 322,
#  'organisms_of_this_type': 323,
#  'rank': 900,
#  'organism_classifications': 325,
#  'school_or_movement': 326,
#  'series_written_or_contributed_to': 327,
#  'works_written': 328,
#  'genre': 1268,
#  'works': 330,
#  'author_s': 331,
#  'magazines_in_this_genre': 333,
#  'circulation_areas': 334,
#  'newspapers_owned': 338,
#  'publisher': 452,
#  'subjects': 1282,
#  'periodical': 342,
#  'periodicals': 343,
#  'associated_authors': 344,
#  'author': 345,
#  'original_language': 346,
#  'content': 359,
#  'area_served': 879,
#  'distributor': 564,
#  'artist': 938,
#  'broadcast': 353,
#  'producer': 1290,
#  'distributes': 358,
#  'produces': 360,
#  'stations': 361,
#  'format': 362,
#  'radio_stations': 364,
#  'tv_stations': 366,
#  'owned_asset': 368,
#  'organization': 1071,
#  'role': 1207,
#  'industry': 378,
#  'companies_of_this_type': 384,
#  'brand': 385,
#  'consumer_product': 386,
#  'person': 1288,
#  'title': 1087,
#  'companies': 390,
#  'sponsored_recipient': 393,
#  'sponsored_by': 394,
#  'friend': 395,
#  'sexual_orientation': 396,
#  'celebrity': 398,
#  'solvent': 399,
#  'created_by': 407,
#  'primary_universe': 401,
#  'regular_featured_appearances': 402,
#  'characters_created': 403,
#  'series_created': 404,
#  'characters_primarily_appearing_in_this_universe': 405,
#  'comic_book_series_published': 406,
#  'featured_characters': 408,
#  'annotations': 410,
#  'topic': 420,
#  'subject_of': 414,
#  'resource': 417,
#  'operating_system': 436,
#  'manufacturer': 422,
#  'computer_models': 423,
#  'developer': 448,
#  'includes_os_versions': 425,
#  'parent_os': 426,
#  'operating_systems_developed': 427,
#  'dialects': 769,
#  'influenced': 759,
#  'influenced_by': 760,
#  'language_designers': 431,
#  'language_paradigms': 432,
#  'parent_language': 433,
#  'languages_designed': 434,
#  'languages': 1269,
#  'languages_used': 438,
#  'license': 439,
#  'software_genre': 440,
#  'software': 441,
#  'software_in_genre': 442,
#  'games': 457,
#  'voice_actor': 460,
#  'cvg_genre': 446,
#  'designers': 447,
#  'game_series': 449,
#  'gameplay_modes': 450,
#  'prequel': 590,
#  'sequel': 598,
#  'games_designed': 455,
#  'games_developed': 456,
#  'games_published': 458,
#  'game': 463,
#  'games_in_series': 461,
#  'games_with_this_mode': 464,
#  'split_to': 465,
#  'dishes': 657,
#  'ingredients': 653,
#  'cuisine': 656,
#  'advisees': 470,
#  'advisors': 471,
#  'institution': 1030,
#  'research_areas': 473,
#  'major_field_of_study': 1031,
#  'minor': 498,
#  'specialization': 499,
#  'student': 500,
#  'campuses': 480,
#  'colors': 1174,
#  'mascot': 482,
#  'parent_institution': 483,
#  'school_type': 484,
#  'sports_teams': 486,
#  'degree': 1029,
#  'subsidiary_or_constituent_schools': 492,
#  'educational_institution': 493,
#  'academics_in_this_field': 494,
#  'subdiscipline_of': 501,
#  'subdisciplines': 502,
#  'colleges_and_universities': 503,
#  'founded_location': 505,
#  'highest_grade_taught': 506,
#  'lowest_grade_taught': 507,
#  'school_district': 508,
#  'schools_of_this_kind': 509,
#  'locations_served': 510,
#  'schools': 511,
#  'school': 1152,
#  'fraternities_and_sororities': 514,
#  'sponsor': 519,
#  'venue': 518,
#  'characters_of_this_gender': 520,
#  'characters_with_this_occupation': 521,
#  'characters_with_this_ability': 522,
#  'characters_of_this_rank': 523,
#  'characters_of_this_species': 524,
#  'characters_of_this_ethnicity': 525,
#  'appears_in_these_fictional_universes': 526,
#  'based_on': 527,
#  'character_created_by': 528,
#  'children': 1028,
#  'ethnicity': 1034,
#  'spouses': 533,
#  'occupation': 534,
#  'parents': 1038,
#  'place_of_birth': 1039,
#  'powers_or_abilities': 537,
#  'partner': 539,
#  'siblings': 540,
#  'species': 541,
#  'fictional_characters_created': 542,
#  'employee': 543,
#  'fictional_characters_born_here': 544,
#  'works_set_here': 547,
#  'characters': 546,
#  'representations_in_fiction': 548,
#  'part_of_these_fictional_universes': 549,
#  'setting': 550,
#  'film': 645,
#  'special_performance_type': 1276,
#  'cinematography': 560,
#  'costume_design_by': 561,
#  'directed_by': 563,
#  'film_distribution_medium': 565,
#  'region': 772,
#  'edited_by': 570,
#  'executive_produced_by': 572,
#  'featured_film_locations': 573,
#  'film_art_direction_by': 574,
#  'film_casting_director': 575,
#  'film_festivals': 576,
#  'film_format': 624,
#  'film_production_design_by': 578,
#  'film_series': 579,
#  'film_set_decoration_by': 580,
#  'music': 584,
#  'crewmember': 626,
#  'film_crew_role': 616,
#  'film_company': 587,
#  'type_of_appearance': 636,
#  'produced_by': 591,
#  'production_companies': 592,
#  'film_regional_debut_venue': 593,
#  'film_release_distribution_medium': 594,
#  'film_release_region': 596,
#  'type_of_film_cut': 597,
#  'story_by': 602,
#  'written_by': 604,
#  'films_art_directed': 605,
#  'films_casting_directed': 606,
#  'costume_design_for_film': 614,
#  'performed_by': 619,
#  'individual_festivals': 620,
#  'festival': 622,
#  'films': 641,
#  'films_in_this_genre': 625,
#  'featured_in_films': 628,
#  'films_production_designed': 629,
#  'films_in_series': 630,
#  'film_sets_designed': 631,
#  'film_story_credits': 632,
#  'films_executive_produced': 640,
#  'countries_formerly_used': 646,
#  'countries_used': 647,
#  'followers': 648,
#  'follows_diet': 649,
#  'compatible_ingredients': 650,
#  'incompatible_ingredients': 651,
#  'nutrient': 654,
#  'compatible_with_dietary_restrictions': 655,
#  'incompatible_with_dietary_restrictions': 658,
#  'boardgames': 659,
#  'islands': 660,
#  'features': 662,
#  'body_of_water': 663,
#  'island_group': 664,
#  'islands_in_group': 665,
#  'basin_countries': 670,
#  'lake_type': 668,
#  'lakes_of_this_type': 669,
#  'mouth': 672,
#  'office': 673,
#  'countries': 674,
#  'jurisdiction': 695,
#  'appointed_by': 1007,
#  'district_represented': 739,
#  'governmental_body': 740,
#  'jurisdiction_of_office': 741,
#  'legislative_sessions': 742,
#  'office_holder': 733,
#  'office_position_or_title': 743,
#  'offices': 683,
#  'governmental_body_if_any': 685,
#  'basic_title': 738,
#  'body_this_is_a_component_of': 693,
#  'component_bodies': 694,
#  'offices_positions': 703,
#  'sessions': 704,
#  'agencies': 705,
#  'government_bodies': 713,
#  'government_positions': 714,
#  'symbol': 715,
#  'legislature': 716,
#  'political_parties': 734,
#  'ideology': 735,
#  'politician': 736,
#  'party': 744,
#  'hockey_position': 751,
#  'peers': 761,
#  'parent_category': 762,
#  'sub_categories': 763,
#  'sites': 766,
#  'website': 767,
#  'countries_spoken_in': 768,
#  'language_family': 770,
#  'main_country': 771,
#  'writing_system': 773,
#  'judge': 777,
#  'inventor': 778,
#  'inventions': 779,
#  'court': 780,
#  'first_level_division_of': 783,
#  'second_level_division_of': 784,
#  'administrative_division': 830,
#  'administrative_divisions': 786,
#  'currency_formerly_used': 788,
#  'currency_used': 789,
#  'first_level_divisions': 790,
#  'form_of_government': 791,
#  'languages_spoken': 1021,
#  'official_language': 793,
#  'second_level_divisions': 794,
#  'county': 795,
#  'place': 796,
#  'adjoins': 803,
#  'containedby': 804,
#  'contains': 805,
#  'events': 1143,
#  'nearby_airports': 807,
#  'partially_containedby': 808,
#  'partially_contains': 809,
#  'people_born_here': 810,
#  'time_zones': 813,
#  'neighborhood_of': 814,
#  'neighborhoods': 815,
#  'adjustment_currency': 818,
#  'exported_to': 821,
#  'imported_from': 822,
#  'county_seat': 831,
#  'hud_county_place': 832,
#  'well_known_practitioner': 833,
#  'martial_art': 834,
#  'adapted_from': 835,
#  'adaptations': 836,
#  'dedicated_by': 839,
#  'dedicated_to': 841,
#  'work_dedicated': 842,
#  'books_in_this_genre': 843,
#  'child_genres': 844,
#  'parent_genre': 919,
#  'titles': 846,
#  'netflix_genres': 847,
#  'conditions_this_may_prevent': 848,
#  'causes': 849,
#  'includes_diseases': 850,
#  'medical_specialties': 851,
#  'notable_people_with_this_condition': 852,
#  'parent_disease': 853,
#  'prevention_factors': 854,
#  'risk_factors': 855,
#  'symptoms': 856,
#  'treatments': 857,
#  'diseases': 876,
#  'active_moieties': 859,
#  'drug_class': 860,
#  'legal_status': 861,
#  'drugs': 862,
#  'active_moiety_of_drug': 863,
#  'more_general_ingredient': 864,
#  'more_specific_ingredient': 865,
#  'includes_classifications': 866,
#  'parent_classification': 867,
#  'infectious_agent_type': 868,
#  'diseases_treated': 869,
#  'side_effects': 870,
#  'used_to_treat': 871,
#  'condition': 872,
#  'side_effect_of': 874,
#  'symptom_of': 875,
#  'service_type': 877,
#  'transit_lines': 878,
#  'military_post': 880,
#  'military_person': 903,
#  'military_conflict': 891,
#  'combatant': 896,
#  'military_commander': 895,
#  'combatants': 893,
#  'conflict': 889,
#  'military_combatant': 894,
#  'military_personnel_involved': 897,
#  'participated_in_conflicts': 1317,
#  'military_force': 902,
#  'armed_force': 901,
#  'albums': 917,
#  'album': 907,
#  'performance_role': 932,
#  'label': 910,
#  'origin': 911,
#  'supporting_artists': 912,
#  'conductor': 915,
#  'ensemble': 916,
#  'artists': 1340,
#  'subgenre': 920,
#  'artists_supported': 921,
#  'instruments_played': 922,
#  'vocal_range': 925,
#  'family': 1329,
#  'instrumentalists': 927,
#  'variation': 928,
#  'contributor': 936,
#  'singers': 939,
#  'olympics': 967,
#  'medal': 961,
#  'medalist': 962,
#  'athlete': 1134,
#  'participating_countries': 953,
#  'sports': 1310,
#  'olympics_participated_in': 964,
#  'olympic_games_contested': 968,
#  'registering_agency': 971,
#  'acquiring_company': 972,
#  'child': 975,
#  'company_acquired': 976,
#  'founders': 977,
#  'geographic_scope': 978,
#  'became_organization': 982,
#  'organizations_merging': 992,
#  'legal_structure': 986,
#  'organization_type': 987,
#  'parent': 988,
#  'place_founded': 991,
#  'sectors': 993,
#  'child_company': 994,
#  'parent_company': 995,
#  'organizations_founded': 996,
#  'organizations_with_this_scope': 998,
#  'organizations_in_this_sector': 999,
#  'organizations_of_this_type': 1000,
#  'appointee': 1010,
#  'appointed_role': 1009,
#  'includes_causes_of_death': 1011,
#  'parent_cause_of_death': 1012,
#  'people': 1022,
#  'cause_of_death': 1014,
#  'place_of_burial': 1015,
#  'place_of_cremation': 1016,
#  'place_of_death': 1017,
#  'geographic_distribution': 1018,
#  'included_in_group': 1019,
#  'includes_groups': 1020,
#  'location_of_ceremony': 1044,
#  'spouse': 1045,
#  'nationality': 1037,
#  'profession': 1041,
#  'sibling': 1043,
#  'type_of_union': 1046,
#  'interred_here': 1047,
#  'people_with_this_profession': 1048,
#  'specialization_of': 1049,
#  'specializations': 1050,
#  'newspapers': 1051,
#  'protected_sites_governed': 1054,
#  'protected_areas': 1055,
#  'category_or_criteria': 1056,
#  'designation': 1057,
#  'listed_site': 1060,
#  'iucn_category': 1059,
#  'deity_of': 1061,
#  'deities': 1063,
#  'is_part_of': 1065,
#  'notable_figures': 1066,
#  'organizations': 1067,
#  'places_of_worship': 1068,
#  'practices': 1069,
#  'texts': 1070,
#  'associated_with': 1072,
#  'leader': 1073,
#  'practice_of': 1074,
#  'religious_text_of': 1075,
#  'order': 1076,
#  'rulers': 1077,
#  'kingdom': 1078,
#  'royal_line': 1079,
#  'noble_title': 1080,
#  'noble_person': 1081,
#  'noble_rank': 1082,
#  'system': 1083,
#  'recipient': 1084,
#  'kingdom_s_ruled': 1085,
#  'monarchs_from_this_line': 1086,
#  'point_awarded_to': 1093,
#  'manager': 1102,
#  'astronauts': 1104,
#  'draft': 1127,
#  'owner_s': 1130,
#  'leagues': 1132,
#  'officials': 1133,
#  'related_equipment': 1135,
#  'competitors': 1137,
#  'champion': 1144,
#  'championship': 1145,
#  'runner_up': 1146,
#  'sport_used_for': 1147,
#  'arena_stadium': 1172,
#  'championships': 1173,
#  'teams_owned': 1197,
#  'namesakes': 1199,
#  'named_after': 1200,
#  'winner': 1203,
#  'loser': 1202,
#  'country_of_origin': 1265,
#  'lyricist': 1206,
#  'plays_in_this_genre': 1209,
#  'play_lyrics_written': 1210,
#  'included_in_event': 1211,
#  'includes_event': 1212,
#  'instance_of_recurring_event': 1213,
#  'locations': 1214,
#  'instances': 1215,
#  'locations_in_this_time_zone': 1216,
#  'bridge_type': 1217,
#  'locale': 1218,
#  'bridges_of_this_type': 1219,
#  'major_cities': 1222,
#  'near_travel_destination': 1223,
#  'mode_of_transportation': 1231,
#  'transport_operator': 1232,
#  'travel_destination': 1229,
#  'transport_terminus': 1233,
#  'month': 1230,
#  'local_transportation': 1234,
#  'tourist_attractions': 1235,
#  'series': 1296,
#  'episodes_appeared_in': 1244,
#  'seasons': 1294,
#  'programs': 1254,
#  'tv_shows_filmed_here': 1255,
#  'areas_served': 1256,
#  'appearance_type': 1286,
#  'producer_type': 1284,
#  'episode': 1287,
#  'episodes': 1266,
#  'filming_locations': 1267,
#  'network': 1270,
#  'program_creator': 1271,
#  'writer': 1292,
#  'spin_offs': 1280,
#  'spun_off_from': 1281,
#  'programs_created': 1285,
#  'tv_programs': 1297,
#  'episodes_written': 1298,
#  'tv_program': 1299,
#  'place_murdered': 1300,
#  'philosophers': 1304,
#  'era': 1302,
#  'interests': 1303,
#  'conferred_upon': 1305,
#  'honorary_title': 1306,
#  'child_concept': 1307,
#  'parent_concept': 1308,
#  'member_states': 1311,
#  'known_for': 1312,
#  'associated_disorder': 1313,
#  'biofluid_location': 1314,
#  'related_topics': 1316,
#  'current_house_members': 1318,
#  'current_members': 1320,
#  'committee_memberships': 1321,
#  'congressional_caucus_memberships': 1322,
#  'nfl_team': 1324,
#  'signatories': 1327,
#  'documents_signed': 1328,
#  'algorithm': 1330,
#  'subject': 1331,
#  'taxonomy': 1332,
#  'investor': 1333,
#  'associated_artists': 1335,
#  'artwork_on_the_subject': 1336,
#  'art_form': 1337,
#  'art_genre': 1338,
#  'art_subject': 1339,
#  'artworks': 1342,
#  'art_forms': 1343,
#  'associated_periods_or_movements': 1344}

# %%
filename = '/home/gebhart/projects/traversing_knowledge_graphs/data/freebase/dev'
head_entities = []
tail_entities = []
relations = []
with open(filename, 'r') as f:
    num_examples = 0
    for line in f:
        items = line.split()
        if len(items) >= 4:
            label = items[3]
        else:
            label = '1'  # if no label, assume positive
            s, path, t = items[:3]
            rels = tuple(path.split(','))
            head_entities.append(s)
            tail_entities.append(t)
            relations.append(rels)

# %%
relations
# Out:
# [('religion',),
#  ('gender',),
#  ('nationality', '**nationality', 'profession', '**profession'),
#  ('gender',),
#  ('place_of_death', '**place_of_death', 'gender', '**gender', 'nationality'),
#  ('**place_of_birth',
#   'profession',
#   '**profession',
#   'nationality',
#   '**place_of_death'),
#  ('place_of_death', '**location'),
#  ('gender', '**gender'),
#  ('place_of_birth',
#   '**place_of_birth',
#   'profession',
#   '**profession',
#   'institution'),
#  ('profession',),
#  ('cause_of_death',),
#  ('gender', '**gender', 'profession'),
#  ('**place_of_death', 'place_of_birth', '**place_of_birth', 'location'),
#  ('gender', '**gender', 'place_of_birth'),
#  ('gender',),
#  ('profession', '**children', '**parents'),
#  ('nationality', '**place_of_death', 'gender', '**gender'),
#  ('gender', '**gender', 'gender', '**gender'),
#  ('gender', '**gender'),
#  ('gender', '**gender'),
#  ('**place_of_birth', 'institution', '**institution'),
#  ('gender', '**gender'),
#  ('location', '**place_of_death'),
#  ('gender', '**gender', 'nationality', '**profession'),
#  ('nationality', '**location', 'gender', '**gender', 'nationality'),
#  ('**place_of_death', 'nationality', '**location', 'religion', '**religion'),
#  ('**location', 'place_of_death', '**place_of_death'),
#  ('location', '**place_of_death', 'religion', '**religion', 'place_of_death'),
#  ('gender', '**gender', 'place_of_birth', '**place_of_birth'),
#  ('cause_of_death', '**cause_of_death'),
#  ('cause_of_death',),
#  ('profession', '**profession'),
#  ('nationality', '**location'),
#  ('gender', '**gender'),
#  ('place_of_death',
#   '**place_of_birth',
#   'place_of_death',
#   '**place_of_death',
#   'spouse'),
#  ('place_of_birth', '**place_of_birth', 'gender', '**gender'),
#  ('religion', '**religion', 'place_of_death', '**location'),
#  ('place_of_death', '**place_of_death', 'gender', '**gender'),
#  ('profession', '**profession'),
#  ('gender', '**gender'),
#  ('nationality', '**nationality', 'place_of_birth', '**location'),
#  ('gender',),
#  ('profession', '**profession'),
#  ('place_of_death', '**location'),
#  ('cause_of_death',),
#  ('gender',),
#  ('profession',),
#  ('**place_of_death',
#   'place_of_birth',
#   '**place_of_birth',
#   'place_of_birth',
#   '**place_of_birth'),
#  ('nationality',),
#  ('nationality', '**nationality', 'place_of_death'),
#  ('gender',),
#  ('nationality',),
#  ('profession', '**profession', 'nationality', '**nationality', 'profession'),
#  ('location', '**location', 'profession', '**profession'),
#  ('place_of_death', '**place_of_death'),
#  ('place_of_birth',
#   '**place_of_death',
#   'place_of_death',
#   '**place_of_death',
#   'profession'),
#  ('gender', '**gender'),
#  ('nationality', '**profession'),
#  ('nationality', '**place_of_birth', 'place_of_death'),
#  ('nationality', '**location', 'ethnicity'),
#  ('place_of_birth',
#   '**location',
#   'institution',
#   '**institution',
#   'institution'),
#  ('place_of_birth', '**place_of_birth'),
#  ('nationality', '**profession', 'gender', '**gender'),
#  ('nationality', '**ethnicity'),
#  ('profession', '**profession'),
#  ('profession', '**profession'),
#  ('**place_of_birth', 'nationality', '**place_of_death'),
#  ('gender', '**gender', 'gender', '**gender'),
#  ('nationality', '**place_of_death', 'gender', '**gender', 'profession'),
#  ('gender', '**gender', 'profession'),
#  ('nationality',),
#  ('nationality',),
#  ('nationality',),
#  ('**place_of_death', 'place_of_death', '**place_of_birth'),
#  ('profession',
#   '**profession',
#   'place_of_death',
#   '**place_of_death',
#   'place_of_birth'),
#  ('location', '**location', 'profession', '**profession'),
#  ('parents', 'children', '**children'),
#  ('location', '**location'),
#  ('gender', '**gender', 'nationality', '**place_of_death'),
#  ('nationality', '**place_of_death', 'nationality', '**location', 'location'),
#  ('place_of_birth',
#   '**location',
#   'place_of_birth',
#   '**place_of_birth',
#   'gender'),
#  ('place_of_birth', '**location', 'nationality'),
#  ('place_of_birth', '**place_of_death', 'nationality', '**place_of_death'),
#  ('gender', '**gender', 'profession', '**profession', 'profession'),
#  ('gender',),
#  ('profession',),
#  ('nationality', '**nationality', 'institution', '**place_of_birth'),
#  ('nationality', '**profession', 'place_of_birth'),
#  ('institution', '**institution', 'gender'),
#  ('institution',),
#  ('nationality', '**profession', 'place_of_birth'),
#  ('cause_of_death', '**cause_of_death'),
#  ('gender',),
#  ('place_of_birth',
#   '**place_of_death',
#   '**parents',
#   'place_of_birth',
#   '**place_of_death'),
#  ('nationality',),
#  ('nationality', '**location', 'gender', '**gender'),
#  ('**parents', 'cause_of_death'),
#  ('nationality', '**nationality', 'profession', '**profession'),
#  ('place_of_birth',
#   '**place_of_birth',
#   'place_of_death',
#   '**place_of_birth',
#   'gender'),
#  ('nationality', '**place_of_death', '**parents', 'place_of_death'),
#  ('parents', '**children', '**parents', '**children', 'parents'),
#  ('profession',),
#  ('**profession', 'location', '**place_of_birth', 'religion', '**religion'),
#  ('nationality', '**nationality', 'place_of_birth'),
#  ('nationality', '**location', 'nationality'),
#  ('profession', '**profession'),
#  ('institution', '**institution', 'gender', '**gender'),
#  ('gender', '**gender', 'place_of_birth'),
#  ('nationality', '**place_of_birth', 'place_of_death'),
#  ('nationality',),
#  ('gender', '**gender', 'nationality'),
#  ('**place_of_death', 'place_of_birth', '**place_of_birth', 'gender'),
#  ('profession',),
#  ('location', '**place_of_death'),
#  ('place_of_birth',
#   '**place_of_death',
#   'place_of_death',
#   '**place_of_birth',
#   'cause_of_death'),
#  ('religion',),
#  ('location', '**location', 'profession'),
#  ('gender', '**gender', '**children', 'children', '**children'),
#  ('profession', '**profession', 'cause_of_death', '**cause_of_death'),
#  ('place_of_birth', '**location'),
#  ('gender',),
#  ('**place_of_birth',
#   'gender',
#   '**gender',
#   'place_of_death',
#   '**place_of_death'),
#  ('location', '**place_of_birth', 'institution', '**institution'),
#  ('location', '**place_of_death', 'gender', '**gender'),
#  ('place_of_birth', '**location'),
#  ('nationality', '**place_of_death', 'gender', '**gender', 'location'),
#  ('cause_of_death',),
#  ('place_of_death', '**place_of_birth', 'place_of_death', '**institution'),
#  ('location', '**place_of_death', 'location', '**place_of_birth'),
#  ('place_of_death', '**location'),
#  ('nationality',),
#  ('place_of_birth', '**place_of_death', 'place_of_death', '**place_of_death'),
#  ('gender',),
#  ('place_of_death',
#   '**nationality',
#   'location',
#   '**place_of_birth',
#   'place_of_death'),
#  ('nationality', '**place_of_birth', 'profession'),
#  ('place_of_death', '**location'),
#  ('gender', '**gender'),
#  ('nationality', '**place_of_death', 'gender', '**gender', 'gender'),
#  ('place_of_death', '**place_of_birth'),
#  ('profession',),
#  ('location', '**location'),
#  ('place_of_death', '**location', 'gender', '**gender'),
#  ('gender',),
#  ('place_of_death', '**place_of_birth', 'place_of_birth'),
#  ('nationality',),
#  ('cause_of_death',
#   '**cause_of_death',
#   'location',
#   '**place_of_birth',
#   'gender'),
#  ('gender', '**gender'),
#  ('nationality', '**place_of_birth', 'place_of_death', '**place_of_birth'),
#  ('nationality', '**place_of_death'),
#  ('profession',
#   '**profession',
#   'profession',
#   '**profession',
#   'place_of_birth'),
#  ('place_of_death', '**location', 'profession', '**profession'),
#  ('location', '**place_of_birth'),
#  ('**location', 'gender', '**gender', 'place_of_death'),
#  ('nationality', '**place_of_birth', 'institution', '**institution'),
#  ('nationality', '**place_of_birth', '**parents'),
#  ('profession',),
#  ('nationality', '**nationality'),
#  ('nationality', '**place_of_death'),
#  ('place_of_death', '**place_of_death'),
#  ('place_of_death', '**location', 'place_of_death'),
#  ('location', '**place_of_birth', 'institution', '**institution'),
#  ('cause_of_death', '**cause_of_death'),
#  ('nationality',),
#  ('nationality',
#   '**place_of_death',
#   'location',
#   '**place_of_death',
#   'profession'),
#  ('gender', '**gender', 'nationality', '**nationality'),
#  ('profession', '**profession', 'place_of_death'),
#  ('gender', '**gender', 'religion'),
#  ('location', '**place_of_death', 'nationality', '**place_of_birth'),
#  ('place_of_death', '**place_of_death'),
#  ('gender', '**gender'),
#  ('nationality',),
#  ('gender', '**gender'),
#  ('place_of_birth', '**location'),
#  ('place_of_birth', '**location', 'place_of_death', '**place_of_death'),
#  ('nationality', '**place_of_death', 'religion', '**religion'),
#  ('profession',),
#  ('gender', '**gender', 'cause_of_death'),
#  ('gender', '**gender'),
#  ('place_of_death', '**place_of_death', 'place_of_birth', '**place_of_death'),
#  ('profession', '**profession', 'profession', '**profession'),
#  ('profession', '**profession', 'profession', '**profession'),
#  ('place_of_death', '**location'),
#  ('gender',),
#  ('gender', '**gender'),
#  ('**parents', 'spouse', '**parents'),
#  ('profession', '**profession', 'gender'),
#  ('profession', '**profession'),
#  ('cause_of_death',
#   '**cause_of_death',
#   'place_of_birth',
#   '**place_of_death',
#   'gender'),
#  ('profession', '**profession', 'place_of_birth', '**place_of_birth'),
#  ('location',
#   '**place_of_birth',
#   'nationality',
#   '**place_of_death',
#   'nationality'),
#  ('profession', '**profession', 'place_of_death', '**nationality', 'location'),
#  ('place_of_birth',
#   '**place_of_death',
#   'profession',
#   '**profession',
#   'nationality'),
#  ('profession', '**profession', 'gender', '**gender', 'gender'),
#  ('profession',),
#  ('gender', '**gender'),
#  ('ethnicity',
#   '**nationality',
#   'cause_of_death',
#   '**cause_of_death',
#   'cause_of_death'),
#  ('nationality',
#   '**place_of_birth',
#   'profession',
#   '**profession',
#   'profession'),
#  ('**place_of_birth', 'place_of_death', '**location', 'gender'),
#  ('profession',),
#  ('place_of_death',
#   '**place_of_birth',
#   'nationality',
#   '**nationality',
#   'nationality'),
#  ('nationality',),
#  ('ethnicity', '**ethnicity', '**children', 'place_of_death'),
#  ('**spouse', 'spouse', 'spouse', 'spouse', 'place_of_death'),
#  ('gender', '**gender'),
#  ('gender', '**gender', 'nationality'),
#  ('profession', '**profession', 'gender', '**gender', 'profession'),
#  ('location', '**place_of_death', 'place_of_death', '**location'),
#  ('place_of_birth', '**location'),
#  ('gender',),
#  ('cause_of_death',),
#  ('place_of_death',
#   '**place_of_death',
#   'gender',
#   '**gender',
#   'place_of_birth'),
#  ('nationality', '**nationality', '**children', '**parents'),
#  ('nationality',
#   '**place_of_death',
#   'place_of_birth',
#   '**place_of_death',
#   'place_of_death'),
#  ('**location', 'nationality', '**location', 'gender', '**gender'),
#  ('religion',),
#  ('place_of_death', '**location'),
#  ('nationality', '**profession'),
#  ('gender', '**gender', 'location', '**location', 'cause_of_death'),
#  ('place_of_birth', '**location', 'location', '**place_of_death'),
#  ('place_of_death',
#   '**location',
#   'location',
#   '**place_of_death',
#   'institution'),
#  ('gender', '**gender', 'parents'),
#  ('place_of_birth',
#   '**place_of_death',
#   'place_of_death',
#   '**location',
#   'gender'),
#  ('place_of_death', '**location', 'location', '**location'),
#  ('parents', 'spouse', 'parents'),
#  ('place_of_death',
#   '**place_of_death',
#   'gender',
#   '**gender',
#   'place_of_death'),
#  ('institution',),
#  ('gender', '**gender', 'profession', '**profession', 'place_of_birth'),
#  ('institution', '**location', 'gender', '**gender', 'place_of_birth'),
#  ('gender', '**gender', 'profession', '**profession'),
#  ('location', '**location', 'gender', '**gender'),
#  ('profession', '**profession', 'nationality', '**location'),
#  ('gender', '**gender'),
#  ('spouse', 'cause_of_death'),
#  ('nationality', '**place_of_death', 'place_of_death'),
#  ('gender', '**gender'),
#  ('nationality', '**nationality', 'children', '**children'),
#  ('profession', '**profession', 'nationality'),
#  ('institution', '**place_of_birth', 'location', '**place_of_birth'),
#  ('profession', '**profession', 'gender', '**gender', 'profession'),
#  ('institution', '**institution'),
#  ('gender', '**gender'),
#  ('gender', '**gender', 'place_of_birth', '**place_of_death'),
#  ('place_of_death',
#   '**place_of_death',
#   'profession',
#   '**profession',
#   'gender'),
#  ('profession',),
#  ('religion', '**religion', 'profession', '**profession', 'spouse'),
#  ('place_of_death', '**place_of_birth', 'gender'),
#  ('place_of_death', '**location'),
#  ('profession', '**profession'),
#  ('**place_of_death',
#   'place_of_birth',
#   '**place_of_death',
#   'nationality',
#   '**place_of_death'),
#  ('place_of_death', '**place_of_death', 'gender', '**gender', 'gender'),
#  ('profession', '**profession', 'gender', '**gender'),
#  ('gender', '**gender'),
#  ('**parents', 'parents', 'gender', '**gender', 'gender'),
#  ('gender', '**gender', 'gender', '**gender'),
#  ('place_of_birth', '**nationality', 'place_of_death', '**location'),
#  ('gender',),
#  ('nationality',),
#  ('profession', '**profession', 'profession', '**profession'),
#  ('profession', '**profession', 'institution', '**institution'),
#  ('gender',),
#  ('nationality', '**place_of_birth', 'place_of_birth', '**place_of_birth'),
#  ('institution', '**institution', 'gender', '**gender'),
#  ('gender', '**gender'),
#  ('profession', '**profession', 'place_of_birth', '**place_of_death'),
#  ('profession',),
#  ('institution', '**institution', 'religion'),
#  ('profession', '**profession'),
#  ('gender',),
#  ('profession',),
#  ('institution', '**institution', 'gender', '**gender'),
#  ('place_of_birth', '**place_of_birth'),
#  ('gender', '**gender', 'nationality', '**nationality'),
#  ('nationality', '**place_of_death', 'nationality', '**location', 'gender'),
#  ('location', '**location', 'location', '**place_of_birth', 'religion'),
#  ('profession',
#   '**profession',
#   'nationality',
#   '**place_of_birth',
#   'nationality'),
#  ('place_of_death', '**place_of_birth', 'profession'),
#  ('**location', 'institution', '**institution', 'profession'),
#  ('location', '**location', 'gender', '**gender', 'nationality'),
#  ('gender',),
#  ('nationality',),
#  ('nationality', '**nationality', 'profession', '**profession', 'profession'),
#  ('**place_of_birth', 'gender', '**gender'),
#  ('gender', '**gender', 'place_of_birth', '**place_of_death'),
#  ('nationality', '**nationality'),
#  ('location', '**place_of_birth'),
#  ('nationality', '**place_of_death', 'nationality'),
#  ('nationality',),
#  ('parents', 'children', 'gender', '**gender'),
#  ('**place_of_death',
#   'nationality',
#   '**location',
#   'nationality',
#   '**location'),
#  ('gender', '**gender'),
#  ('profession', '**profession', 'gender', '**gender'),
#  ('place_of_birth', '**location', 'place_of_birth', '**location'),
#  ('nationality', '**profession'),
#  ('profession', '**profession', 'institution'),
#  ('gender', '**gender', 'nationality', '**nationality'),
#  ('gender', '**gender', 'location', '**place_of_death'),
#  ('profession',),
#  ('**location', 'spouse', 'gender', '**gender', 'place_of_birth'),
#  ('place_of_birth', '**location', 'gender', '**gender', 'gender'),
#  ('location', '**location', 'nationality'),
#  ('profession', '**profession', 'gender', '**gender'),
#  ('profession', '**profession', 'gender'),
#  ('ethnicity',),
#  ('institution',),
#  ('nationality', '**profession', 'profession'),
#  ('nationality', '**location', 'location'),
#  ('profession', '**profession', 'profession', '**profession'),
#  ('ethnicity', '**ethnicity', 'ethnicity', '**religion'),
#  ('cause_of_death',),
#  ('profession',),
#  ('gender', '**gender', 'place_of_birth', '**location'),
#  ('nationality',),
#  ('gender',),
#  ('location', '**place_of_death'),
#  ('cause_of_death',),
#  ('location', '**location', 'nationality'),
#  ('place_of_birth', '**place_of_birth'),
#  ('ethnicity', '**ethnicity', 'ethnicity', '**ethnicity', 'place_of_birth'),
#  ('**place_of_birth', 'place_of_birth', '**place_of_birth'),
#  ('**place_of_birth', 'profession', '**profession', 'location', '**location'),
#  ('gender',),
#  ('nationality',),
#  ('**parents', '**spouse', 'place_of_death', '**place_of_birth'),
#  ('profession', '**profession'),
#  ('profession', '**profession', 'nationality', '**profession'),
#  ('place_of_birth', '**location'),
#  ('place_of_death',
#   '**location',
#   'location',
#   '**place_of_death',
#   'place_of_death'),
#  ('**place_of_birth', 'profession', '**profession'),
#  ('nationality', '**ethnicity', 'place_of_birth', '**location'),
#  ('**children', 'parents', 'parents', 'children', 'gender'),
#  ('**location', 'gender', '**gender'),
#  ('**place_of_death', 'place_of_death', '**place_of_death'),
#  ('gender', '**gender'),
#  ('profession', '**profession', 'place_of_death', '**location', 'location'),
#  ('profession',),
#  ('cause_of_death', '**cause_of_death', 'place_of_birth'),
#  ('nationality', '**location'),
#  ('religion', '**religion', 'religion', '**religion'),
#  ('gender', '**gender', 'gender', '**gender'),
#  ('profession', '**profession', 'place_of_birth', '**location'),
#  ('nationality', '**place_of_birth'),
#  ('**place_of_death', 'profession'),
#  ('profession',),
#  ('profession', '**profession', 'nationality', '**location', 'location'),
#  ('religion', '**religion', 'place_of_birth', '**place_of_birth'),
#  ('**children',
#   'place_of_birth',
#   '**place_of_birth',
#   'religion',
#   '**religion'),
#  ('gender', '**gender'),
#  ('gender', '**gender'),
#  ('gender', '**gender', 'institution', '**institution'),
#  ('place_of_birth',
#   '**place_of_death',
#   'nationality',
#   '**location',
#   'nationality'),
#  ('profession', '**profession'),
#  ('place_of_death',
#   '**place_of_death',
#   'place_of_death',
#   '**place_of_birth',
#   'place_of_death'),
#  ('profession', '**profession'),
#  ('**place_of_birth',
#   'place_of_birth',
#   '**place_of_birth',
#   'nationality',
#   '**place_of_birth'),
#  ('**place_of_death', 'gender', '**gender', '**parents'),
#  ('**parents', '**parents', 'gender', '**gender', 'gender'),
#  ('nationality', '**location'),
#  ('gender', '**gender', 'place_of_death'),
#  ('profession',),
#  ('cause_of_death',),
#  ('religion',),
#  ('place_of_birth', '**place_of_death'),
#  ('nationality', '**place_of_birth'),
#  ('gender', '**gender', 'profession'),
#  ('gender', '**gender', 'profession', '**profession'),
#  ('nationality', '**profession', 'nationality'),
#  ('gender', '**gender', 'place_of_birth', '**place_of_death'),
#  ('profession',),
#  ('**place_of_death', 'place_of_birth', '**place_of_death', 'gender'),
#  ('ethnicity',),
#  ('institution',),
#  ('**profession', 'nationality'),
#  ('gender', '**gender', 'gender'),
#  ('nationality', '**location', 'place_of_death', '**place_of_birth'),
#  ('place_of_death', '**place_of_birth', 'place_of_birth'),
#  ('place_of_birth', '**location', 'place_of_death', '**place_of_death'),
#  ('profession', '**profession', 'nationality', '**nationality'),
#  ('place_of_birth', '**location'),
#  ('place_of_death', '**place_of_death', 'nationality', '**ethnicity'),
#  ('gender', '**gender', 'location', '**place_of_birth'),
#  ('cause_of_death', '**cause_of_death'),
#  ('religion',
#   '**religion',
#   'place_of_birth',
#   '**place_of_birth',
#   'cause_of_death'),
#  ('institution',),
#  ('place_of_death', '**place_of_death', 'gender', '**gender', 'nationality'),
#  ('**place_of_death', 'profession', '**profession'),
#  ('place_of_birth', '**location', 'place_of_birth'),
#  ('profession', '**profession', 'profession', '**profession'),
#  ('gender',),
#  ('gender', '**gender'),
#  ('place_of_birth', '**place_of_birth', 'place_of_birth', '**place_of_birth'),
#  ('religion',),
#  ('place_of_birth', '**place_of_death', 'place_of_death', '**place_of_death'),
#  ('ethnicity', '**ethnicity', 'place_of_death', '**location', 'profession'),
#  ('place_of_death', '**place_of_death', 'gender', '**gender', 'nationality'),
#  ('nationality',),
#  ('institution', '**institution', 'institution', '**institution', 'ethnicity'),
#  ('**institution', 'nationality', '**nationality', 'profession'),
#  ('cause_of_death',
#   '**cause_of_death',
#   'place_of_death',
#   '**place_of_death',
#   'place_of_birth'),
#  ('location', '**place_of_birth', 'place_of_birth', '**location'),
#  ('place_of_death', '**place_of_death', '**children'),
#  ('cause_of_death', '**cause_of_death'),
#  ('gender', '**gender', 'nationality', '**ethnicity', 'nationality'),
#  ('profession',),
#  ('gender', '**gender', '**parents'),
#  ('nationality', '**nationality'),
#  ('place_of_death',
#   '**place_of_death',
#   'nationality',
#   '**place_of_death',
#   'location'),
#  ('profession', '**profession', 'profession', '**profession'),
#  ('gender', '**gender', 'parents', 'children', 'cause_of_death'),
#  ('gender', '**gender', 'nationality', '**nationality', 'place_of_birth'),
#  ('**parents', 'parents', 'gender'),
#  ('gender', '**gender', 'profession'),
#  ('gender', '**gender', 'location'),
#  ('place_of_birth',
#   '**place_of_death',
#   'nationality',
#   '**place_of_birth',
#   'gender'),
#  ('gender', '**gender'),
#  ('**spouse', '**parents', 'spouse', 'location'),
#  ('cause_of_death', '**cause_of_death'),
#  ('parents', 'religion', '**religion', 'nationality', '**place_of_birth'),
#  ('location',
#   '**place_of_birth',
#   'location',
#   '**place_of_death',
#   'place_of_birth'),
#  ('ethnicity', '**nationality', 'nationality', '**religion', '**parents'),
#  ('profession', '**profession', 'nationality'),
#  ('profession',),
#  ('institution', '**institution', 'spouse', '**spouse'),
#  ('profession', '**profession', 'profession', '**profession', 'nationality'),
#  ('**institution', 'gender', '**gender'),
#  ('nationality', '**profession'),
#  ('place_of_death',
#   '**place_of_birth',
#   'religion',
#   '**religion',
#   'nationality'),
#  ('profession', '**profession', 'profession', '**profession'),
#  ('place_of_birth', '**place_of_death', 'gender', '**gender'),
#  ('place_of_death',
#   '**location',
#   'nationality',
#   '**place_of_birth',
#   'place_of_death'),
#  ('place_of_death',
#   '**place_of_birth',
#   'profession',
#   '**profession',
#   'religion'),
#  ('profession', '**profession'),
#  ('profession',),
#  ('**children', 'place_of_birth', '**place_of_birth'),
#  ('nationality', '**location'),
#  ('gender', '**gender', 'gender', '**gender', 'location'),
#  ('children', 'spouse', 'gender', '**gender', 'location'),
#  ('gender', '**gender', 'gender'),
#  ('parents', 'gender', '**gender', 'place_of_death', '**place_of_birth'),
#  ('profession',),
#  ('parents', '**parents', 'children', 'gender'),
#  ('place_of_death', '**place_of_birth', 'gender', '**gender'),
#  ('gender',),
#  ('profession',),
#  ('**profession', 'location', '**place_of_death'),
#  ('gender', '**gender', 'ethnicity', '**religion', 'institution'),
#  ('**institution', 'spouse', '**spouse', 'place_of_birth'),
#  ('gender',),
#  ('location', '**place_of_death', 'place_of_death'),
#  ('gender', '**gender'),
#  ('place_of_death', '**place_of_death'),
#  ('cause_of_death', '**cause_of_death'),
#  ('**children',
#   'location',
#   '**place_of_death',
#   'place_of_death',
#   '**location'),
#  ('ethnicity',),
#  ('location', '**location', 'nationality', '**nationality'),
#  ('gender', '**gender', 'profession', '**profession'),
#  ('gender',),
#  ('profession', '**profession'),
#  ('institution',),
#  ('gender', '**gender', 'nationality'),
#  ('gender', '**gender', 'place_of_birth', '**place_of_death'),
#  ('nationality', '**location', 'profession', '**profession'),
#  ('location', '**place_of_death', 'nationality', '**location'),
#  ('ethnicity', '**ethnicity', 'place_of_birth', '**place_of_birth'),
#  ('profession', '**profession', 'nationality', '**place_of_birth'),
#  ('**place_of_death', 'place_of_death', '**place_of_birth', 'place_of_birth'),
#  ('place_of_birth', '**place_of_death'),
#  ('place_of_death', '**location', 'nationality', '**nationality', 'location'),
#  ('religion',),
#  ('gender', '**gender', 'place_of_death', '**location', 'location'),
#  ('**place_of_birth',
#   'place_of_birth',
#   '**place_of_birth',
#   'ethnicity',
#   '**nationality'),
#  ('gender', '**gender', 'nationality', '**nationality'),
#  ('religion',),
#  ('profession', '**profession', 'profession'),
#  ('**place_of_birth',
#   'nationality',
#   '**place_of_death',
#   'place_of_birth',
#   '**place_of_death'),
#  ('place_of_death', '**place_of_death', 'place_of_birth'),
#  ('**place_of_death', 'place_of_death', '**location'),
#  ('gender',),
#  ('nationality', '**nationality', 'gender'),
#  ('place_of_death', '**place_of_birth', 'place_of_birth'),
#  ('profession',),
#  ('nationality',),
#  ('institution',),
#  ('**location', 'nationality', '**ethnicity', 'ethnicity'),
#  ('gender',),
#  ('place_of_death', '**location', 'profession', '**profession'),
#  ('location', '**place_of_birth', 'gender', '**gender'),
#  ('place_of_birth', '**place_of_death', 'gender'),
#  ('gender', '**gender', 'gender', '**gender'),
#  ('religion', '**religion', 'place_of_death', '**place_of_death'),
#  ('location', '**place_of_birth'),
#  ('place_of_birth', '**place_of_death', 'gender', '**gender', 'profession'),
#  ('profession', '**profession', 'nationality'),
#  ('gender', '**gender', 'place_of_death', '**nationality'),
#  ('**location', 'gender', '**gender'),
#  ('gender',),
#  ('place_of_birth', '**place_of_birth', 'nationality'),
#  ('place_of_birth', '**location', 'place_of_birth'),
#  ('profession', '**profession'),
#  ('gender', '**gender', 'place_of_birth'),
#  ('nationality', '**ethnicity', 'ethnicity'),
#  ('location',
#   '**place_of_death',
#   'place_of_birth',
#   '**place_of_birth',
#   'gender'),
#  ('gender', '**gender', 'nationality'),
#  ('place_of_birth', '**place_of_birth'),
#  ('place_of_birth', '**place_of_birth', 'gender', '**gender'),
#  ('gender', '**gender'),
#  ('place_of_death',
#   '**place_of_death',
#   'nationality',
#   '**nationality',
#   'profession'),
#  ('location', '**location', 'place_of_birth'),
#  ('place_of_birth', '**place_of_birth'),
#  ('place_of_death', '**place_of_birth'),
#  ('place_of_birth', '**place_of_death', 'place_of_birth', '**place_of_birth'),
#  ('**place_of_death', 'place_of_death'),
#  ('place_of_birth', '**place_of_death', 'place_of_death', '**place_of_death'),
#  ('location',
#   '**place_of_birth',
#   'nationality',
#   '**place_of_birth',
#   'place_of_birth'),
#  ('location', '**place_of_birth'),
#  ('religion', '**religion', '**parents', 'gender'),
#  ('location', '**location', 'gender', '**gender', 'gender'),
#  ('institution',
#   '**institution',
#   'institution',
#   '**institution',
#   'nationality'),
#  ('gender', '**gender'),
#  ('nationality', '**place_of_death', 'place_of_birth'),
#  ('place_of_death', '**place_of_birth'),
#  ('profession', '**profession', 'profession'),
#  ('gender',
#   '**gender',
#   'place_of_birth',
#   '**place_of_death',
#   'place_of_death'),
#  ('institution', '**institution'),
#  ('ethnicity', '**ethnicity', 'gender', '**gender', 'cause_of_death'),
#  ('gender', '**gender', 'nationality', '**place_of_birth', 'place_of_birth'),
#  ('profession', '**profession', 'gender', '**gender', 'place_of_birth'),
#  ('profession',),
#  ('gender', '**gender', 'institution', '**institution'),
#  ('nationality',),
#  ('cause_of_death',),
#  ('place_of_birth', '**location', 'gender', '**gender'),
#  ('gender',),
#  ('location', '**location', 'place_of_death', '**place_of_death', 'gender'),
#  ('gender',
#   '**gender',
#   'place_of_birth',
#   '**place_of_death',
#   'place_of_birth'),
#  ('gender', '**gender'),
#  ('location', '**place_of_birth'),
#  ('profession', '**profession', 'profession'),
#  ('ethnicity', '**ethnicity', 'ethnicity', '**ethnicity'),
#  ('profession',
#   '**profession',
#   'place_of_birth',
#   '**place_of_death',
#   'place_of_death'),
#  ('profession', '**profession'),
#  ('institution',
#   '**institution',
#   'location',
#   '**place_of_birth',
#   'place_of_death'),
#  ('nationality',),
#  ('gender',),
#  ('nationality', '**location', 'gender'),
#  ('cause_of_death',),
#  ('profession',
#   '**profession',
#   'cause_of_death',
#   '**cause_of_death',
#   'profession'),
#  ('nationality',),
#  ('institution', '**institution'),
#  ('nationality', '**place_of_death', 'place_of_birth', '**place_of_birth'),
#  ('nationality',),
#  ('profession',),
#  ('place_of_death',
#   '**place_of_death',
#   'cause_of_death',
#   '**cause_of_death',
#   'gender'),
#  ('institution', '**institution', 'profession', '**profession'),
#  ('profession', '**profession', 'nationality'),
#  ('institution', '**institution', 'place_of_death', '**location'),
#  ('gender', '**gender'),
#  ('gender', '**gender', 'place_of_death', '**location'),
#  ('nationality', '**place_of_birth'),
#  ('cause_of_death',
#   '**cause_of_death',
#   'location',
#   '**place_of_birth',
#   'location'),
#  ('nationality', '**location', 'gender', '**gender'),
#  ('**place_of_death', 'gender', '**gender', 'nationality'),
#  ('profession', '**profession'),
#  ('profession', '**profession', 'place_of_birth'),
#  ('cause_of_death',),
#  ('profession', '**profession', 'location'),
#  ('nationality', '**place_of_death', 'place_of_death'),
#  ('gender', '**gender', 'gender', '**gender'),
#  ('nationality',),
#  ('nationality',),
#  ('institution', '**institution', 'institution', '**institution'),
#  ('parents', 'place_of_death', '**place_of_death'),
#  ('profession', '**profession'),
#  ('nationality', '**location', 'gender'),
#  ('gender', '**gender', 'gender'),
#  ('gender', '**gender', 'location', '**place_of_birth', 'place_of_birth'),
#  ('profession', '**profession', 'institution'),
#  ('nationality',
#   '**place_of_birth',
#   'place_of_birth',
#   '**nationality',
#   'location'),
#  ('parents', 'place_of_death', '**location', 'institution', '**institution'),
#  ('place_of_birth',
#   '**place_of_birth',
#   'place_of_birth',
#   '**place_of_birth',
#   'gender'),
#  ('gender',),
#  ('gender', '**gender', 'cause_of_death', '**cause_of_death', 'profession'),
#  ('children', 'gender', '**gender', 'children', 'gender'),
#  ('nationality', '**cause_of_death', 'cause_of_death', '**place_of_death'),
#  ('**location', 'place_of_death', '**place_of_death', 'gender', '**gender'),
#  ('profession',),
#  ('place_of_birth', '**place_of_death', 'profession'),
#  ('nationality', '**place_of_death', 'place_of_birth', '**place_of_birth'),
#  ('location', '**place_of_death', 'gender', '**gender', 'nationality'),
#  ('location', '**location'),
#  ('institution',),
#  ('place_of_death', '**location', 'nationality'),
#  ('place_of_birth', '**place_of_birth'),
#  ('nationality', '**nationality', 'place_of_death'),
#  ('place_of_death', '**place_of_birth', 'place_of_death', '**location'),
#  ('nationality', '**nationality', 'ethnicity'),
#  ('nationality',),
#  ('location', '**location', 'nationality', '**nationality'),
#  ('gender', '**gender', 'place_of_birth', '**location'),
#  ('profession',),
#  ('ethnicity',),
#  ('nationality', '**location', 'location', '**location', 'gender'),
#  ('place_of_birth', '**location', 'gender', '**gender', 'gender'),
#  ('place_of_birth', '**location'),
#  ('gender', '**gender', '**children'),
#  ('gender', '**gender', 'nationality', '**place_of_birth', 'profession'),
#  ('cause_of_death',),
#  ('place_of_birth', '**place_of_death', 'gender', '**gender', 'gender'),
#  ('nationality', '**nationality'),
#  ('place_of_death', '**place_of_death', 'place_of_death', '**location'),
#  ('place_of_birth', '**location', 'profession', '**profession', 'gender'),
#  ('place_of_birth', '**place_of_birth', 'profession', '**profession'),
#  ('gender', '**gender', 'place_of_birth'),
#  ('**location', '**spouse', 'location', '**location', 'profession'),
#  ('location', '**place_of_death', 'location', '**place_of_death'),
#  ('place_of_birth', '**place_of_birth', 'gender', '**gender'),
#  ('nationality', '**nationality'),
#  ('place_of_death', '**place_of_birth', 'gender', '**gender'),
#  ('place_of_birth', '**place_of_death', 'location', '**location', 'gender'),
#  ('location', '**place_of_death', 'place_of_birth'),
#  ('place_of_death', '**location', 'profession', '**profession'),
#  ('gender',),
#  ('gender', '**gender', 'place_of_death'),
#  ('place_of_death', '**place_of_birth', 'nationality'),
#  ('cause_of_death',),
#  ('gender', '**gender'),
#  ('nationality', '**place_of_death'),
#  ('institution',),
#  ('profession',),
#  ('**location',
#   'cause_of_death',
#   '**cause_of_death',
#   'location',
#   '**place_of_death'),
#  ('gender', '**gender', 'gender', '**gender', 'profession'),
#  ('institution', '**institution', 'religion'),
#  ('profession', '**profession', 'place_of_death', '**place_of_birth'),
#  ('nationality', '**nationality', 'gender'),
#  ('profession',),
#  ('profession', '**profession', 'place_of_death', '**place_of_death'),
#  ('nationality', '**nationality', 'gender', '**gender', 'gender'),
#  ('gender',),
#  ('place_of_birth',
#   '**place_of_death',
#   'place_of_birth',
#   '**place_of_birth',
#   'gender'),
#  ('gender', '**gender', 'profession'),
#  ('**place_of_birth',
#   'place_of_death',
#   '**location',
#   'place_of_death',
#   '**place_of_birth'),
#  ('place_of_birth', '**place_of_birth', 'gender', '**gender', 'gender'),
#  ('profession', '**profession', 'profession'),
#  ('place_of_birth',
#   '**place_of_death',
#   'location',
#   '**place_of_birth',
#   'nationality'),
#  ('religion',),
#  ('gender',),
#  ('location', '**location', 'gender', '**gender'),
#  ('nationality', '**place_of_death', 'gender', '**gender'),
#  ('place_of_death', '**place_of_death'),
#  ('ethnicity',),
#  ('profession', '**profession', 'gender', '**gender'),
#  ('institution', '**institution'),
#  ('location',
#   '**place_of_birth',
#   'nationality',
#   '**nationality',
#   'place_of_birth'),
#  ('place_of_birth',
#   '**place_of_death',
#   'profession',
#   '**profession',
#   'profession'),
#  ('gender', '**gender', 'profession', '**profession'),
#  ('nationality', '**location'),
#  ('cause_of_death', '**cause_of_death', 'ethnicity'),
#  ('place_of_death', '**place_of_death', 'place_of_birth', '**location'),
#  ('nationality',
#   '**ethnicity',
#   'place_of_death',
#   '**location',
#   'place_of_death'),
#  ('nationality',),
#  ('location', '**place_of_birth', 'nationality'),
#  ('gender',),
#  ('gender', '**gender', 'gender', '**gender'),
#  ('profession',),
#  ('gender', '**gender'),
#  ('nationality', '**place_of_death', 'institution', '**institution'),
#  ('gender', '**gender', 'gender', '**gender'),
#  ('profession',),
#  ('place_of_birth', '**place_of_death', 'gender'),
#  ('gender', '**gender'),
#  ('**place_of_death',
#   'profession',
#   '**profession',
#   'nationality',
#   '**nationality'),
#  ('gender', '**gender'),
#  ('**place_of_birth', 'gender', '**gender'),
#  ('place_of_death', '**place_of_death', 'gender', '**gender'),
#  ('location', '**location', 'place_of_death'),
#  ('nationality',),
#  ('**place_of_birth', 'gender', '**gender', 'profession', '**profession'),
#  ('gender',),
#  ('gender',),
#  ('profession',),
#  ('place_of_birth', '**place_of_birth', 'parents', '**spouse'),
#  ('gender', '**gender', 'place_of_birth'),
#  ('cause_of_death', '**cause_of_death', 'profession', '**profession'),
#  ('nationality', '**profession'),
#  ('gender', '**gender', 'profession'),
#  ('gender',),
#  ('place_of_death', '**place_of_birth', 'religion', '**religion'),
#  ('nationality',),
#  ('institution',),
#  ('nationality', '**location', 'location', '**place_of_death', 'profession'),
#  ('profession',),
#  ('**location', 'location', '**place_of_birth', 'location'),
#  ('gender',),
#  ('**institution', 'place_of_death', '**location', 'gender'),
#  ('place_of_birth',
#   '**place_of_birth',
#   'location',
#   '**location',
#   'institution'),
#  ('ethnicity',),
#  ('gender', '**gender'),
#  ('profession', '**profession', '**spouse'),
#  ('nationality', '**place_of_birth', 'nationality', '**nationality'),
#  ('location', '**place_of_death', 'profession', '**profession', 'gender'),
#  ('nationality', '**nationality', 'gender', '**gender', 'gender'),
#  ('place_of_birth', '**place_of_birth'),
#  ('spouse', '**parents', 'spouse'),
#  ('place_of_birth', '**place_of_birth', 'place_of_death'),
#  ('place_of_birth', '**place_of_birth', 'profession', '**profession'),
#  ('nationality', '**nationality', 'nationality', '**place_of_birth'),
#  ('cause_of_death', '**cause_of_death', 'religion', '**religion', 'religion'),
#  ('nationality', '**place_of_birth'),
#  ('institution',),
#  ('gender', '**gender'),
#  ('institution',),
#  ('place_of_birth', '**place_of_birth'),
#  ('institution', '**institution', 'institution', '**institution'),
#  ('cause_of_death',),
#  ('gender', '**gender', 'institution'),
#  ('place_of_birth', '**place_of_birth', 'nationality', '**profession'),
#  ('nationality', '**nationality', 'place_of_death', '**location'),
#  ('gender',),
#  ('ethnicity', '**ethnicity', '**spouse', 'gender', '**gender'),
#  ('ethnicity',),
#  ('gender',),
#  ('nationality', '**profession'),
#  ('parents', '**parents', 'children'),
#  ('**spouse', 'spouse', '**spouse', '**children'),
#  ('nationality',),
#  ('place_of_birth', '**place_of_birth', 'location', '**place_of_birth'),
#  ('institution', '**institution'),
#  ('gender',),
#  ('place_of_death', '**location', 'gender', '**gender'),
#  ('gender', '**gender', '**children'),
#  ('**institution', 'gender', '**gender', 'cause_of_death', '**cause_of_death'),
#  ('place_of_birth',
#   '**location',
#   'nationality',
#   '**profession',
#   'nationality'),
#  ('location', '**location', 'institution', '**institution', 'place_of_death'),
#  ('religion', '**religion', '**parents', 'place_of_death'),
#  ('place_of_birth', '**location'),
#  ('nationality',),
#  ('**parents', 'place_of_death', '**place_of_death', 'gender', '**gender'),
#  ('place_of_death', '**place_of_birth', 'gender', '**gender'),
#  ('nationality', '**place_of_death', 'institution', '**institution'),
#  ('**ethnicity', 'ethnicity', '**ethnicity', 'gender', '**gender'),
#  ('religion', '**religion'),
#  ('gender',),
#  ('profession',),
#  ('nationality',),
#  ('gender', '**gender'),
#  ('nationality',
#   '**place_of_birth',
#   'place_of_death',
#   '**location',
#   'place_of_death'),
#  ('nationality',),
#  ('nationality', '**location'),
#  ('nationality', '**place_of_birth', 'profession', '**profession'),
#  ('place_of_birth', '**place_of_birth', 'religion', '**religion'),
#  ('gender', '**gender', 'place_of_death'),
#  ('nationality', '**place_of_birth'),
#  ('gender', '**gender', 'place_of_death', '**place_of_birth'),
#  ('gender',),
#  ('gender', '**gender'),
#  ('parents',
#   'nationality',
#   '**place_of_death',
#   'place_of_death',
#   '**nationality'),
#  ('nationality', '**place_of_birth', 'nationality', '**location', 'location'),
#  ('gender', '**gender'),
#  ('parents', '**children', 'place_of_death'),
#  ('gender',),
#  ('nationality',),
#  ('nationality',),
#  ('place_of_death',
#   '**place_of_death',
#   'place_of_birth',
#   '**place_of_death',
#   'children'),
#  ('place_of_death',
#   '**place_of_birth',
#   'place_of_birth',
#   '**location',
#   'profession'),
#  ('location', '**location', 'location'),
#  ('place_of_death', '**place_of_birth', 'cause_of_death'),
#  ('gender', '**gender', 'place_of_death'),
#  ('gender', '**gender'),
#  ('gender', '**gender', 'place_of_birth'),
#  ('gender', '**gender', 'cause_of_death'),
#  ('nationality', '**profession', 'profession'),
#  ('cause_of_death',),
#  ('cause_of_death',),
#  ('place_of_birth',
#   '**location',
#   'place_of_death',
#   '**place_of_birth',
#   'place_of_birth'),
#  ('place_of_death', '**place_of_death', 'place_of_death'),
#  ('place_of_death', '**place_of_death', 'nationality', '**nationality'),
#  ('profession',
#   '**profession',
#   'place_of_death',
#   '**place_of_birth',
#   'nationality'),
#  ('place_of_birth',
#   '**location',
#   'location',
#   '**place_of_birth',
#   'nationality'),
#  ('**location', 'location', '**place_of_death', 'gender'),
#  ('gender',),
#  ('profession', '**profession'),
#  ('**place_of_birth', 'location', '**location', 'profession'),
#  ('place_of_birth', '**location'),
#  ('nationality', '**location', 'location'),
#  ('gender',),
#  ('religion', '**religion', 'profession'),
#  ('gender', '**gender', 'profession'),
#  ('gender',),
#  ('nationality', '**nationality', 'place_of_birth', '**place_of_death'),
#  ('place_of_birth', '**location', 'place_of_birth', '**location'),
#  ('gender', '**gender', 'nationality', '**place_of_death', 'gender'),
#  ('religion', '**religion', 'cause_of_death'),
#  ('**place_of_death', 'religion', '**religion', 'location', '**location'),
#  ('profession', '**profession', 'location'),
#  ('institution',),
#  ('nationality', '**place_of_birth'),
#  ('gender', '**gender', 'cause_of_death', '**cause_of_death'),
#  ('nationality', '**cause_of_death'),
#  ('profession', '**profession'),
#  ('gender', '**gender', 'place_of_birth', '**location'),
#  ('place_of_death', '**place_of_birth', 'profession'),
#  ('gender', '**gender', 'place_of_death', '**location', 'gender'),
#  ('profession',),
#  ('profession', '**profession', 'profession', '**profession'),
#  ('institution',
#   '**institution',
#   'place_of_birth',
#   '**place_of_birth',
#   'nationality'),
#  ('profession',
#   '**profession',
#   'place_of_birth',
#   '**place_of_birth',
#   'place_of_birth'),
#  ('nationality', '**place_of_death', 'place_of_death'),
#  ('cause_of_death',),
#  ('religion',),
#  ('parents', '**spouse', '**spouse'),
#  ('**institution', 'place_of_death', '**place_of_death'),
#  ('nationality', '**location'),
#  ('gender', '**gender', 'place_of_death'),
#  ('nationality',
#   '**place_of_birth',
#   'place_of_birth',
#   '**location',
#   'nationality'),
#  ('nationality', '**nationality', 'gender', '**gender', 'place_of_birth'),
#  ('profession', '**profession', 'profession', '**profession'),
#  ('place_of_death',
#   '**place_of_birth',
#   'profession',
#   '**profession',
#   'profession'),
#  ('place_of_death', '**location', 'nationality', '**place_of_birth'),
#  ('profession',),
#  ('religion',),
#  ('cause_of_death',),
#  ('gender', '**gender', 'place_of_birth', '**place_of_death', 'religion'),
#  ('gender', '**gender', 'place_of_death'),
#  ('profession', '**children', 'gender', '**gender', 'location'),
#  ('place_of_death', '**place_of_birth', 'religion'),
#  ('gender',),
#  ('place_of_death',
#   '**place_of_death',
#   'place_of_death',
#   '**place_of_death',
#   'place_of_birth'),
#  ('place_of_birth', '**place_of_death'),
#  ('nationality', '**place_of_death', 'place_of_death'),
#  ('location', '**place_of_birth', 'place_of_birth', '**place_of_death'),
#  ('place_of_birth', '**place_of_birth'),
#  ('cause_of_death', '**cause_of_death', 'place_of_death', '**place_of_death'),
#  ('parents', '**parents', 'spouse'),
#  ('profession',),
#  ('place_of_death', '**location', 'location', '**location'),
#  ('**place_of_birth', 'gender', '**gender'),
#  ('gender', '**gender', 'gender', '**gender'),
#  ('**location', 'gender', '**gender', 'gender'),
#  ('profession', '**profession', 'place_of_death'),
#  ('place_of_death', '**place_of_death'),
#  ('cause_of_death', '**cause_of_death', 'place_of_birth'),
#  ('profession', '**profession', 'gender', '**gender'),
#  ('place_of_death', '**place_of_death', 'nationality'),
#  ('place_of_birth', '**location', 'nationality', '**place_of_death'),
#  ('**place_of_death', 'place_of_birth'),
#  ('gender', '**gender', 'gender'),
#  ('gender',),
#  ('**parents', 'spouse', '**parents'),
#  ('institution',),
#  ('gender', '**gender'),
#  ('**parents', '**children', 'location'),
#  ('profession',),
#  ('place_of_birth', '**location', 'nationality'),
#  ('profession', '**profession'),
#  ('place_of_birth', '**location', 'place_of_death'),
#  ('nationality',
#   '**profession',
#   'nationality',
#   '**place_of_death',
#   'place_of_death'),
#  ('place_of_death', '**place_of_death'),
#  ('gender', '**gender', 'profession', '**profession'),
#  ('**institution', 'location', '**place_of_death'),
#  ('profession', '**profession', 'profession', '**profession', 'location'),
#  ('nationality', '**nationality', 'institution', '**institution', 'gender'),
#  ('location',
#   '**place_of_birth',
#   'place_of_birth',
#   '**place_of_death',
#   'place_of_death'),
#  ('profession', '**profession', 'gender', '**gender', 'place_of_death'),
#  ('cause_of_death',),
#  ('profession', '**profession', 'profession', '**profession', 'gender'),
#  ('place_of_birth',
#   '**place_of_birth',
#   'place_of_death',
#   '**place_of_death',
#   'profession'),
#  ('gender', '**gender', 'gender', '**gender', 'place_of_death'),
#  ('location', '**location', 'profession', '**profession'),
#  ('nationality', '**location'),
#  ('location', '**place_of_birth', 'gender', '**gender'),
#  ('gender', '**gender'),
#  ('place_of_death', '**location', 'nationality', '**place_of_death'),
#  ('religion',),
#  ('nationality',
#   '**place_of_birth',
#   'place_of_death',
#   '**location',
#   'institution'),
#  ('place_of_birth',
#   '**place_of_death',
#   'place_of_birth',
#   '**place_of_birth',
#   'gender'),
#  ('gender', '**gender', 'gender', '**gender', 'location'),
#  ('gender', '**gender', 'location', '**place_of_birth'),
#  ('place_of_birth', '**place_of_death'),
#  ('ethnicity',),
#  ('place_of_death', '**place_of_death', 'institution'),
#  ('nationality', '**ethnicity', 'institution', '**institution', 'gender'),
#  ('gender', '**gender', 'gender', '**gender', 'place_of_death'),
#  ('nationality',
#   '**nationality',
#   'ethnicity',
#   '**ethnicity',
#   'cause_of_death'),
#  ('profession',),
#  ('profession',),
#  ('profession', '**profession'),
#  ('place_of_birth', '**location'),
#  ('gender',),
#  ('place_of_birth',
#   '**place_of_birth',
#   'nationality',
#   '**nationality',
#   'gender'),
#  ('gender', '**gender'),
#  ('**location', 'gender', '**gender'),
#  ('gender', '**gender'),
#  ('nationality',),
#  ('nationality', '**place_of_birth', 'location', '**place_of_birth'),
#  ('nationality',),
#  ('gender',),
#  ('profession', '**profession', 'location', '**place_of_birth', 'nationality'),
#  ('gender', '**gender'),
#  ('place_of_death', '**location'),
#  ('**place_of_death', 'spouse', 'place_of_death'),
#  ('gender',),
#  ('place_of_death', '**place_of_death', 'gender', '**gender'),
#  ('**place_of_birth', 'gender', '**gender', 'gender', '**gender'),
#  ('gender', '**gender', 'place_of_birth'),
#  ('location', '**location', 'cause_of_death', '**cause_of_death'),
#  ('gender', '**gender', 'place_of_death'),
#  ('place_of_birth',
#   '**place_of_death',
#   'location',
#   '**location',
#   'place_of_birth'),
#  ('profession', '**profession'),
#  ('gender', '**gender', 'place_of_birth', '**location', 'place_of_birth'),
#  ('place_of_death', '**place_of_birth'),
#  ('**place_of_birth', 'place_of_death'),
#  ('parents', 'gender', '**gender'),
#  ('place_of_death', '**place_of_birth', 'place_of_birth', '**place_of_birth'),
#  ('gender', '**gender', 'nationality', '**nationality', 'institution'),
#  ('gender', '**gender', 'place_of_birth', '**location', 'nationality'),
#  ('gender',),
#  ('gender',),
#  ('ethnicity',),
#  ('nationality', '**nationality', 'location', '**place_of_birth', 'location'),
#  ('nationality', '**location', 'religion'),
#  ('**children', '**children', '**parents', 'children', 'place_of_death'),
#  ('place_of_death', '**place_of_death', 'gender'),
#  ('gender',),
#  ('gender', '**gender'),
#  ('nationality',),
#  ('institution',),
#  ('nationality',),
#  ('place_of_death', '**place_of_death', 'gender', '**gender', 'profession'),
#  ('institution',),
#  ('place_of_birth',
#   '**location',
#   'nationality',
#   '**place_of_death',
#   'profession'),
#  ('**place_of_birth', 'gender', '**gender'),
#  ('place_of_death', '**location', 'gender'),
#  ('profession',),
#  ('place_of_death', '**place_of_birth'),
#  ('place_of_birth', '**location', '**spouse'),
#  ('nationality',),
#  ('nationality',),
#  ('gender', '**gender', 'place_of_death'),
#  ('gender', '**gender', 'profession', '**profession'),
#  ('gender', '**gender'),
#  ('gender', '**gender', 'profession'),
#  ('**location', 'children', 'parents', 'location', '**location'),
#  ('place_of_birth', '**place_of_birth'),
#  ('gender', '**gender'),
#  ('place_of_death', '**place_of_birth', 'nationality', '**nationality'),
#  ('gender', '**gender', 'place_of_death'),
#  ('gender', '**gender'),
#  ('location', '**location', 'location', '**location'),
#  ('profession',),
#  ('gender', '**gender'),
#  ('gender',),
#  ('place_of_death',
#   '**place_of_death',
#   'place_of_death',
#   '**place_of_birth',
#   'gender'),
#  ('cause_of_death', '**cause_of_death', 'nationality', '**place_of_death'),
#  ('institution',),
#  ('ethnicity', '**ethnicity', 'nationality', '**location'),
#  ('profession',
#   '**profession',
#   'nationality',
#   '**place_of_death',
#   'place_of_death'),
#  ('cause_of_death',),
#  ('gender',),
#  ('gender', '**gender', 'profession', '**profession'),
#  ('nationality', '**ethnicity', 'ethnicity'),
#  ('location', '**location', 'gender', '**gender', 'gender'),
#  ('location', '**location', 'gender', '**gender'),
#  ('place_of_death', '**place_of_birth', 'place_of_death', '**place_of_death'),
#  ('gender', '**gender'),
#  ('nationality',),
#  ('profession', '**profession', 'gender', '**gender'),
#  ('place_of_birth', '**place_of_birth', 'nationality', '**place_of_death'),
#  ('place_of_death', '**location', 'gender', '**gender', 'gender'),
#  ('nationality', '**location', 'location'),
#  ('profession',),
#  ('gender', '**gender', '**children', '**parents'),
#  ('gender', '**gender', 'location', '**place_of_birth', 'profession'),
#  ('location', '**location', 'nationality'),
#  ('profession', '**profession'),
#  ('gender',),
#  ('nationality',),
#  ('profession', '**profession'),
#  ('institution',),
#  ('place_of_birth', '**place_of_birth', 'location'),
#  ('gender', '**gender', 'place_of_death', '**location', 'nationality'),
#  ('cause_of_death',),
#  ('location', '**place_of_death', 'profession', '**profession'),
#  ('nationality', '**place_of_birth', 'place_of_death'),
#  ('**parents', 'parents', 'parents', '**spouse', '**spouse'),
#  ('location', '**place_of_death', 'gender'),
#  ('nationality', '**profession', 'profession', '**location'),
#  ('institution', '**institution', 'place_of_death'),
#  ('place_of_birth',
#   '**place_of_death',
#   'place_of_death',
#   '**place_of_death',
#   'institution'),
#  ('nationality',
#   '**place_of_death',
#   'children',
#   '**children',
#   'place_of_birth'),
#  ('**location',
#   'place_of_death',
#   '**place_of_death',
#   'profession',
#   '**profession'),
#  ('gender', '**gender', 'nationality', '**location'),
#  ('profession', '**profession', 'place_of_death'),
#  ('gender', '**gender'),
#  ('gender', '**gender', 'gender', '**gender', 'gender'),
#  ('profession',),
#  ('gender',),
#  ('place_of_death', '**place_of_death', 'place_of_birth'),
#  ('**children', '**spouse', 'spouse', '**children', 'nationality'),
#  ('religion', '**religion', 'religion'),
#  ('nationality', '**location', 'location'),
#  ('institution', '**institution', 'profession', '**profession'),
#  ...]

# %%
head_entities
# Out:
# ['ananda_maitreya',
#  'enrique_de_villena',
#  'simone_renant',
#  'moses_harvey',
#  'isaac_r_harrington',
#  'ontario',
#  'bridget_of_sweden',
#  'saint_alban',
#  'asa_p_blunt',
#  'jr_mitchell',
#  'donald_pleasence',
#  'horst_bienek',
#  'telavi',
#  'norberto_romualdez',
#  'werner_klemperer',
#  'francisco_guerrero',
#  'aleksander_wielopolski',
#  'pablo_antonio',
#  'ramon_sampedro',
#  'ninette_de_valois',
#  'vouziers',
#  'jan_august_hendrik_leys',
#  'john_rauch',
#  'peter_iii_of_portugal',
#  'david_r_brower',
#  'mumbai',
#  'totteridge',
#  'catherine_of_siena',
#  'angelique_pettyjohn',
#  'unity_mitford',
#  'teresa_de_la_parra',
#  'george_holland',
#  'henry_darcy',
#  'robert_stirling',
#  'francois_edouard_picot',
#  'eduard_vogel',
#  'francis_l_sullivan',
#  'samuel_baldwin_marks_young',
#  'hubert_harrison',
#  'octave_chanute',
#  'ernst_von_wildenbruch',
#  'gussie_davis',
#  'richard_yates_1860',
#  'johann_gottlieb_heineccius',
#  'masaharu_homma',
#  'wladyslaw_grabski',
#  'bess_flowers',
#  'amman',
#  'john_langdon',
#  'richard_b_anderson',
#  'oscar_v_peterson',
#  'john_p_stockton',
#  'reginald_punnett',
#  'kazimierz_zalewski',
#  'olaf_fonss',
#  'giorgio_perlasca',
#  'lucie_lady_duff_gordon',
#  'james_m_cox',
#  'elliott_p_joslin',
#  'billy_and_bobby_mauch',
#  'thomas_baldwin_peddie',
#  'mohammed_haydar_zammar',
#  'naomi_childers',
#  'charles_arbuthnot',
#  'kevin_izod_odoherty',
#  'edward_adelbert_doisy',
#  'ivanovo',
#  'johannes_vilhelm_jensen',
#  'helena_faucit',
#  'g_william_miller',
#  'aaron_willard',
#  'eulalia_perez_de_guillen_marine',
#  'lindsay_hawker',
#  'binh_dinh_province',
#  'george_otis_smith',
#  'bill_lovett',
#  'hedwig_elizabeth_charlotte_of_holstein_gottorp',
#  'adriaen_van_der_werff',
#  'theophilus_parsons',
#  'hugues_doneau',
#  'morris_rosenfeld',
#  'paris_theodore',
#  'stephen_m_young',
#  'wilhelm_suss',
#  'anna_of_austria',
#  'walther_meissner',
#  'james_carne',
#  'ed_cole',
#  'ernst_kummer',
#  'george_h_main',
#  'uncle_dave_macon',
#  'huang_yuanyong',
#  'angus_fairhurst',
#  'hyacinthe_collin_de_vermont',
#  'alfred_clebsch',
#  'nicolino_locche',
#  'margaret_of_burgundy_queen_of_navarre',
#  'samuel_w_reynolds',
#  'mikhail_glinka',
#  'tomas_carrasquilla',
#  'christian_duke_of_saxe_eisenberg',
#  'mack_sennett',
#  'serial_killer',
#  'numa_morikazu',
#  'jacques_villere',
#  'ludwig_windthorst',
#  'henry_paget_1st_marquess_of_anglesey',
#  'master_betty',
#  'theo_marzials',
#  'bruce_edwards_ivins',
#  'hector_giacomelli',
#  'norway',
#  'ken_campbell_1941',
#  'nicolaas_pieneman',
#  'michael_a_monsoor',
#  'gerard_manley_hopkins',
#  'jacob_meir',
#  'pierre_dugua_sieur_de_monts',
#  'yevhen_petrushevych',
#  'helen_westley',
#  'simon_ungers',
#  'yelabuga',
#  'h_clay_myers_jr',
#  'pauli_murray',
#  'archduke_ferdinand_karl_joseph_of_austria-este',
#  'franz_studniczka',
#  'ron_vawter',
#  'julius_binder',
#  'robert_taschereau',
#  'marcheline_bertrand',
#  'james_purdy',
#  'pedro_antonio_de_alarcon',
#  'archibald_macleish',
#  'andrei_sinyavsky',
#  'betty_blue',
#  'muramatsu_sh_fu',
#  'billy_rush_masters',
#  'marie_windsor',
#  'arnold_von_bruck',
#  'petr_novak',
#  'alexander_meiklejohn',
#  'ruby_keeler',
#  'jacqueline_logan',
#  'george_zinkhan',
#  'ustad_allah_rakha',
#  'anna_anderson',
#  'simple_kapadia',
#  'dominic_elwes',
#  'george_leslie_mackay',
#  'abdullah_shirazi',
#  'toni_frissell',
#  'valentin_glushko',
#  'bohemia',
#  'shields_green',
#  'eleazer_mccomb',
#  'denys_val_baker',
#  'albert_p_clark',
#  'kubo_tadazane',
#  'bugs_moran',
#  'adolphe_guillaumat',
#  'william_workman',
#  'chris_wood_1944',
#  'edward_durell_stone',
#  'pauline_mills_mcgibbon',
#  'george_farm',
#  'turgut_reis',
#  'thomas_s_baer',
#  'william_a_earle',
#  'domenico_zampieri',
#  'zhenfei',
#  'sabu_dastagir',
#  'reinhard_h_luthin',
#  'felix_morrow',
#  'giovanni_battista_casanova',
#  'james_henry_greathead',
#  'jean-baptiste_alphonse_karr',
#  'george_b_anderson',
#  'jean_baptiste_edouard_bornet',
#  'kanehiro_takaki',
#  'ludwig_boltzmann',
#  'james_goold_cutler',
#  'gordon_pask',
#  'count_alexei_alexandrovich_belevsky_zhukovsky',
#  'margaret_fuller',
#  'anne_henriette_of_bavaria',
#  'phoe_par_gyi',
#  'hamilton_fish_iii',
#  'jock_wallace',
#  'john_gaffney',
#  'edward_robeson_taylor',
#  'paisius_of_hilendar',
#  'otto_kron',
#  'alan_lloyd_hodgkin',
#  'magnus_pegel',
#  'john_buscema',
#  'carl_brashear',
#  'e_c_segar',
#  'la_porte',
#  'john_clerk_of_eldin',
#  'heinrich_reimann',
#  'thomas_green',
#  'viveca_lindfors',
#  'moina_mathers',
#  'lloyd_monserratt',
#  'frank_parker_day',
#  'herbert_jenner_fust',
#  'visconte_maggiolo',
#  'alys_countess_of_the_vexin',
#  'dillwyn_parrish',
#  'jacqueline_kennedy_onassis',
#  'elisabeth_bergner',
#  'graham_moffatt',
#  'amasa_mason_lyman',
#  'norfolk',
#  'alfonso_iv_of_leon',
#  'karl_robert_eduard_von_hartmann',
#  'richard_jewell',
#  'frank_hereford',
#  'evan_tanner',
#  'philip_carey',
#  'benedetto_varchi',
#  'charles_allston_collins',
#  'thomas_gainsborough',
#  'grand_duke_nikolai_konstantinovich_of_russia',
#  'johann_nepomuk_von_nussbaum',
#  'john_sebastian_helmcken',
#  'magnentius',
#  'jared_sparks',
#  'lenore_ulric',
#  'willem_buys',
#  'joseph_gurney_cannon',
#  'antoine_deparcieux',
#  'mrs_w_grimm',
#  'walter_p_brownlow',
#  'lewis_bernstein_namier',
#  'clifford_possum_tjapaltjarri',
#  'allen_bristol_aylesworth',
#  'gordon_paiea_chung_hoon',
#  'don_porter',
#  'eugen_bamberger',
#  'philipp_ii_count_of_schaumburg_lippe',
#  'ben_gold',
#  'josephine_lang',
#  'nawabzada_nasrullah_khan',
#  'daniel_pearl',
#  'johann_von_miquel',
#  'alfred_l_werker',
#  'alexis_bouvard',
#  'petersham_new_south_wales',
#  'jack_watling',
#  'robert_henderson_robertson',
#  'edmund_rice',
#  'chagatai_khan',
#  'rolf_hagedorn',
#  'akwasi_afrifa',
#  'reinaldo_arenas',
#  'eric_hoffer',
#  'swede_risberg',
#  'harry_m_daugherty',
#  'caesar_a_rodney',
#  'adna_chaffee',
#  'michael_ross',
#  'saint_erentrude',
#  'william_jessop',
#  'charles_evans_whittaker',
#  'colin_macleod',
#  'zacharias_janssen',
#  'robert_c_delarge',
#  'august_von_der_heydt',
#  'arnold_goodman_baron_goodman',
#  'charles_gratiot',
#  'giuseppe_addobbati',
#  'marian_spore_bush',
#  'harry_stewart_new',
#  'solomon_blatt',
#  'thomas_merton',
#  'wurttemberg',
#  'alfred_kubin',
#  'cecily_grey_marchioness_of_dorset',
#  'mahmud_jam',
#  'david_beck',
#  'thompson_connecticut',
#  'willard_fiske',
#  'claude_piron',
#  'keith_whitley',
#  'scott_brayton',
#  'kevin_grubb',
#  'sigurd_i_of_norway',
#  'birmingham_alabama',
#  'kirk_lippold',
#  'godfrey_binaisa',
#  'ranulph_de_gernon_2nd_earl_of_chester',
#  'verne_orr',
#  'andreas_avgerinos',
#  'carl_frederik_von_breda',
#  'lou_fine',
#  'victor_h_schiro',
#  'monroe_michigan',
#  'william_dobson',
#  'henry_reuterdahl',
#  'charles_etienne_louis_camus',
#  'william_stanley_jevons',
#  'anthony_hecht',
#  'john_ray',
#  'william_jones_1760',
#  'baron_stow',
#  'francisco_manuel_blanco',
#  'julius_schwartz',
#  'robert_bargeron',
#  'wallace_f_bennett',
#  'clyde_mcphatter',
#  'william_willcocks',
#  'fernando_sor',
#  'dutta_samant',
#  'samael_aun_weor',
#  'mitchell_kennerley',
#  'marie_jules_cesar_savigny',
#  'murder_of_rhys_jones',
#  'ontario_oregon',
#  'gainesville',
#  'george_schneevoigt',
#  'michael_sheard',
#  'hugh_the_younger_despenser',
#  'wladimir_gelfand',
#  'zenobe_gramme',
#  'john_d_new',
#  'samuel_franklin_emmons',
#  'tunis',
#  'augustus_fitzroy_3rd_duke_of_grafton',
#  'philippine_elisabeth_of_orleans',
#  'ithaca_new_york',
#  'indio',
#  'comandante_ramona',
#  'h_guy_hunt',
#  'bernard_cornfeld',
#  'dick_powell',
#  'bo_diddley',
#  'giuseppe_garibaldi',
#  'james_b_howell',
#  'kevin_dubrow',
#  'marie_jules_cesar_savigny',
#  'belfast',
#  'david_brewster',
#  'ivan_starov',
#  'leonardo_da_vinci',
#  'prince_carlos_of_bourbon_two_sicilies',
#  'fulk_iii_of_anjou',
#  'jeronimo_zurita_y_castro',
#  'al_hunter_ashton',
#  'john_martin_poyer',
#  'johan_nicolai_madvig',
#  'josephine_lang',
#  'jose_asuncion_silva',
#  'collingwood_victoria',
#  'tucson',
#  'adelaide_del_vasto',
#  'samuel_wesley',
#  'wilhelm_kuchelbecker',
#  'godfrey_howitt',
#  'kevin_granata',
#  'samuel_eells',
#  'david_lipscomb',
#  'jacob_moleschott',
#  'thomas_wright_1711',
#  'hermann_von_francois',
#  'clifton_deberry',
#  'rudolf_bultmann',
#  'john_f_boynton',
#  'cochinchina',
#  'yitzchak_kaduri',
#  'charles_e_brady_jr',
#  'public_speaker',
#  'prentiss_mellen',
#  'gladys_swarthout',
#  'elisa_von_der_recke',
#  'jean_baptiste_du_val_de_grace_baron_de_cloots',
#  'thomas_butler_king',
#  'kathleen_byron',
#  'melvin_belli',
#  'franti_ek_klacel',
#  'jacob_veldhuyzen_van_zanten',
#  'franklin_knight_lane',
#  'eugene_t_booth',
#  'karl_erb',
#  'east_orange',
#  'enoch_seeman',
#  'max_mason',
#  'monroe_hayward',
#  'sebastian_of_portugal',
#  'paul_sweezy',
#  'francisco_da_costa_gomes',
#  'joseph_dunninger',
#  'lucio_fulci',
#  'john_stapp',
#  'denis_diderot',
#  'eugene_mallove',
#  'university_of_toronto',
#  'stan_jones_1931',
#  'sebastian_franck',
#  'constantine_vi',
#  'kevin_grubb',
#  'charles-adolphe_wurtz',
#  'gabriel_lippmann',
#  'gertrud_naumann',
#  'isabel_marshal',
#  'robert_strauss_new_york',
#  'klondike_douglass',
#  'fielding_l_wright',
#  'edmund_lee_jr',
#  'emperor_go-uda',
#  'washington_lafayette_elliott',
#  'karl_friedrich_otto_westphal',
#  'ford_madox_brown',
#  'jean-baptiste_morin',
#  'princess_luisa_carlotta_of_the_two_sicilies',
#  'crescentius_the_younger',
#  'infanta_beatriz_of_spain',
#  'angel_sauce',
#  'joe_choynski',
#  'ewen_neil_mcqueen',
#  'pim_fortuyn',
#  'alfred_newton',
#  'john_h_outland',
#  'university_of_kansas',
#  'charles_j_bell',
#  'henry_trefflich',
#  'antonio_francesco_carli',
#  'lilly_steinschneider',
#  'john_oxley',
#  'william_ball_gilbert',
#  'simone_renant',
#  'michael_anthony_bilandic',
#  'anne_duchess_of_luxembourg',
#  'jefferson_j_deblanc',
#  'chief_logan',
#  'edward_the_elder',
#  'sir_william_jenner_1st_baronet',
#  'bramwell_booth',
#  'simon_mayr',
#  'philippe_charles_3rd_count_of_arenberg',
#  'thomas_edward_cliffe_leslie',
#  'juhan_viiding',
#  'john_campbell_elliott',
#  'spokesman',
#  'cyril_demarne',
#  'pacific_university',
#  'coenraad_jacob_temminck',
#  'george_h_atkinson',
#  'robert_zarinsky',
#  'lars_sonck',
#  'azie_taylor_morton',
#  'princess_alexandra_of_bavaria',
#  'micha_josef_berdyczewski',
#  'jaap_eden',
#  'daniel_dixon_2nd_baron_glentoran',
#  'william_donahey',
#  'vicente_perez_rosales',
#  'perry_belmont',
#  'frances_munds',
#  'emanuel_sweert',
#  'leon_trotsky',
#  'ignaz_von_plener',
#  'jefferson_davis',
#  'qiu_ying',
#  'neuruppin',
#  'john_t_thompson',
#  'yamamoto_shugoro',
#  'bhaskara',
#  'lorenzo_di_pierfrancesco_de_medici',
#  'columbus_georgia',
#  'rene_de_birague',
#  'tanguturi_prakasam',
#  'edmund_ludlow',
#  'reading',
#  'minor_butler_poole',
#  'toulouse',
#  'ferenc_mora',
#  'patrick_keely',
#  'antun_stipan_ic',
#  'ilia_the_righteous',
#  'helene_deutsch',
#  'paul_p_harris',
#  'stowe_vermont',
#  'frances_polidori',
#  'harry_hay',
#  'daniel_itzig',
#  'elizabeth_bentley_1767',
#  'sei_shonagon',
#  'benilde_romancon',
#  'clarence_dutton',
#  'ed_ricketts',
#  'andrew_cunanan',
#  'john_hutt',
#  'kapurthala',
#  'georges_lemaitre',
#  'may_irwin',
#  'frits_zernike',
#  'david_lavender',
#  'jan_groenveld',
#  'william_melville',
#  'casper_asbjornson',
#  'carlos_finlay',
#  'joseph_lancaster',
#  'jan_blahoslav',
#  'ion_emanuel_florescu',
#  'june_martel',
#  'dave_cockrum',
#  'henry_paget_1st_marquess_of_anglesey',
#  'pehr_edman',
#  'james_mcgill',
#  'alcsutdoboz',
#  'edgar_leopold_layard',
#  'ann_eliza_bleecker',
#  'samuel_martin_kier',
#  'hildegard_of_bingen',
#  'william_butler_yeats',
#  'thomas_macdonald_patterson',
#  'august_von_pettenkofen',
#  'charles_hermite',
#  'gunther_rucker',
#  'william_sharon',
#  'thierry_aubin',
#  'lyman_abbott',
#  'rasul_amin',
#  'felipe_pedrell',
#  'franklin_schaffner',
#  'dwight_d_eisenhower',
#  'mike_parkes',
#  'anton_van_leeuwenhoek',
#  'nathan_meeker',
#  'leon_r_taylor',
#  'dorothy_deborba',
#  'jan_stuyt',
#  'george_thesiger',
#  'spessard_holland',
#  'james_f_byrnes',
#  'william_cooley',
#  'robert_henry_lawrence_jr',
#  'jadin_wong',
#  'lola_beltran',
#  'george_sutherland',
#  'elmer_davis',
#  'aris_t_allen',
#  'fred_quimby',
#  'osamu_tezuka',
#  'georgette_heyer',
#  'lee_choon_seng',
#  'andrei_tarkovsky',
#  'ioan_slavici',
#  'john_connally',
#  'clifton_chenier',
#  'luis_alcoriza',
#  'walter_roth',
#  'grete_wiesenthal',
#  'paul_cravath',
#  'john_bell_williams',
#  'george_partridge',
#  'john_gore',
#  'huda_bin_abdul_haq',
#  'mickey_conroy',
#  'mongolia',
#  'lorraine_hunt_lieberson',
#  'thomas_stevenson_1838',
#  'subramaniyam_sugirdharajan',
#  'holland_nimmons_mctyeire',
#  'p_b_chatwin',
#  'hans_seyffer',
#  'joseph_pilates',
#  'charles_lennox_3rd_duke_of_richmond',
#  'iris_chang',
#  'anton_ulrich_duke_of_saxe_meiningen',
#  'fleiss_joseph_l',
#  'valery_bryusov',
#  'charles_nicoletti',
#  'james_d_bettridge',
#  'haakon_lie',
#  'john_chandler',
#  'virginia_woolf',
#  'ekaterina_furtseva',
#  'angela_king',
#  'donald_judd',
#  'charles_grey_1804',
#  'robert_hermann_schomburgk',
#  'bosnia_and_herzegovina',
#  'mian_tufail_mohammad',
#  'arnoldus_montanus',
#  'rudy_perpich',
#  'dave_arneson',
#  'manuel_a_alonso',
#  'jaime_garzon',
#  'rufus_mallory',
#  'louis_henri_duc_de_bourbon',
#  'artur_gorgey',
#  'canadian_martyrs',
#  'pakubuwono_x',
#  'constance_collier',
#  'gala_galaction',
#  'mary_jayne_gold',
#  'c_douglas_dillon',
#  'arthur_rubinstein',
#  'forrest_l_vosler',
#  'tommaso_laureti',
#  'joseph_nathaniel_french',
#  'dimitrija_demeter',
#  'william_johnstone_1st_marquess_of_annandale',
#  'maurice_gibson',
#  'ernie_coombs',
#  'stefan_octavian_iosif',
#  'william_k_jones',
#  'dietrich_kraiss',
#  'william_moseley_jones',
#  'gainsford_bruce',
#  'amman',
#  'vincent_pallotti',
#  'ivan_saric',
#  'john_w_king',
#  'wang_hongwen',
#  'kenneth_richard_norris',
#  'john_fairfield',
#  'edward_ashael_birge',
#  'margaret_of_anjou',
#  'aretas_b_fleming',
#  'giuseppe_garibaldi_ii',
#  'johnathan_goddard',
#  'aernout_van_der_neer',
#  'walter_zapp',
#  'richard_miles_mccool',
#  'gale_bruno_van_albada',
#  'antofagasta',
#  'queen_anne_of_romania',
#  'pierre_schaeffer',
#  'jean_anouilh',
#  'francis_p_matthews',
#  'jules_janin',
#  'tony_doyle',
#  'karel_kryl',
#  'william_demarest',
#  'dmitri_shepilov',
#  'louis_gabriel_suchet',
#  'polperro',
#  'rafael_larco_hoyle',
#  'francis_ysidro_edgeworth',
#  'samson_raphael_hirsch',
#  'shen_kuo',
#  'georgy_pyatakov',
#  'ivan_dixon',
#  'james_barber',
#  's_k_amin',
#  'william_feller',
#  'raul_brandao',
#  'owen_josephus_roberts',
#  'harold_schafer',
#  'christian_friedrich_heinecken',
#  'tomas_masaryk',
#  'gillis_dhondecoeter',
#  'frankie_thomas',
#  'douglas_anne_munson',
#  'john_prettyjohns',
#  'albert_dekker',
#  'maurice_gibb',
#  'ernst_casimir',
#  'abu_ali_mustafa',
#  'hermann_eduard_von_holst',
#  'norman_leslie_19th_earl_of_rothes',
#  'thomas_roberts_ferguson',
#  'jay_belasco',
#  'matyla_ghyka',
#  'chudadhut_dharadilok',
#  'gonzalo_de_sandoval',
#  'argenteuil',
#  'master_bertram',
#  'dartmouth_massachusetts',
#  'francis_kelly_1860',
#  'peig_sayers',
#  'florentino_ameghino',
#  'columbus_indiana',
#  'bert_haanstra',
#  'richard_of_conisburgh_3rd_earl_of_cambridge',
#  'theodor_morell',
#  'erich_leie',
#  'margaret_chase_smith',
#  'larry_keating',
#  'augustus_c_french',
#  'robert_mylne',
#  'friedrich_august_kekule_von_stradonitz',
#  'george_robledo',
#  'michiel_de_swaen',
#  'willis_lamb',
#  'octave_cremazie',
#  'vladimir_arnold',
#  'karnal',
#  'menno_van_coehoorn',
#  'university_of_graz',
#  'john_b_curtis',
#  'kermit_roosevelt_jr',
#  'cheikha_rimitti',
#  'johann_georg_halske',
#  'alfred_fowler',
#  'eliska_junkova',
#  'martiros_saryan',
#  'tran_quoc_binh',
#  'philip_iii_of_navarre',
#  'charles_sidney_winder',
#  'luis_de_morales',
#  'roger_martin_du_gard',
#  'betty_hutton',
#  'nicholas_flamel',
#  'robertson_davies',
#  'erhard_altdorfer',
#  'william_montagu_douglas_scott_6th_duke_of_buccleuch',
#  'albert_e_mead',
#  'douglas_hamilton_8th_duke_of_hamilton',
#  'john_edward_mack',
#  'willard_m_mitchell',
#  'robert_fassnacht',
#  'john_scalise',
#  'm_r_james',
#  'james_clerk_maxwell',
#  'otto_beit',
#  'joseph_cornell',
#  'edwin_gray_lee',
#  'pinklao',
#  'prince_christoph_of_hesse-cassel',
#  'bela_kun',
#  'jo_van_fleet',
#  'kenneth_bainbridge',
#  'paul_dessau',
#  'shams_tabrizi',
#  'aida_alberti',
#  'brigham_young_university',
#  'charlotte_greenwood',
#  'jose_burgos',
#  'ferdinand_ii_of_naples',
#  'beniamino_andreatta',
#  'j_t_walsh',
#  'tintoretto',
#  'federico_seismit_doda',
#  'johann_christian_kittel',
#  'manchu',
#  'emilio_lisson',
#  'archduke_anton_prince_of_tuscany',
#  'anna_maria_lenngren',
#  'e_f_schumacher',
#  'heinrich_geissler',
#  'li_xiannian',
#  'alice_coltrane',
#  'john_james_powers',
#  'irene_nemirovsky',
#  'joseph_cotten',
#  'emanuel_hahn',
#  'georges_gilles_de_la_tourette',
#  'mykhaylo_maksymovych',
#  'francis_peyton_rous',
#  'romain_maes',
#  'john_romilly_1st_baron_romilly',
#  'grace_albee',
#  'dmitry_likhachev',
#  'ludwig_ii_of_bavaria',
#  'sala_burton',
#  'john_carradine',
#  'andrei_gromyko',
#  'eugenius_warming',
#  'anne_dharnoncourt',
#  'pietro_bettelini',
#  'dayton_miller',
#  'carlos_ruiz_tagle',
#  'samuel_williston',
#  'conroy_maddox',
#  'camille_desmoulins',
#  'jonathan_dickinson_1688',
#  'francois_truffaut',
#  'joey_stefano',
#  'sophie_rostopchine_comtesse_de_segur',
#  'stanislaw_kopanski',
#  'johann_peter_pixis',
#  'bud_abbott',
#  'ferdinand_iii_grand_duke_of_tuscany',
#  'berlin',
#  'ion_baiesu',
#  'kid_chocolate',
#  'xenia',
#  'jose_gautier_benitez',
#  'catherine_drinker_bowen',
#  'tikka_khan',
#  'maria_montessori',
#  'dora_stratou',
#  'sophia_of_hanover',
#  'james_van_der_zee',
#  'ephraim_kishon',
#  'ion_ratiu',
#  'hossein_fatemi',
#  'agra',
#  'robert_hope-jones',
#  'william_jones',
#  'constant_feith',
#  'petros_adamian',
#  'cecil_reginald_noble',
#  'w_g_grace',
#  'john_mcarthur',
#  'thomas_beecham',
#  'eddie_byrne',
#  'rich_cronin',
#  'yueh_feng',
#  'turgut_ozal',
#  'james_wong_howe',
#  'theodor_schneider',
#  'silas_soule',
#  'frederick_banting',
#  'john_i_of_denmark',
#  'university_of_maryland_school_of_law',
#  'jean_metzinger',
#  'john_a_j_creswell',
#  'antonio_marcello_barberini',
#  'alfred_beit',
#  'madame_de_pompadour',
#  'rolf_nesch',
#  'louis_i_count_of_blois',
#  'svyatoslav_fyodorov',
#  'ezekiel_gilman_robinson',
#  'dora_carrington',
#  'charles_scott_todd',
#  'thomas_o_selfridge_jr',
#  'daniel_auber',
#  'frans_post',
#  'archie_alexander',
#  'michel_de_grammont',
#  'patriarch_alexius_ii',
#  'leverett_saltonstall',
#  'bernardino_ochino',
#  'eugene_marais',
#  'charlie_paddock',
#  'ramesses_ii',
#  'john_hamilton_1886',
#  'gabriel_anton',
#  'olomouc',
#  'tom_longboat',
#  'zhongshan',
#  'gottfried_benn',
#  'john_graves_simcoe',
#  'gene_pitney',
#  'guy_mairesse',
#  'jimmy_doolittle',
#  'antonio_molinari',
#  'egypt',
#  'kersey_graves',
#  'rosika_schwimmer',
#  'keohok_lole',
#  'julian_abele',
#  'jake_hanna',
#  'david_poe_jr',
#  'gaetano_guadagni',
#  'gabriel_valentin',
#  'moritz_schlick',
#  'bela_miklos',
#  'frank_navin',
#  'william_beaudine',
#  'francis_webb',
#  'university_of_hamburg',
#  'stuart_roosa',
#  'nitish_katara',
#  'gottfried_von_strassburg',
#  'jay_dratler',
#  'bob_marley',
#  'john_dierkes',
#  'maria_swanenburg',
#  'philip_i_of_france',
#  'leonard_wibberley',
#  'mathias_loras',
#  'gervasio_antonio_de_posadas',
#  'richard_katz',
#  'claire_lee_chennault',
#  'john_f_boynton',
#  'thomas_meehan',
#  'pope_alexander_vii',
#  'william_goetz',
#  'art_carney',
#  'louis_legendre',
#  'joseph_roth',
#  'burke_marshall',
#  'richard_cassirer',
#  'christian_x_of_denmark',
#  'john_h_bartlett',
#  'vilhelm_bjerknes',
#  'james_reese_europe',
#  'albinus_nance',
#  'valentinian_ii',
#  'prince_nicholas_of_romania',
#  'honda_tadakatsu',
#  'daniel_ruggles',
#  'watertown',
#  'mohammed_baqir_al-hakim',
#  'blake_ragsdale_van_leer',
#  'friedrich_hegar',
#  'giuseppe_ungaretti',
#  'lorenzo_tucker',
#  'fred_fish',
#  'jose_gola',
#  'james_edward_quigley',
#  'argyll',
#  'thomas_mayne_daly',
#  'patricia_mcgee',
#  'amaxi',
#  'adolf_wilhelm_theodor_stahr',
#  'thomas_satterwhite_noble',
#  'juan_larrea',
#  'david_george_ouellet',
#  'harold_wilson',
#  'alan_beddoe',
#  'ray_lyman_wilbur',
#  'toledo_ohio',
#  'theodosia_burr_alston',
#  'henry_herbert_stevens',
#  'william_bateson',
#  'learie_constantine',
#  'matt_monro',
#  'antoni_lange',
#  'ryan_patrick_halligan',
#  'william_augustine_ogden',
#  'israel_isidor_elyashev',
#  'saadat_ali_khan',
#  'vakhtang_vi_of_kartli',
#  'charles_xiii_of_sweden',
#  'maurice_perrault',
#  'dennis_chavez',
#  'jacob_k_javits',
#  'louis_ramond_de_carbonnieres',
#  'edmond_obrien',
#  'charles_edward_howard_vincent',
#  'george_stott',
#  'jiquilpan',
#  'johannes_von_geissel',
#  'duke_ellington',
#  'theodore_sedgwick',
#  'robert_planquette',
#  'paul_tillich',
#  'joaquin_murrieta',
#  'niall_of_the_nine_hostages',
#  'sulpiz_boisseree',
#  'ithell_colquhoun',
#  'uwe_nettelbeck',
#  'east_macedonia_and_thrace',
#  'cesar_basa',
#  'ferdinand_meldahl',
#  'giambologna',
#  'john_scott_youll',
#  'maria_celeste',
#  'alfred_capus',
#  'rudolf_virchow',
#  'peter_crerar',
#  'dogen',
#  'rembert_dodoens',
#  'billy_evans',
#  'thomas_graham_jackson',
#  'joseph_kessel',
#  'jean_stas',
#  'ali_akbar_khan',
#  'richard_b_garnett',
#  'carson_whitsett',
#  'johann_arndt',
#  'pea_ridge_day',
#  'salomon_van_ruisdael',
#  'guillermo_tell_villegas',
#  'charles_horace_mayo',
#  'lluis_maria_xirinacs',
#  'james_b_a_robertson',
#  'ditlev_gothard_monrad',
#  'john_donne',
#  'josias_fendall',
#  'richard_wayne_dirksen',
#  'peggy_shippen',
#  'olga_de_meyer',
#  'theodore_taylor',
#  'david_octavius_hill',
#  'stafford_repp',
#  'johanna_crossman',
#  'george_macdonald_fraser',
#  'j_h_c_whitehead',
#  'marquis_cooper',
#  'jean-pierre_cassel',
#  'leo_szilard',
#  'max_dessoir',
#  'robert_l_williams',
#  'sigismund_iii_vasa',
#  'libbie_hyman',
#  'martha_sleeper',
#  'william_scoresby',
#  'leo_mckern',
#  'w_b_henning',
#  'pine_bluff',
#  'aime_girard',
#  'charles_boucher_de_boucherville',
#  'allen_tate',
#  'schelto_patijn',
#  'samuel_liddell_macgregor_mathers',
#  'billy_murdoch',
#  'siegfried_jacobsen',
#  'george_cholmondeley_6th_marquess_of_cholmondeley',
#  'william_alabaster',
#  'william_hopper',
#  'william_buckland',
#  ...]

# %%
mapped_dataset = []
inverse_info = []
miss_cnt = 0
for i in range(len(head_entities)):
    head_name = head_entities[i]
    tail_name = tail_entities[i]
    relation_names = relations[i]
    if head_name in n2fbid and tail_name in n2fbid:
        head_idx = id2idx[n2fbid[head_name]]
        tail_idx = id2idx[n2fbid[tail_name]]
    else:
        miss_cnt += 1
        continue
    rel_idxs = []
    rel_inverses = []
    for rel_name in relation_names:
        if '**' in rel_name:
            rel_inverses.append(1)
            rname = rel_name.replace('**', '')
        else:
            rel_inverses.append(0)
            rname = rel_name
        rel_idx = rname2idx[rname]
        rel_idxs.append(rel_idx)
    row = [head_idx, rel_idxs, tail_idx]
    mapped_dataset.append(row)

# %%
print(miss_cnt,  len(head_entities))
# Out:
# 26828 27163

# %% [markdown]
# - want: list of lists: [entity_idx0, [rel_idx0, rel_idx1, rel_idx2, ... ], entity_idx1]
# - have: list of lists: [entity_name0, [rel_name0, rel_name1, rel_name2, ...], entity_name1]
# - have: mapping entity indices to ids -- > mapping entity ids to indices
# - have: mapping entity ids to names --> mapping names to entity ids
# - have: mapping relation idxs to names --> mapping names to relation idxs
#
# - plan:
#     - loop over json file, creating dictionary from (lowercased, space underscored) names to fb ids (n2fbid)
#     - create mapping of relation names to shortened names (taking final /word) then invert this dictionary
#     - for each row in traversal dataset:
#         - map each entity name via n2fbid then map result to index via fbid2idx
#         - for each relation:
#             - map relation name to relation short long name the map result to relation idx
#             - keep track of which are inverses
